# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 646

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Enter your API key here
api_key = weather_api_key
 
# base_url variable to store url
base_url = "http://api.openweathermap.org/data/2.5/weather?"
 
# complete url address
for city in cities:
    complete_url = base_url + "appid=" + api_key + "&q=" + city
    
# return response object using get method and json method
    response = requests.get(complete_url).json()
    
    print(json.dumps(response, indent=4))
# Out:
# {
#     "coord": {
#         "lon": -155.09,
#         "lat": 19.7297
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 298.88,
#         "feels_like": 299.6,
#         "temp_min": 297.38,
#         "temp_max": 300,
#         "pressure": 1013,
#         "humidity": 80
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.06,
#         "deg": 90
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1662871518,
#     "sys": {
#         "type": 1,
#         "id": 7881,
#         "country": "US",
#         "sunrise": 1662826019,
#         "sunset": 1662870472
#     },
#     "timezone": -36000,
#     "id": 5855927,
#     "name": "Hilo",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 28.8684,
#         "lat": 51.3929
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 284.33,
#         "feels_like": 283.93,
#         "temp_min": 284.33,
#         "temp_max": 284.33,
#         "pressure": 1009,
#         "humidity": 93,
#         "sea_level": 1009,
#         "grnd_level": 986
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.37,
#         "deg": 209,
#         "gust": 7.95
#     },
#     "clouds": {
#         "all": 99
#     },
#     "dt": 1662871518,
#     "sys": {
#         "country": "UA",
#         "sunrise": 1662867172,
#         "sunset": 1662913799
#     },
#     "timezone": 10800,
#     "id": 697608,
#     "name": "Pershotravneve",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 46.4667,
#         "lat": 14.4
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 301.87,
#         "feels_like": 301.1,
#         "temp_min": 301.87,
#         "temp_max": 301.87,
#         "pressure": 1010,
#         "humidity": 35,
#         "sea_level": 1010,
#         "grnd_level": 889
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.35,
#         "deg": 221,
#         "gust": 1.1
#     },
#     "clouds": {
#         "all": 93
#     },
#     "dt": 1662871518,
#     "sys": {
#         "country": "YE",
#         "sunrise": 1662864170,
#         "sunset": 1662908355
#     },
#     "timezone": 10800,
#     "id": 72181,
#     "name": "Marzuq",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 138.7333,
#         "lat": -34.6
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 288.58,
#         "feels_like": 287.77,
#         "temp_min": 286.88,
#         "temp_max": 288.98,
#         "pressure": 1019,
#         "humidity": 61,
#         "sea_level": 1019,
#         "grnd_level": 1013
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.19,
#         "deg": 238,
#         "gust": 5.14
#     },
#     "clouds": {
#         "all": 65
#     },
#     "dt": 1662871429,
#     "sys": {
#         "type": 2,
#         "id": 2002614,
#         "country": "AU",
#         "sunrise": 1662843066,
#         "sunset": 1662885183
#     },
#     "timezone": 34200,
#     "id": 2071059,
#     "name": "Gawler",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": -50.0119,
#         "lat": -24.7911
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 287.03,
#         "feels_like": 287.03,
#         "temp_min": 287.03,
#         "temp_max": 287.03,
#         "pressure": 1019,
#         "humidity": 98,
#         "sea_level": 1019,
#         "grnd_level": 906
#     },
#     "visibility": 74,
#     "wind": {
#         "speed": 2.78,
#         "deg": 105,
#         "gust": 5.29
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871451,
#     "sys": {
#         "country": "BR",
#         "sunrise": 1662888094,
#         "sunset": 1662930729
#     },
#     "timezone": -10800,
#     "id": 3466704,
#     "name": "Castro",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -42.0278,
#         "lat": -22.9661
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 293.64,
#         "feels_like": 294.17,
#         "temp_min": 293.64,
#         "temp_max": 293.64,
#         "pressure": 1018,
#         "humidity": 93,
#         "sea_level": 1018,
#         "grnd_level": 1016
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 9.02,
#         "deg": 206,
#         "gust": 12.82
#     },
#     "clouds": {
#         "all": 99
#     },
#     "dt": 1662871519,
#     "sys": {
#         "country": "BR",
#         "sunrise": 1662886141,
#         "sunset": 1662928851
#     },
#     "timezone": -10800,
#     "id": 3471451,
#     "name": "Arraial do Cabo",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 18.4232,
#         "lat": -33.9258
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 285.99,
#         "feels_like": 285.73,
#         "temp_min": 284.88,
#         "temp_max": 286.38,
#         "pressure": 1021,
#         "humidity": 92
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.06,
#         "deg": 50
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1662871521,
#     "sys": {
#         "type": 2,
#         "id": 2073005,
#         "country": "ZA",
#         "sunrise": 1662871895,
#         "sunset": 1662914088
#     },
#     "timezone": 7200,
#     "id": 3369157,
#     "name": "Cape Town",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 36.9856,
#         "lat": -16.8392
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 295.59,
#         "feels_like": 295.61,
#         "temp_min": 295.59,
#         "temp_max": 295.59,
#         "pressure": 1018,
#         "humidity": 66,
#         "sea_level": 1018,
#         "grnd_level": 1001
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.76,
#         "deg": 44,
#         "gust": 3.89
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871521,
#     "sys": {
#         "country": "MZ",
#         "sunrise": 1662867065,
#         "sunset": 1662910010
#     },
#     "timezone": 7200,
#     "id": 1024312,
#     "name": "Mocuba",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 115.8257,
#         "lat": 22.8134
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 302.57,
#         "feels_like": 306.21,
#         "temp_min": 302.57,
#         "temp_max": 302.57,
#         "pressure": 1008,
#         "humidity": 67,
#         "sea_level": 1008,
#         "grnd_level": 1007
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.67,
#         "deg": 189,
#         "gust": 3.34
#     },
#     "clouds": {
#         "all": 18
#     },
#     "dt": 1662871434,
#     "sys": {
#         "country": "CN",
#         "sunrise": 1662847328,
#         "sunset": 1662891914
#     },
#     "timezone": 28800,
#     "id": 1805857,
#     "name": "Jieshi",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 55.2,
#         "lat": 45.3167
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 288.6,
#         "feels_like": 287.09,
#         "temp_min": 288.6,
#         "temp_max": 288.6,
#         "pressure": 1023,
#         "humidity": 34,
#         "sea_level": 1023,
#         "grnd_level": 1022
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.44,
#         "deg": 342,
#         "gust": 5.76
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871522,
#     "sys": {
#         "country": "KZ",
#         "sunrise": 1662861153,
#         "sunset": 1662907182
#     },
#     "timezone": 18000,
#     "id": 610298,
#     "name": "Beyneu",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -69.3632,
#         "lat": 77.484
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 276.32,
#         "feels_like": 273.28,
#         "temp_min": 276.32,
#         "temp_max": 276.32,
#         "pressure": 1004,
#         "humidity": 99,
#         "sea_level": 1004,
#         "grnd_level": 1000
#     },
#     "visibility": 252,
#     "wind": {
#         "speed": 3.23,
#         "deg": 101,
#         "gust": 4.66
#     },
#     "rain": {
#         "1h": 0.64
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871522,
#     "sys": {
#         "country": "GL",
#         "sunrise": 1662886463,
#         "sunset": 1662941647
#     },
#     "timezone": -10800,
#     "id": 3831208,
#     "name": "Qaanaaq",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 10.7833,
#         "lat": 45.1667
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 291.09,
#         "feels_like": 291.16,
#         "temp_min": 289.23,
#         "temp_max": 294.68,
#         "pressure": 1013,
#         "humidity": 85
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.89,
#         "deg": 226,
#         "gust": 1.34
#     },
#     "clouds": {
#         "all": 3
#     },
#     "dt": 1662871239,
#     "sys": {
#         "type": 2,
#         "id": 2011529,
#         "country": "IT",
#         "sunrise": 1662871828,
#         "sunset": 1662917821
#     },
#     "timezone": 7200,
#     "id": 3174050,
#     "name": "Province of Mantua",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 168.8643,
#         "lat": -46.1927
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 287.86,
#         "feels_like": 286.82,
#         "temp_min": 287.86,
#         "temp_max": 287.86,
#         "pressure": 1008,
#         "humidity": 55,
#         "sea_level": 1008,
#         "grnd_level": 1002
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.86,
#         "deg": 62,
#         "gust": 1.7
#     },
#     "clouds": {
#         "all": 2
#     },
#     "dt": 1662871523,
#     "sys": {
#         "type": 2,
#         "id": 2008959,
#         "country": "NZ",
#         "sunrise": 1662836200,
#         "sunset": 1662877590
#     },
#     "timezone": 43200,
#     "id": 6201424,
#     "name": "Mataura",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -70.9167,
#         "lat": -53.15
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 278.21,
#         "feels_like": 274.26,
#         "temp_min": 278.21,
#         "temp_max": 278.21,
#         "pressure": 1007,
#         "humidity": 70
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.66,
#         "deg": 330
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871523,
#     "sys": {
#         "type": 1,
#         "id": 8487,
#         "country": "CL",
#         "sunrise": 1662893941,
#         "sunset": 1662934914
#     },
#     "timezone": -10800,
#     "id": 3874787,
#     "name": "Punta Arenas",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -49.6678,
#         "lat": 61.994
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 279.54,
#         "feels_like": 275.77,
#         "temp_min": 279.54,
#         "temp_max": 279.54,
#         "pressure": 1022,
#         "humidity": 83,
#         "sea_level": 1022,
#         "grnd_level": 1020
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.1,
#         "deg": 156,
#         "gust": 8.63
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871524,
#     "sys": {
#         "country": "GL",
#         "sunrise": 1662885243,
#         "sunset": 1662933415
#     },
#     "timezone": -7200,
#     "id": 3421193,
#     "name": "Paamiut",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -7.7169,
#         "lat": 4.375
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296.93,
#         "feels_like": 297.61,
#         "temp_min": 296.93,
#         "temp_max": 296.93,
#         "pressure": 1014,
#         "humidity": 86,
#         "sea_level": 1014,
#         "grnd_level": 1013
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.85,
#         "deg": 213,
#         "gust": 5.37
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871524,
#     "sys": {
#         "country": "LR",
#         "sunrise": 1662877379,
#         "sunset": 1662921148
#     },
#     "timezone": 0,
#     "id": 2276492,
#     "name": "Harper",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 88.3972,
#         "lat": 69.4865
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 277.71,
#         "feels_like": 274.68,
#         "temp_min": 277.71,
#         "temp_max": 277.71,
#         "pressure": 1011,
#         "humidity": 99,
#         "sea_level": 1011,
#         "grnd_level": 1002
#     },
#     "visibility": 23,
#     "wind": {
#         "speed": 3.66,
#         "deg": 166,
#         "gust": 5.32
#     },
#     "rain": {
#         "1h": 0.98
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871526,
#     "sys": {
#         "type": 2,
#         "id": 49144,
#         "country": "RU",
#         "sunrise": 1662850986,
#         "sunset": 1662901418
#     },
#     "timezone": 25200,
#     "id": 1490256,
#     "name": "Talnakh",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 36.5766,
#         "lat": 37.1972
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 297.02,
#         "feels_like": 296.9,
#         "temp_min": 297.02,
#         "temp_max": 297.02,
#         "pressure": 1011,
#         "humidity": 55,
#         "sea_level": 1011,
#         "grnd_level": 945
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.3,
#         "deg": 286,
#         "gust": 1.38
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871526,
#     "sys": {
#         "country": "TR",
#         "sunrise": 1662865941,
#         "sunset": 1662911331
#     },
#     "timezone": 10800,
#     "id": 322391,
#     "name": "Bah\u00e7e",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 26.891,
#         "lat": -33.5906
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 289.58,
#         "feels_like": 289.16,
#         "temp_min": 289.58,
#         "temp_max": 289.58,
#         "pressure": 1018,
#         "humidity": 72,
#         "sea_level": 1018,
#         "grnd_level": 1016
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 9.25,
#         "deg": 254,
#         "gust": 11.76
#     },
#     "clouds": {
#         "all": 58
#     },
#     "dt": 1662871527,
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1662869856,
#         "sunset": 1662912063
#     },
#     "timezone": 7200,
#     "id": 964432,
#     "name": "Port Alfred",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -151.5483,
#         "lat": 59.6425
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 284.94,
#         "feels_like": 284.24,
#         "temp_min": 284.28,
#         "temp_max": 285.09,
#         "pressure": 1013,
#         "humidity": 79
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.89,
#         "deg": 3,
#         "gust": 2.24
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871527,
#     "sys": {
#         "type": 1,
#         "id": 7709,
#         "country": "US",
#         "sunrise": 1662823417,
#         "sunset": 1662871375
#     },
#     "timezone": -28800,
#     "id": 5864145,
#     "name": "Homer",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -68.3,
#         "lat": -54.8
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 275.96,
#         "feels_like": 274.54,
#         "temp_min": 275.96,
#         "temp_max": 275.96,
#         "pressure": 1003,
#         "humidity": 70
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.54,
#         "deg": 200
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871249,
#     "sys": {
#         "type": 1,
#         "id": 8303,
#         "country": "AR",
#         "sunrise": 1662893391,
#         "sunset": 1662934208
#     },
#     "timezone": -10800,
#     "id": 3833367,
#     "name": "Ushuaia",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 115.3333,
#         "lat": -33.65
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 289.79,
#         "feels_like": 289.26,
#         "temp_min": 289.79,
#         "temp_max": 289.79,
#         "pressure": 1016,
#         "humidity": 67,
#         "sea_level": 1016,
#         "grnd_level": 1016
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.06,
#         "deg": 332,
#         "gust": 4.59
#     },
#     "clouds": {
#         "all": 47
#     },
#     "dt": 1662871283,
#     "sys": {
#         "country": "AU",
#         "sunrise": 1662848652,
#         "sunset": 1662890826
#     },
#     "timezone": 28800,
#     "id": 2075265,
#     "name": "Busselton",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 72.4042,
#         "lat": 57.509
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 282.15,
#         "feels_like": 280.61,
#         "temp_min": 282.15,
#         "temp_max": 282.15,
#         "pressure": 1013,
#         "humidity": 65,
#         "sea_level": 1013,
#         "grnd_level": 1005
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.77,
#         "deg": 42,
#         "gust": 4.11
#     },
#     "clouds": {
#         "all": 21
#     },
#     "dt": 1662871527,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662856300,
#         "sunset": 1662903778
#     },
#     "timezone": 21600,
#     "id": 1489661,
#     "name": "Tevriz",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 27.8492,
#         "lat": 71.0357
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 280.12,
#         "feels_like": 278.33,
#         "temp_min": 280.1,
#         "temp_max": 280.12,
#         "pressure": 1012,
#         "humidity": 87
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.57,
#         "deg": 290
#     },
#     "rain": {
#         "1h": 0.13
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1662871529,
#     "sys": {
#         "type": 1,
#         "id": 1633,
#         "country": "NO",
#         "sunrise": 1662865237,
#         "sunset": 1662916222
#     },
#     "timezone": 7200,
#     "id": 778707,
#     "name": "Mehamn",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": -2.356,
#         "lat": 42.5617
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 286.38,
#         "feels_like": 285.77,
#         "temp_min": 283.39,
#         "temp_max": 286.38,
#         "pressure": 1017,
#         "humidity": 77
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0,
#         "deg": 0
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871530,
#     "sys": {
#         "type": 1,
#         "id": 6418,
#         "country": "ES",
#         "sunrise": 1662875093,
#         "sunset": 1662920861
#     },
#     "timezone": 7200,
#     "id": 3129839,
#     "name": "Aras",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 36.0366,
#         "lat": -7.6766
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 286.45,
#         "feels_like": 285.98,
#         "temp_min": 286.45,
#         "temp_max": 286.45,
#         "pressure": 1019,
#         "humidity": 82,
#         "sea_level": 1019,
#         "grnd_level": 870
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.37,
#         "deg": 136,
#         "gust": 4.09
#     },
#     "clouds": {
#         "all": 16
#     },
#     "dt": 1662871531,
#     "sys": {
#         "type": 1,
#         "id": 2611,
#         "country": "TZ",
#         "sunrise": 1662867113,
#         "sunset": 1662910417
#     },
#     "timezone": 10800,
#     "id": 159179,
#     "name": "Ilula",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -159.319,
#         "lat": 22.0752
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 299.59,
#         "feels_like": 299.59,
#         "temp_min": 297.7,
#         "temp_max": 301.14,
#         "pressure": 1013,
#         "humidity": 77
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.63,
#         "deg": 50
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1662871531,
#     "sys": {
#         "type": 2,
#         "id": 2005473,
#         "country": "US",
#         "sunrise": 1662826977,
#         "sunset": 1662871544
#     },
#     "timezone": -36000,
#     "id": 5848280,
#     "name": "Kapaa",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -114.3525,
#         "lat": 62.456
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 283.44,
#         "feels_like": 282.38,
#         "temp_min": 283.44,
#         "temp_max": 283.46,
#         "pressure": 1003,
#         "humidity": 71
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.2,
#         "deg": 270,
#         "gust": 11.83
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1662871236,
#     "sys": {
#         "type": 1,
#         "id": 1007,
#         "country": "CA",
#         "sunrise": 1662814190,
#         "sunset": 1662862752
#     },
#     "timezone": -21600,
#     "id": 6185377,
#     "name": "Yellowknife",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -37.6368,
#         "lat": 65.6145
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 276.24,
#         "feels_like": 274.08,
#         "temp_min": 276.24,
#         "temp_max": 276.24,
#         "pressure": 1020,
#         "humidity": 74,
#         "sea_level": 1020,
#         "grnd_level": 1015
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.2,
#         "deg": 290,
#         "gust": 2.27
#     },
#     "clouds": {
#         "all": 85
#     },
#     "dt": 1662871532,
#     "sys": {
#         "type": 1,
#         "id": 81,
#         "country": "GL",
#         "sunrise": 1662881928,
#         "sunset": 1662930957
#     },
#     "timezone": -7200,
#     "id": 3424607,
#     "name": "Tasiilaq",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -134.9692,
#         "lat": -23.1203
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296.01,
#         "feels_like": 296.15,
#         "temp_min": 296.01,
#         "temp_max": 296.01,
#         "pressure": 1023,
#         "humidity": 69,
#         "sea_level": 1023,
#         "grnd_level": 1020
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.3,
#         "deg": 62,
#         "gust": 5.56
#     },
#     "clouds": {
#         "all": 19
#     },
#     "dt": 1662871532,
#     "sys": {
#         "country": "PF",
#         "sunrise": 1662822095,
#         "sunset": 1662864741
#     },
#     "timezone": -32400,
#     "id": 4030556,
#     "name": "Rikitea",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 97.4531,
#         "lat": 58.3814
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 288.98,
#         "feels_like": 287.85,
#         "temp_min": 288.98,
#         "temp_max": 288.98,
#         "pressure": 1012,
#         "humidity": 47,
#         "sea_level": 1012,
#         "grnd_level": 997
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.97,
#         "deg": 200,
#         "gust": 4.55
#     },
#     "clouds": {
#         "all": 81
#     },
#     "dt": 1662871532,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662850209,
#         "sunset": 1662897849
#     },
#     "timezone": 25200,
#     "id": 1509844,
#     "name": "Boguchany",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 37.3321,
#         "lat": 19.1059
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 306.22,
#         "feels_like": 308.74,
#         "temp_min": 306.22,
#         "temp_max": 306.22,
#         "pressure": 1006,
#         "humidity": 47,
#         "sea_level": 1006,
#         "grnd_level": 1006
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.15,
#         "deg": 359,
#         "gust": 1.69
#     },
#     "clouds": {
#         "all": 94
#     },
#     "dt": 1662871533,
#     "sys": {
#         "country": "SD",
#         "sunrise": 1662866258,
#         "sunset": 1662910651
#     },
#     "timezone": 7200,
#     "id": 367544,
#     "name": "Saw\u0101kin",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 91.6419,
#         "lat": 48.0056
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 294.93,
#         "feels_like": 293.76,
#         "temp_min": 294.93,
#         "temp_max": 294.93,
#         "pressure": 1009,
#         "humidity": 23,
#         "sea_level": 1009,
#         "grnd_level": 861
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.56,
#         "deg": 114,
#         "gust": 2.88
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871533,
#     "sys": {
#         "country": "MN",
#         "sunrise": 1662852272,
#         "sunset": 1662898575
#     },
#     "timezone": 25200,
#     "id": 1516048,
#     "name": "Khovd",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -7.2667,
#         "lat": 55.25
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 284.27,
#         "feels_like": 283.87,
#         "temp_min": 284.27,
#         "temp_max": 284.27,
#         "pressure": 1015,
#         "humidity": 93,
#         "sea_level": 1015,
#         "grnd_level": 1011
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.53,
#         "deg": 158,
#         "gust": 2.54
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871533,
#     "sys": {
#         "country": "IE",
#         "sunrise": 1662875613,
#         "sunset": 1662922698
#     },
#     "timezone": 3600,
#     "id": 2965761,
#     "name": "Carndonagh",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 25.5701,
#         "lat": -33.918
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 287.77,
#         "feels_like": 287.59,
#         "temp_min": 287.31,
#         "temp_max": 287.77,
#         "pressure": 1018,
#         "humidity": 88
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.17,
#         "deg": 260
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1662871254,
#     "sys": {
#         "type": 2,
#         "id": 2072678,
#         "country": "ZA",
#         "sunrise": 1662870181,
#         "sunset": 1662912372
#     },
#     "timezone": 7200,
#     "id": 964420,
#     "name": "Port Elizabeth",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 20.0403,
#         "lat": -34.5322
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 285.21,
#         "feels_like": 284.77,
#         "temp_min": 285.21,
#         "temp_max": 285.21,
#         "pressure": 1021,
#         "humidity": 88,
#         "sea_level": 1021,
#         "grnd_level": 1012
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.14,
#         "deg": 273,
#         "gust": 6.82
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871534,
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1662871522,
#         "sunset": 1662913685
#     },
#     "timezone": 7200,
#     "id": 1015776,
#     "name": "Bredasdorp",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 124.8925,
#         "lat": -9.1061
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 302.84,
#         "feels_like": 303.75,
#         "temp_min": 302.84,
#         "temp_max": 302.84,
#         "pressure": 1010,
#         "humidity": 50,
#         "sea_level": 1010,
#         "grnd_level": 972
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.74,
#         "deg": 323,
#         "gust": 3.17
#     },
#     "clouds": {
#         "all": 12
#     },
#     "dt": 1662871535,
#     "sys": {
#         "country": "ID",
#         "sunrise": 1662845824,
#         "sunset": 1662889066
#     },
#     "timezone": 28800,
#     "id": 1651103,
#     "name": "Atambua",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 57.7,
#         "lat": -20.4081
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296.31,
#         "feels_like": 296.35,
#         "temp_min": 296.07,
#         "temp_max": 296.31,
#         "pressure": 1022,
#         "humidity": 64
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.17,
#         "deg": 90
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1662871378,
#     "sys": {
#         "type": 1,
#         "id": 2061,
#         "country": "MU",
#         "sunrise": 1662862169,
#         "sunset": 1662904965
#     },
#     "timezone": 14400,
#     "id": 934322,
#     "name": "Mah\u00e9bourg",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -173.3,
#         "lat": 64.3833
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 280.22,
#         "feels_like": 276.38,
#         "temp_min": 280.22,
#         "temp_max": 280.22,
#         "pressure": 1002,
#         "humidity": 67,
#         "sea_level": 1002,
#         "grnd_level": 1001
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.84,
#         "deg": 72,
#         "gust": 8.13
#     },
#     "clouds": {
#         "all": 96
#     },
#     "dt": 1662871535,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662914709,
#         "sunset": 1662963277
#     },
#     "timezone": 43200,
#     "id": 4031574,
#     "name": "Provideniya",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 100.3354,
#         "lat": 5.4112
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 300.28,
#         "feels_like": 302.78,
#         "temp_min": 298.11,
#         "temp_max": 300.87,
#         "pressure": 1012,
#         "humidity": 76
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.68,
#         "deg": 180,
#         "gust": 0
#     },
#     "rain": {
#         "1h": 0.56
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1662871487,
#     "sys": {
#         "type": 2,
#         "id": 2037578,
#         "country": "MY",
#         "sunrise": 1662851430,
#         "sunset": 1662895245
#     },
#     "timezone": 28800,
#     "id": 1735106,
#     "name": "George Town",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 57.082,
#         "lat": 60.4078
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 279.76,
#         "feels_like": 279.76,
#         "temp_min": 279.76,
#         "temp_max": 279.76,
#         "pressure": 1019,
#         "humidity": 94,
#         "sea_level": 1019,
#         "grnd_level": 1004
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.3,
#         "deg": 22,
#         "gust": 1.08
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871536,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662859734,
#         "sunset": 1662907697
#     },
#     "timezone": 18000,
#     "id": 542184,
#     "name": "Krasnovishersk",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 168.3333,
#         "lat": -46.6
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 288.04,
#         "feels_like": 287.44,
#         "temp_min": 288.04,
#         "temp_max": 288.04,
#         "pressure": 1009,
#         "humidity": 71,
#         "sea_level": 1009,
#         "grnd_level": 1006
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.03,
#         "deg": 133,
#         "gust": 4.2
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871536,
#     "sys": {
#         "type": 2,
#         "id": 2008959,
#         "country": "NZ",
#         "sunrise": 1662836342,
#         "sunset": 1662877702
#     },
#     "timezone": 43200,
#     "id": 2206939,
#     "name": "Bluff",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 69.5725,
#         "lat": 32.2989
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 299.48,
#         "feels_like": 299.48,
#         "temp_min": 299.48,
#         "temp_max": 299.48,
#         "pressure": 1008,
#         "humidity": 50,
#         "sea_level": 1008,
#         "grnd_level": 863
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.54,
#         "deg": 129,
#         "gust": 1.4
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871536,
#     "sys": {
#         "country": "PK",
#         "sunrise": 1662858174,
#         "sunset": 1662903263
#     },
#     "timezone": 18000,
#     "id": 1162634,
#     "name": "Wana",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 25.4459,
#         "lat": 36.3985
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296.26,
#         "feels_like": 296.79,
#         "temp_min": 295.3,
#         "temp_max": 296.31,
#         "pressure": 1010,
#         "humidity": 83
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0,
#         "deg": 0
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871537,
#     "sys": {
#         "type": 1,
#         "id": 6645,
#         "country": "GR",
#         "sunrise": 1662868640,
#         "sunset": 1662913973
#     },
#     "timezone": 10800,
#     "id": 257224,
#     "name": "Messaria",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 6.2642,
#         "lat": 4.9247
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296.24,
#         "feels_like": 297.06,
#         "temp_min": 296.24,
#         "temp_max": 296.24,
#         "pressure": 1014,
#         "humidity": 94,
#         "sea_level": 1014,
#         "grnd_level": 1013
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.67,
#         "deg": 234,
#         "gust": 4.57
#     },
#     "clouds": {
#         "all": 99
#     },
#     "dt": 1662871537,
#     "sys": {
#         "country": "NG",
#         "sunrise": 1662874013,
#         "sunset": 1662917805
#     },
#     "timezone": 3600,
#     "id": 2318123,
#     "name": "Yenagoa",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -139.0333,
#         "lat": -9.8
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 298.17,
#         "feels_like": 298.61,
#         "temp_min": 298.17,
#         "temp_max": 298.17,
#         "pressure": 1015,
#         "humidity": 72,
#         "sea_level": 1015,
#         "grnd_level": 1007
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.97,
#         "deg": 91,
#         "gust": 9.61
#     },
#     "clouds": {
#         "all": 5
#     },
#     "dt": 1662871537,
#     "sys": {
#         "country": "PF",
#         "sunrise": 1662822790,
#         "sunset": 1662865996
#     },
#     "timezone": -34200,
#     "id": 4020109,
#     "name": "Atuona",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -169.9187,
#         "lat": -19.0595
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 299.09,
#         "feels_like": 299.54,
#         "temp_min": 299.09,
#         "temp_max": 299.09,
#         "pressure": 1015,
#         "humidity": 69
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.63,
#         "deg": 100
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871538,
#     "sys": {
#         "type": 1,
#         "id": 7306,
#         "country": "NU",
#         "sunrise": 1662830390,
#         "sunset": 1662873218
#     },
#     "timezone": -39600,
#     "id": 4036284,
#     "name": "Alofi",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 124.1694,
#         "lat": 14.0453
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 304.88,
#         "feels_like": 309.6,
#         "temp_min": 304.88,
#         "temp_max": 304.88,
#         "pressure": 1007,
#         "humidity": 60,
#         "sea_level": 1007,
#         "grnd_level": 1007
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.46,
#         "deg": 219,
#         "gust": 3.09
#     },
#     "clouds": {
#         "all": 97
#     },
#     "dt": 1662871538,
#     "sys": {
#         "country": "PH",
#         "sunrise": 1662845529,
#         "sunset": 1662889708
#     },
#     "timezone": 28800,
#     "id": 1695546,
#     "name": "Pandan",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 116.8477,
#         "lat": 6.8837
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 299.11,
#         "feels_like": 299.11,
#         "temp_min": 298.87,
#         "temp_max": 299.11,
#         "pressure": 1010,
#         "humidity": 89
#     },
#     "visibility": 8000,
#     "wind": {
#         "speed": 4.63,
#         "deg": 240
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1662871538,
#     "sys": {
#         "type": 1,
#         "id": 9375,
#         "country": "MY",
#         "sunrise": 1662847437,
#         "sunset": 1662891313
#     },
#     "timezone": 28800,
#     "id": 1736458,
#     "name": "Kudat",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 19.2345,
#         "lat": -34.4187
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 286.37,
#         "feels_like": 285.94,
#         "temp_min": 286.37,
#         "temp_max": 286.37,
#         "pressure": 1021,
#         "humidity": 84,
#         "sea_level": 1021,
#         "grnd_level": 1018
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.18,
#         "deg": 245,
#         "gust": 5.05
#     },
#     "rain": {
#         "1h": 0.28
#     },
#     "clouds": {
#         "all": 99
#     },
#     "dt": 1662871539,
#     "sys": {
#         "type": 2,
#         "id": 2006131,
#         "country": "ZA",
#         "sunrise": 1662871713,
#         "sunset": 1662913881
#     },
#     "timezone": 7200,
#     "id": 3366880,
#     "name": "Hermanus",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -75.833,
#         "lat": 42.2506
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 291.3,
#         "feels_like": 291.16,
#         "temp_min": 289.87,
#         "temp_max": 292.94,
#         "pressure": 1002,
#         "humidity": 76
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.57,
#         "deg": 180
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871539,
#     "sys": {
#         "type": 2,
#         "id": 2036074,
#         "country": "US",
#         "sunrise": 1662892753,
#         "sunset": 1662938462
#     },
#     "timezone": -14400,
#     "id": 5110365,
#     "name": "Broome",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 141.6739,
#         "lat": 45.4094
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 297.14,
#         "feels_like": 296.9,
#         "temp_min": 297.14,
#         "temp_max": 297.14,
#         "pressure": 1018,
#         "humidity": 50
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.63,
#         "deg": 250
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1662871250,
#     "sys": {
#         "type": 1,
#         "id": 7981,
#         "country": "JP",
#         "sunrise": 1662840377,
#         "sunset": 1662886460
#     },
#     "timezone": 32400,
#     "id": 2127515,
#     "name": "Wakkanai",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": 151.6667,
#         "lat": -32.95
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 293.84,
#         "feels_like": 293.11,
#         "temp_min": 293,
#         "temp_max": 295.1,
#         "pressure": 1012,
#         "humidity": 44
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.89,
#         "deg": 108,
#         "gust": 2.68
#     },
#     "clouds": {
#         "all": 5
#     },
#     "dt": 1662871540,
#     "sys": {
#         "type": 2,
#         "id": 2007334,
#         "country": "AU",
#         "sunrise": 1662839922,
#         "sunset": 1662882120
#     },
#     "timezone": 36000,
#     "id": 2171766,
#     "name": "Charlestown",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -65.7125,
#         "lat": 66.1451
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 281.06,
#         "feels_like": 279.29,
#         "temp_min": 281.06,
#         "temp_max": 281.06,
#         "pressure": 1006,
#         "humidity": 90,
#         "sea_level": 1006,
#         "grnd_level": 1003
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.79,
#         "deg": 104,
#         "gust": 4.31
#     },
#     "rain": {
#         "1h": 1
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871542,
#     "sys": {
#         "country": "CA",
#         "sunrise": 1662888609,
#         "sunset": 1662937749
#     },
#     "timezone": -14400,
#     "id": 6096551,
#     "name": "Pangnirtung",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -135.0107,
#         "lat": 68.2191
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 279.68,
#         "feels_like": 278.58,
#         "temp_min": 279.68,
#         "temp_max": 279.68,
#         "pressure": 1010,
#         "humidity": 96,
#         "sea_level": 1010,
#         "grnd_level": 1010
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.73,
#         "deg": 326,
#         "gust": 2.77
#     },
#     "rain": {
#         "1h": 0.27
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871542,
#     "sys": {
#         "country": "CA",
#         "sunrise": 1662818352,
#         "sunset": 1662868504
#     },
#     "timezone": -21600,
#     "id": 5882953,
#     "name": "Aklavik",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": 55.7679,
#         "lat": -21.3585
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296.92,
#         "feels_like": 297.31,
#         "temp_min": 296.92,
#         "temp_max": 296.92,
#         "pressure": 1024,
#         "humidity": 75,
#         "sea_level": 1024,
#         "grnd_level": 1017
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.84,
#         "deg": 75,
#         "gust": 3.82
#     },
#     "clouds": {
#         "all": 15
#     },
#     "dt": 1662871543,
#     "sys": {
#         "type": 1,
#         "id": 2127,
# ...
#         "temp_min": 297.32,
#         "temp_max": 297.32,
#         "pressure": 1014,
#         "humidity": 53,
#         "sea_level": 1014,
#         "grnd_level": 910
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.91,
#         "deg": 101,
#         "gust": 1.8
#     },
#     "clouds": {
#         "all": 93
#     },
#     "dt": 1662871768,
#     "sys": {
#         "country": "ZM",
#         "sunrise": 1662868658,
#         "sunset": 1662911932
#     },
#     "timezone": 7200,
#     "id": 176758,
#     "name": "Kaputa",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": 58.1442,
#         "lat": 48.8264
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 284.2,
#         "feels_like": 283.06,
#         "temp_min": 284.2,
#         "temp_max": 284.2,
#         "pressure": 1019,
#         "humidity": 65,
#         "sea_level": 1019,
#         "grnd_level": 991
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7,
#         "deg": 347,
#         "gust": 8.44
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871769,
#     "sys": {
#         "country": "KZ",
#         "sunrise": 1662860277,
#         "sunset": 1662906644
#     },
#     "timezone": 18000,
#     "id": 609924,
#     "name": "Emba",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 25.85,
#         "lat": -9.2
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296.41,
#         "feels_like": 296.04,
#         "temp_min": 296.41,
#         "temp_max": 296.41,
#         "pressure": 1014,
#         "humidity": 48,
#         "sea_level": 1014,
#         "grnd_level": 947
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.23,
#         "deg": 224,
#         "gust": 0.5
#     },
#     "clouds": {
#         "all": 14
#     },
#     "dt": 1662871769,
#     "sys": {
#         "country": "CD",
#         "sunrise": 1662869586,
#         "sunset": 1662912832
#     },
#     "timezone": 7200,
#     "id": 217834,
#     "name": "Bukama",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 150.4667,
#         "lat": -35.35
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 291.91,
#         "feels_like": 291.17,
#         "temp_min": 291.91,
#         "temp_max": 291.91,
#         "pressure": 1011,
#         "humidity": 51,
#         "sea_level": 1011,
#         "grnd_level": 1007
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.16,
#         "deg": 61,
#         "gust": 5.84
#     },
#     "clouds": {
#         "all": 2
#     },
#     "dt": 1662871770,
#     "sys": {
#         "type": 2,
#         "id": 2004986,
#         "country": "AU",
#         "sunrise": 1662840272,
#         "sunset": 1662882345
#     },
#     "timezone": 36000,
#     "id": 2145554,
#     "name": "Ulladulla",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 20.7833,
#         "lat": -11.55
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 289.56,
#         "feels_like": 287.94,
#         "temp_min": 289.56,
#         "temp_max": 289.56,
#         "pressure": 1015,
#         "humidity": 26,
#         "sea_level": 1015,
#         "grnd_level": 889
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.41,
#         "deg": 134,
#         "gust": 2.96
#     },
#     "clouds": {
#         "all": 5
#     },
#     "dt": 1662871771,
#     "sys": {
#         "country": "AO",
#         "sunrise": 1662870847,
#         "sunset": 1662914003
#     },
#     "timezone": 3600,
#     "id": 876123,
#     "name": "Lumeje",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -74.4958,
#         "lat": 20.3467
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 300.57,
#         "feels_like": 304.72,
#         "temp_min": 300.57,
#         "temp_max": 300.57,
#         "pressure": 1017,
#         "humidity": 87,
#         "sea_level": 1017,
#         "grnd_level": 1017
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.09,
#         "deg": 61,
#         "gust": 4.84
#     },
#     "clouds": {
#         "all": 62
#     },
#     "dt": 1662871771,
#     "sys": {
#         "country": "CU",
#         "sunrise": 1662893072,
#         "sunset": 1662937501
#     },
#     "timezone": -14400,
#     "id": 3567834,
#     "name": "Baracoa",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -123.7276,
#         "lat": 48.3746
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 290.06,
#         "feels_like": 289.32,
#         "temp_min": 287.35,
#         "temp_max": 293.16,
#         "pressure": 1010,
#         "humidity": 58
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.03,
#         "deg": 140
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871772,
#     "sys": {
#         "type": 1,
#         "id": 441,
#         "country": "CA",
#         "sunrise": 1662817509,
#         "sunset": 1662863933
#     },
#     "timezone": -25200,
#     "id": 6151264,
#     "name": "Sooke",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 57.6142,
#         "lat": -19.9842
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296.19,
#         "feels_like": 296.3,
#         "temp_min": 296.19,
#         "temp_max": 296.19,
#         "pressure": 1022,
#         "humidity": 67
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.47,
#         "deg": 124,
#         "gust": 9.83
#     },
#     "clouds": {
#         "all": 3
#     },
#     "dt": 1662871774,
#     "sys": {
#         "type": 2,
#         "id": 2002134,
#         "country": "MU",
#         "sunrise": 1662862181,
#         "sunset": 1662904995
#     },
#     "timezone": 14400,
#     "id": 934649,
#     "name": "Cap Malheureux",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 122.9,
#         "lat": 54.05
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 287.94,
#         "feels_like": 286.52,
#         "temp_min": 287.94,
#         "temp_max": 287.94,
#         "pressure": 1017,
#         "humidity": 40,
#         "sea_level": 1017,
#         "grnd_level": 960
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.8,
#         "deg": 30,
#         "gust": 3.75
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871774,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662844415,
#         "sunset": 1662891432
#     },
#     "timezone": 32400,
#     "id": 2014078,
#     "name": "Urusha",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -72.7111,
#         "lat": -16.6228
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 288.37,
#         "feels_like": 288.17,
#         "temp_min": 288.37,
#         "temp_max": 288.37,
#         "pressure": 1020,
#         "humidity": 85,
#         "sea_level": 1020,
#         "grnd_level": 1018
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.97,
#         "deg": 124,
#         "gust": 4.27
#     },
#     "clouds": {
#         "all": 84
#     },
#     "dt": 1662871478,
#     "sys": {
#         "country": "PE",
#         "sunrise": 1662807022,
#         "sunset": 1662849938
#     },
#     "timezone": -18000,
#     "id": 3945985,
#     "name": "Caman\u00e1",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 13.64,
#         "lat": 45.08
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 289.42,
#         "feels_like": 289.17,
#         "temp_min": 289.42,
#         "temp_max": 290.05,
#         "pressure": 1013,
#         "humidity": 79,
#         "sea_level": 1013,
#         "grnd_level": 1012
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.34,
#         "deg": 52,
#         "gust": 2.37
#     },
#     "clouds": {
#         "all": 37
#     },
#     "dt": 1662871775,
#     "sys": {
#         "type": 1,
#         "id": 6386,
#         "country": "HR",
#         "sunrise": 1662871146,
#         "sunset": 1662917133
#     },
#     "timezone": 7200,
#     "id": 3191518,
#     "name": "Rovinj",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -100.0502,
#         "lat": 51.1494
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 285.23,
#         "feels_like": 284.01,
#         "temp_min": 285.23,
#         "temp_max": 285.23,
#         "pressure": 1018,
#         "humidity": 58
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.12,
#         "deg": 220
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662871775,
#     "sys": {
#         "type": 1,
#         "id": 780,
#         "country": "CA",
#         "sunrise": 1662811666,
#         "sunset": 1662858413
#     },
#     "timezone": -18000,
#     "id": 5935341,
#     "name": "Dauphin",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -46.0333,
#         "lat": 60.7167
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 279.45,
#         "feels_like": 279.45,
#         "temp_min": 279.45,
#         "temp_max": 279.45,
#         "pressure": 1024,
#         "humidity": 83,
#         "sea_level": 1024,
#         "grnd_level": 1024
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.69,
#         "deg": 119,
#         "gust": 1.04
#     },
#     "clouds": {
#         "all": 99
#     },
#     "dt": 1662871775,
#     "sys": {
#         "country": "GL",
#         "sunrise": 1662884494,
#         "sunset": 1662932420
#     },
#     "timezone": -7200,
#     "id": 3420846,
#     "name": "Qaqortoq",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 45.1994,
#         "lat": 48.7119
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 285.87,
#         "feels_like": 284.35,
#         "temp_min": 285.87,
#         "temp_max": 285.87,
#         "pressure": 1025,
#         "humidity": 44,
#         "sea_level": 1025,
#         "grnd_level": 1026
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.22,
#         "deg": 83,
#         "gust": 5.51
#     },
#     "clouds": {
#         "all": 2
#     },
#     "dt": 1662871776,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662863393,
#         "sunset": 1662909740
#     },
#     "timezone": 10800,
#     "id": 536156,
#     "name": "Leninsk",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 77.4,
#         "lat": 16.8667
#     },
#     "weather": [
#         {
#             "id": 502,
#             "main": "Rain",
#             "description": "heavy intensity rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 295.59,
#         "feels_like": 296.29,
#         "temp_min": 295.59,
#         "temp_max": 295.59,
#         "pressure": 1006,
#         "humidity": 92,
#         "sea_level": 1006,
#         "grnd_level": 940
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.6,
#         "deg": 261,
#         "gust": 9.15
#     },
#     "rain": {
#         "1h": 15.38
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871777,
#     "sys": {
#         "country": "IN",
#         "sunrise": 1662856692,
#         "sunset": 1662900990
#     },
#     "timezone": 19800,
#     "id": 1270627,
#     "name": "Gurmatk\u0101l",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 37.4667,
#         "lat": 12.6
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 289.95,
#         "feels_like": 289.59,
#         "temp_min": 289.95,
#         "temp_max": 289.95,
#         "pressure": 1015,
#         "humidity": 73,
#         "sea_level": 1015,
#         "grnd_level": 789
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.83,
#         "deg": 46,
#         "gust": 1.07
#     },
#     "clouds": {
#         "all": 95
#     },
#     "dt": 1662871552,
#     "sys": {
#         "country": "ET",
#         "sunrise": 1662866369,
#         "sunset": 1662910475
#     },
#     "timezone": 10800,
#     "id": 336014,
#     "name": "Gonder",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -13.5477,
#         "lat": 28.963
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296.14,
#         "feels_like": 296.53,
#         "temp_min": 296.14,
#         "temp_max": 296.14,
#         "pressure": 1015,
#         "humidity": 78
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.63,
#         "deg": 20
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662871778,
#     "sys": {
#         "type": 1,
#         "id": 2379,
#         "country": "ES",
#         "sunrise": 1662878226,
#         "sunset": 1662923099
#     },
#     "timezone": 3600,
#     "id": 2521570,
#     "name": "Arrecife",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 130.9889,
#         "lat": -25.2406
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296.88,
#         "feels_like": 296.25,
#         "temp_min": 296.88,
#         "temp_max": 296.88,
#         "pressure": 1011,
#         "humidity": 36,
#         "sea_level": 1011,
#         "grnd_level": 954
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.34,
#         "deg": 209,
#         "gust": 2.75
#     },
#     "clouds": {
#         "all": 3
#     },
#     "dt": 1662871779,
#     "sys": {
#         "country": "AU",
#         "sunrise": 1662844696,
#         "sunset": 1662887268
#     },
#     "timezone": 34200,
#     "id": 6355222,
#     "name": "Yulara",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -65.8993,
#         "lat": 18.0072
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 298.5,
#         "feels_like": 299.49,
#         "temp_min": 297.53,
#         "temp_max": 300.21,
#         "pressure": 1016,
#         "humidity": 92,
#         "sea_level": 1016,
#         "grnd_level": 1014
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.07,
#         "deg": 77,
#         "gust": 4.22
#     },
#     "clouds": {
#         "all": 94
#     },
#     "dt": 1662871780,
#     "sys": {
#         "type": 2,
#         "id": 2034588,
#         "country": "PR",
#         "sunrise": 1662891061,
#         "sunset": 1662935387
#     },
#     "timezone": -14400,
#     "id": 4566208,
#     "name": "Maunabo",
#     "cod": 200
# }

# %%
print(requests.get(complete_url))
# Out:
# <Response [200]>

# %%
# setting up empty lists to hold retrieved data
city_name = []
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# processing record starting from 1
processing_record = 1

# starting statement just to match the outputs given
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Looping through the cities for data retrieval
# complete url address
for city in cities:
    complete_url = base_url + "appid=" + api_key + "&q=" + city
    
# return response object using get method and json method
    response = requests.get(complete_url).json()

# try and except method
    try:
        
        city_name.append(response["name"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        city_record = response["name"]
        print(f"Processing Record {processing_record} | {city_record}")
        
        # for next iteration
        processing_record += 1
        
    except:
        print("City not found. Skipping...") 
    
    # Print Ending Log Statement
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Hilo
# Processing Record 2 | Pershotravneve
# Processing Record 3 | Marzuq
# Processing Record 4 | Gawler
# City not found. Skipping...
# Processing Record 5 | Castro
# Processing Record 6 | Arraial do Cabo
# Processing Record 7 | Cape Town
# Processing Record 8 | Mocuba
# Processing Record 9 | Jieshi
# Processing Record 10 | Beyneu
# Processing Record 11 | Qaanaaq
# Processing Record 12 | Province of Mantua
# Processing Record 13 | Mataura
# Processing Record 14 | Punta Arenas
# Processing Record 15 | Paamiut
# Processing Record 16 | Harper
# Processing Record 17 | Talnakh
# Processing Record 18 | Bahçe
# Processing Record 19 | Port Alfred
# Processing Record 20 | Homer
# Processing Record 21 | Ushuaia
# Processing Record 22 | Busselton
# Processing Record 23 | Tevriz
# Processing Record 24 | Mehamn
# City not found. Skipping...
# Processing Record 25 | Aras
# Processing Record 26 | Ilula
# Processing Record 27 | Kapaa
# Processing Record 28 | Yellowknife
# Processing Record 29 | Tasiilaq
# Processing Record 30 | Rikitea
# Processing Record 31 | Boguchany
# Processing Record 32 | Sawākin
# Processing Record 33 | Khovd
# Processing Record 34 | Carndonagh
# Processing Record 35 | Port Elizabeth
# Processing Record 36 | Bredasdorp
# Processing Record 37 | Atambua
# Processing Record 38 | Mahébourg
# Processing Record 39 | Provideniya
# Processing Record 40 | George Town
# Processing Record 41 | Krasnovishersk
# Processing Record 42 | Bluff
# Processing Record 43 | Wana
# Processing Record 44 | Messaria
# Processing Record 45 | Yenagoa
# Processing Record 46 | Atuona
# Processing Record 47 | Alofi
# Processing Record 48 | Pandan
# Processing Record 49 | Kudat
# Processing Record 50 | Hermanus
# Processing Record 51 | Broome
# Processing Record 52 | Wakkanai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 53 | Charlestown
# Processing Record 54 | Pangnirtung
# Processing Record 55 | Aklavik
# City not found. Skipping...
# Processing Record 56 | Saint-Philippe
# Processing Record 57 | Shenjiamen
# Processing Record 58 | Quatre Cocos
# Processing Record 59 | Anna
# City not found. Skipping...
# Processing Record 60 | Manokwari
# City not found. Skipping...
# Processing Record 61 | Jamestown
# Processing Record 62 | Ozernovskiy
# Processing Record 63 | Palmer
# Processing Record 64 | Tiksi
# Processing Record 65 | Hobart
# Processing Record 66 | Alice Springs
# Processing Record 67 | Shingū
# Processing Record 68 | Ondjiva
# Processing Record 69 | Bentiu
# Processing Record 70 | Workington
# Processing Record 71 | Husavik
# Processing Record 72 | Tilichiki
# Processing Record 73 | Albany
# Processing Record 74 | Airai
# Processing Record 75 | Srednekolymsk
# Processing Record 76 | New Norfolk
# Processing Record 77 | Taseyevo
# Processing Record 78 | Berdigestyakh
# Processing Record 79 | Hay River
# Processing Record 80 | Torbay
# Processing Record 81 | Guerrero Negro
# Processing Record 82 | Avarua
# Processing Record 83 | Chui
# Processing Record 84 | Hasaki
# Processing Record 85 | Ribeira Grande
# Processing Record 86 | Acapulco de Juárez
# Processing Record 87 | Xining
# Processing Record 88 | Pindwāra
# Processing Record 89 | Puerto Ayora
# Processing Record 90 | Champerico
# City not found. Skipping...
# Processing Record 91 | Pisco
# Processing Record 92 | Navrongo
# Processing Record 93 | Bayan
# Processing Record 94 | Half Moon Bay
# Processing Record 95 | Alexandria
# Processing Record 96 | Salinópolis
# Processing Record 97 | Fairfield
# Processing Record 98 | Nikolskoye
# Processing Record 99 | Adrar
# Processing Record 100 | Maïné Soroa
# Processing Record 101 | San Lorenzo
# Processing Record 102 | Lippstadt
# Processing Record 103 | Saint Paul Harbor
# Processing Record 104 | Mar del Plata
# Processing Record 105 | Rocky Mountain House
# Processing Record 106 | Jagalūr
# Processing Record 107 | Nelson Bay
# Processing Record 108 | Cairns
# Processing Record 109 | Sistranda
# City not found. Skipping...
# Processing Record 110 | Talaya
# Processing Record 111 | Vao
# Processing Record 112 | Sørland
# Processing Record 113 | Dhadar
# Processing Record 114 | Wewak
# Processing Record 115 | Lebu
# Processing Record 116 | Whitehorse
# Processing Record 117 | Poum
# Processing Record 118 | Strelka
# Processing Record 119 | Vaini
# Processing Record 120 | Baza
# Processing Record 121 | Mandalgovi
# Processing Record 122 | Bambous Virieux
# Processing Record 123 | Saskylakh
# Processing Record 124 | Ilebo
# Processing Record 125 | Altamira
# Processing Record 126 | Coyhaique
# Processing Record 127 | Port-Cartier
# Processing Record 128 | Santa Maria
# City not found. Skipping...
# Processing Record 129 | Miracema do Tocantins
# Processing Record 130 | Ostrovnoy
# Processing Record 131 | Cayenne
# Processing Record 132 | Obo
# Processing Record 133 | Polovinnoye
# Processing Record 134 | Kudahuvadhoo
# Processing Record 135 | Palencia
# Processing Record 136 | Barrow
# City not found. Skipping...
# Processing Record 137 | East London
# Processing Record 138 | Kavaratti
# Processing Record 139 | Butaritari
# Processing Record 140 | Jumla
# Processing Record 141 | Letka
# Processing Record 142 | Yarmouth
# Processing Record 143 | Hualmay
# Processing Record 144 | Ust-Nera
# Processing Record 145 | Ponnāni
# Processing Record 146 | Russell
# Processing Record 147 | Yangi Marg`ilon
# Processing Record 148 | Lima
# Processing Record 149 | Kologriv
# Processing Record 150 | Chokurdakh
# Processing Record 151 | Longyearbyen
# Processing Record 152 | Haines Junction
# Processing Record 153 | Chardara
# Processing Record 154 | Flin Flon
# Processing Record 155 | Pevek
# Processing Record 156 | Banda Aceh
# Processing Record 157 | Tura
# Processing Record 158 | Thinadhoo
# Processing Record 159 | Nānākuli
# Processing Record 160 | Hoquiam
# City not found. Skipping...
# Processing Record 161 | Olafsvik
# Processing Record 162 | Sabzawār
# Processing Record 163 | Grivenskaya
# Processing Record 164 | Hithadhoo
# Processing Record 165 | Roald
# Processing Record 166 | Sitka
# Processing Record 167 | Esperance
# Processing Record 168 | Bumba
# Processing Record 169 | Solnechnyy
# Processing Record 170 | Mount Gambier
# Processing Record 171 | La Ronge
# Processing Record 172 | Upernavik
# Processing Record 173 | Juneau
# Processing Record 174 | Santa Barbara
# Processing Record 175 | Santa Rosalía
# Processing Record 176 | Turukhansk
# Processing Record 177 | Voh
# City not found. Skipping...
# Processing Record 178 | Nha Trang
# Processing Record 179 | Souillac
# Processing Record 180 | Thompson
# Processing Record 181 | Alekseyevka
# Processing Record 182 | Biu
# Processing Record 183 | Cherskiy
# City not found. Skipping...
# Processing Record 184 | Nome
# Processing Record 185 | Santa Rosa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 186 | Fairbanks
# Processing Record 187 | Klaksvík
# Processing Record 188 | Dulce Nombre de Culmí
# Processing Record 189 | Kamenka
# Processing Record 190 | Vila Velha
# Processing Record 191 | Vila Franca do Campo
# Processing Record 192 | Ponta do Sol
# Processing Record 193 | Bojnourd
# Processing Record 194 | Fortuna
# Processing Record 195 | Annau
# Processing Record 196 | Hong Kong
# Processing Record 197 | Maniitsoq
# City not found. Skipping...
# Processing Record 198 | Quatis
# Processing Record 199 | Saint George
# City not found. Skipping...
# Processing Record 200 | Perkáta
# Processing Record 201 | Asău
# Processing Record 202 | Verkhnyaya Inta
# City not found. Skipping...
# Processing Record 203 | Mossamedes
# Processing Record 204 | Skrunda
# Processing Record 205 | Lagunas
# Processing Record 206 | Birjand
# Processing Record 207 | Bethel
# Processing Record 208 | Zhangaözen
# Processing Record 209 | Shache
# Processing Record 210 | Venezuela
# Processing Record 211 | Henties Bay
# Processing Record 212 | Tautira
# Processing Record 213 | Mandera
# Processing Record 214 | Edd
# Processing Record 215 | Bambanglipuro
# Processing Record 216 | Freeport
# Processing Record 217 | Ellisras
# Processing Record 218 | Oborniki
# Processing Record 219 | Turbat
# City not found. Skipping...
# Processing Record 220 | Gamba
# Processing Record 221 | San Julián
# Processing Record 222 | Bubaque
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 223 | Ahipara
# Processing Record 224 | Amiens
# Processing Record 225 | Aban
# Processing Record 226 | Ojinaga
# City not found. Skipping...
# Processing Record 227 | Touros
# Processing Record 228 | Kenai
# Processing Record 229 | Östersund
# Processing Record 230 | Bengkulu
# Processing Record 231 | Narsaq
# Processing Record 232 | Lagoa
# Processing Record 233 | Hamilton
# Processing Record 234 | Ürümqi
# Processing Record 235 | Balkanabat
# City not found. Skipping...
# Processing Record 236 | Pacific Grove
# Processing Record 237 | Lüderitz
# Processing Record 238 | Seoul
# City not found. Skipping...
# Processing Record 239 | Capinota
# Processing Record 240 | Sinnamary
# Processing Record 241 | Nanortalik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 242 | Dalnerechensk
# Processing Record 243 | Dikson
# City not found. Skipping...
# Processing Record 244 | Pilar
# Processing Record 245 | Palāsa
# Processing Record 246 | Cabedelo
# Processing Record 247 | La Palma
# Processing Record 248 | Dwārka
# Processing Record 249 | Saint-Augustin
# Processing Record 250 | Nantucket
# Processing Record 251 | Gävle
# Processing Record 252 | Pacora
# Processing Record 253 | Ballarat
# Processing Record 254 | Dhidhdhoo
# Processing Record 255 | Grants
# Processing Record 256 | Clyde River
# Processing Record 257 | Cocal
# City not found. Skipping...
# Processing Record 258 | Alamogordo
# Processing Record 259 | Yangambi
# Processing Record 260 | Ballina
# Processing Record 261 | Korla
# City not found. Skipping...
# Processing Record 262 | Farmington
# Processing Record 263 | Charter Township of Clinton
# Processing Record 264 | Lata
# Processing Record 265 | Kizilskoye
# Processing Record 266 | Saint-Pierre
# Processing Record 267 | Honningsvåg
# Processing Record 268 | Yumen
# Processing Record 269 | Santa Isabel Rio Negro
# Processing Record 270 | Santa Teresa del Tuy
# Processing Record 271 | Kirksville
# City not found. Skipping...
# Processing Record 272 | Opunake
# Processing Record 273 | Leshukonskoye
# Processing Record 274 | Keuruu
# Processing Record 275 | Skoghall
# Processing Record 276 | Port Hardy
# Processing Record 277 | Berlevåg
# Processing Record 278 | Leningradskiy
# City not found. Skipping...
# Processing Record 279 | Deputatsky
# Processing Record 280 | Spirit River
# City not found. Skipping...
# Processing Record 281 | Los Llanos de Aridane
# Processing Record 282 | Baringo
# City not found. Skipping...
# Processing Record 283 | Cabo San Lucas
# Processing Record 284 | Puerto Limón
# Processing Record 285 | Haapiti
# Processing Record 286 | Baykit
# Processing Record 287 | Kommunisticheskiy
# Processing Record 288 | Bilma
# Processing Record 289 | Yabēlo
# Processing Record 290 | Sidi Ali
# Processing Record 291 | High Level
# Processing Record 292 | Norwich
# Processing Record 293 | Ritchie
# Processing Record 294 | Polis
# Processing Record 295 | Paita
# Processing Record 296 | Semey
# Processing Record 297 | Libreville
# Processing Record 298 | Alice Town
# Processing Record 299 | Kärdla
# Processing Record 300 | Broken Hill
# Processing Record 301 | Vryburg
# Processing Record 302 | Nara
# Processing Record 303 | Carnarvon
# Processing Record 304 | Pascagoula
# Processing Record 305 | Soria
# Processing Record 306 | Yar-Sale
# Processing Record 307 | Hofn
# Processing Record 308 | Lucapa
# Processing Record 309 | Nishihara
# Processing Record 310 | Arlit
# Processing Record 311 | Jasper
# Processing Record 312 | Namatanai
# Processing Record 313 | Mitchell
# Processing Record 314 | Anloga
# Processing Record 315 | Hongjiang
# Processing Record 316 | Bathsheba
# Processing Record 317 | Ţahţā
# Processing Record 318 | Rocha
# Processing Record 319 | Caxito
# Processing Record 320 | Plastun
# Processing Record 321 | Aparecida do Taboado
# Processing Record 322 | Avera
# Processing Record 323 | Oriximiná
# Processing Record 324 | Ayan
# Processing Record 325 | Tuktoyaktuk
# Processing Record 326 | Buncrana
# Processing Record 327 | Tiznit Province
# Processing Record 328 | Lázaro Cárdenas
# Processing Record 329 | Kyabé
# Processing Record 330 | Chanute
# Processing Record 331 | Jūrmala
# Processing Record 332 | Lashio
# Processing Record 333 | Edmundston
# Processing Record 334 | Guaíba
# Processing Record 335 | Oktyabr'skoye
# Processing Record 336 | Prieska
# Processing Record 337 | Toora-Khem
# Processing Record 338 | Kabelvåg
# Processing Record 339 | Dodge City
# Processing Record 340 | Butajīra
# Processing Record 341 | Belle Fourche
# Processing Record 342 | Álamos
# Processing Record 343 | Te Anau
# Processing Record 344 | Vanimo
# Processing Record 345 | Abu Kamal
# Processing Record 346 | San Rafael del Sur
# City not found. Skipping...
# Processing Record 347 | Valparaíso
# Processing Record 348 | Viedma
# Processing Record 349 | San Patricio
# Processing Record 350 | São Benedito do Rio Preto
# City not found. Skipping...
# Processing Record 351 | Diré
# Processing Record 352 | Basco
# Processing Record 353 | Port Macquarie
# Processing Record 354 | Geraldton
# Processing Record 355 | Martapura
# Processing Record 356 | Nicoya
# Processing Record 357 | Tymovskoye
# Processing Record 358 | Cocorit
# Processing Record 359 | Katsuura
# Processing Record 360 | Kiryat Gat
# Processing Record 361 | Saint-François
# Processing Record 362 | Abalak
# Processing Record 363 | Yarke Pole
# Processing Record 364 | Faanui
# Processing Record 365 | Itarema
# Processing Record 366 | Grand Gaube
# Processing Record 367 | Byron Bay
# Processing Record 368 | Kotelnikowo
# Processing Record 369 | Weymouth
# Processing Record 370 | Antibes
# Processing Record 371 | Christchurch
# Processing Record 372 | Kutum
# Processing Record 373 | Bereket
# Processing Record 374 | Esim
# Processing Record 375 | Barcelona
# Processing Record 376 | Meulaboh
# Processing Record 377 | Prince Rupert
# Processing Record 378 | Udachny
# Processing Record 379 | Camacha
# Processing Record 380 | Acarí
# Processing Record 381 | Lunino
# Processing Record 382 | Oranjemund
# Processing Record 383 | Gillette
# Processing Record 384 | Qasigiannguit
# Processing Record 385 | Oistins
# City not found. Skipping...
# Processing Record 386 | Zlobin
# Processing Record 387 | Kuala Terengganu
# Processing Record 388 | Hambantota
# Processing Record 389 | Prome
# Processing Record 390 | Kumul
# Processing Record 391 | Rawson
# Processing Record 392 | Bāfq
# Processing Record 393 | Tongren
# Processing Record 394 | Muzhi
# Processing Record 395 | Nowa Dęba
# City not found. Skipping...
# Processing Record 396 | Peniche
# Processing Record 397 | Damaturu
# Processing Record 398 | Yerbogachën
# Processing Record 399 | Gidrotorf
# Processing Record 400 | Dentsville
# Processing Record 401 | Coahuayana Viejo
# Processing Record 402 | Victor Harbor
# Processing Record 403 | Huilong
# Processing Record 404 | La Foa
# City not found. Skipping...
# Processing Record 405 | San Andrés
# Processing Record 406 | Muros
# Processing Record 407 | Taiping
# Processing Record 408 | Port Blair
# Processing Record 409 | Quelimane
# Processing Record 410 | Isangel
# Processing Record 411 | Nālūt
# Processing Record 412 | Manakara
# Processing Record 413 | Lüshunkou
# Processing Record 414 | Hearst
# Processing Record 415 | Comodoro Rivadavia
# City not found. Skipping...
# Processing Record 416 | Nouadhibou
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 417 | Rohnert Park
# Processing Record 418 | Kruisfontein
# Processing Record 419 | Kalmunai
# Processing Record 420 | Norman Wells
# Processing Record 421 | Nizhneangarsk
# Processing Record 422 | Chifeng
# Processing Record 423 | Yamada
# Processing Record 424 | Fukuechō
# Processing Record 425 | Hobyo
# Processing Record 426 | Severo-Kuril'sk
# Processing Record 427 | Abonnema
# Processing Record 428 | Korem
# Processing Record 429 | Lokosovo
# Processing Record 430 | Port-Gentil
# Processing Record 431 | Laguna
# Processing Record 432 | Ixtapa
# Processing Record 433 | Ketchikan
# Processing Record 434 | Dhārchula
# Processing Record 435 | Tuatapere
# Processing Record 436 | Wanning
# Processing Record 437 | Laiyang
# City not found. Skipping...
# Processing Record 438 | Vangaindrano
# Processing Record 439 | Baruun-Urt
# City not found. Skipping...
# Processing Record 440 | Kirakira
# Processing Record 441 | Itapema
# Processing Record 442 | Launceston
# Processing Record 443 | Buala
# Processing Record 444 | Codrington
# Processing Record 445 | Ranong
# Processing Record 446 | Harlingen
# Processing Record 447 | Kamina
# Processing Record 448 | Grindavik
# Processing Record 449 | Barra de Tecoanapa
# Processing Record 450 | Sandpoint
# Processing Record 451 | Kolosovka
# Processing Record 452 | Riyadh
# Processing Record 453 | St. George's
# Processing Record 454 | Tailai
# Processing Record 455 | ‘Ewa Beach
# Processing Record 456 | Nosy Varika
# Processing Record 457 | Caravelas
# Processing Record 458 | Kaduy
# Processing Record 459 | Guangyuan
# Processing Record 460 | Doha
# Processing Record 461 | Santa Isabel
# Processing Record 462 | Karratha
# Processing Record 463 | Lorengau
# Processing Record 464 | Belmonte
# Processing Record 465 | Barkhan
# City not found. Skipping...
# Processing Record 466 | Lewistown
# Processing Record 467 | Sibu
# Processing Record 468 | Vila
# Processing Record 469 | Iqaluit
# Processing Record 470 | Gizo Government Station
# Processing Record 471 | Itatiaia
# Processing Record 472 | Kahului
# Processing Record 473 | Springbok
# Processing Record 474 | Mae Hong Son
# Processing Record 475 | Nassau
# Processing Record 476 | Praia da Vitória
# Processing Record 477 | Kavieng
# Processing Record 478 | Nísia Floresta
# Processing Record 479 | Mandiana
# Processing Record 480 | Erdenet
# Processing Record 481 | Khatanga
# Processing Record 482 | Balabac
# Processing Record 483 | Shirokiy
# Processing Record 484 | Carutapera
# Processing Record 485 | Tvøroyri
# Processing Record 486 | Boa Vista
# Processing Record 487 | Dingle
# Processing Record 488 | Salalah
# Processing Record 489 | Shelburne
# Processing Record 490 | Lampang
# Processing Record 491 | Berbera
# Processing Record 492 | Verkhnevilyuysk
# Processing Record 493 | Podstepki
# Processing Record 494 | West Odessa
# Processing Record 495 | Sovetskaya Gavan'
# Processing Record 496 | Ilulissat
# Processing Record 497 | São Filipe
# Processing Record 498 | Taber
# Processing Record 499 | Mundo Nuevo (Ojo de Agua)
# Processing Record 500 | Vila do Maio
# Processing Record 501 | Władysławowo
# Processing Record 502 | Ascension
# Processing Record 503 | Turtas
# Processing Record 504 | Awjilah
# Processing Record 505 | Singleton
# City not found. Skipping...
# Processing Record 506 | Waipawa
# Processing Record 507 | Kaitangata
# Processing Record 508 | Khandagayty
# Processing Record 509 | Kayes
# City not found. Skipping...
# Processing Record 510 | Xixiang
# Processing Record 511 | Bandarbeyla
# Processing Record 512 | Bahía Solano
# Processing Record 513 | Bago
# Processing Record 514 | Kigoma
# Processing Record 515 | At-Bashi
# Processing Record 516 | Beira
# Processing Record 517 | Puerto Madryn
# Processing Record 518 | Huntington
# Processing Record 519 | Wad Medani
# Processing Record 520 | Porto Walter
# Processing Record 521 | Bauchi
# Processing Record 522 | Macusani
# Processing Record 523 | Bougouni
# Processing Record 524 | Dehlorān
# Processing Record 525 | Nsoko
# Processing Record 526 | Stoeneşti
# Processing Record 527 | Gladstone
# Processing Record 528 | Saint-Leu
# Processing Record 529 | Shimoda
# Processing Record 530 | Pattaya
# Processing Record 531 | Skjervøy
# Processing Record 532 | Hostotipaquillo
# Processing Record 533 | Gornyy
# Processing Record 534 | Mildura
# Processing Record 535 | Mayo
# Processing Record 536 | Toribío
# Processing Record 537 | Saint-Joseph
# Processing Record 538 | Stepnyak
# Processing Record 539 | Cidreira
# Processing Record 540 | Ryōtsu-minato
# Processing Record 541 | Chul'man
# Processing Record 542 | Phalaborwa
# Processing Record 543 | Sibolga
# Processing Record 544 | Mēga
# Processing Record 545 | Grand-Santi
# Processing Record 546 | Flinders
# Processing Record 547 | Palm Beach
# City not found. Skipping...
# Processing Record 548 | Pringsewu
# Processing Record 549 | Ayna
# Processing Record 550 | Orchard Homes
# Processing Record 551 | College
# Processing Record 552 | Hūn
# Processing Record 553 | Robertsport
# Processing Record 554 | Camaçari
# Processing Record 555 | Lavrentiya
# Processing Record 556 | Quesnel
# Processing Record 557 | Pacifica
# Processing Record 558 | Altay
# Processing Record 559 | Preobrazheniye
# Processing Record 560 | Evensk
# Processing Record 561 | Hanzhong
# Processing Record 562 | La Rioja
# Processing Record 563 | Ouadda
# Processing Record 564 | Naryan-Mar
# Processing Record 565 | Ankang
# Processing Record 566 | Vestmannaeyjar
# Processing Record 567 | Phuntsholing
# Processing Record 568 | Rio Grande
# Processing Record 569 | Boyolangu
# Processing Record 570 | Catacaos
# City not found. Skipping...
# Processing Record 571 | Nyuksenitsa
# Processing Record 572 | San Felipe
# Processing Record 573 | Constitución
# Processing Record 574 | Noumea
# Processing Record 575 | Sisa
# Processing Record 576 | Gönc
# Processing Record 577 | Daru
# Processing Record 578 | Kaputa
# City not found. Skipping...
# Processing Record 579 | Emba
# Processing Record 580 | Bukama
# Processing Record 581 | Ulladulla
# Processing Record 582 | Lumeje
# Processing Record 583 | Baracoa
# Processing Record 584 | Sooke
# Processing Record 585 | Cap Malheureux
# Processing Record 586 | Urusha
# Processing Record 587 | Camaná
# Processing Record 588 | Rovinj
# Processing Record 589 | Dauphin
# Processing Record 590 | Qaqortoq
# Processing Record 591 | Leninsk
# Processing Record 592 | Gurmatkāl
# Processing Record 593 | Gonder
# Processing Record 594 | Arrecife
# Processing Record 595 | Yulara
# Processing Record 596 | Maunabo
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Display the DataFrame
weather_data_dict = {
    "City": city_name,
    "Lat": latitude,
    "Lng": longitude,
    "Max Temp": max_temperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
    
}

weather_data_df = pd.DataFrame(weather_data_dict)
weather_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hilo  19.7297 -155.0900    300.00        80          40
# 1  Pershotravneve  51.3929   28.8684    284.33        93          99
# 2          Marzuq  14.4000   46.4667    301.87        35          93
# 3          Gawler -34.6000  138.7333    288.98        61          65
# 4          Castro -24.7911  -50.0119    287.03        98         100
#
#    Wind Speed Country        Date
# 0        2.06      US  1662871518
# 1        3.37      UA  1662871518
# 2        1.35      YE  1662871518
# 3        4.19      AU  1662871429
# 4        2.78      BR  1662871451

# %%
#Export the city data into a .csv.
weather_data_df.to_csv("../WeatherPy/weather_data.csv")

# %%
# using sort method to check if there are any humidity outliers
city_humidity=weather_data_df.sort_values("Humidity",ascending=False)
city_humidity
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 69       Workington  54.6425  -3.5441    288.05       100          89
# 360  Saint-François  46.4154   3.9054    280.84       100          12
# 228       Östersund  63.1792  14.6357    279.40       100          34
# 255     Clyde River  70.4692 -68.5914    276.28       100         100
# 16          Talnakh  69.4865  88.3972    277.71        99         100
# ..              ...      ...      ...       ...       ...         ...
# 260           Korla  41.7597  86.1469    304.89        14           1
# 389           Kumul  42.8000  93.4500    306.32        13           0
# 208          Shache  38.4167  77.2406    303.88        10         100
# 523        Dehlorān  32.6941  47.2679    309.37         9           0
# 267           Yumen  40.2833  97.2000    303.66         7           0
#
#      Wind Speed Country        Date
# 69         2.47      GB  1662871549
# 360        0.00      FR  1662871677
# 228        3.58      SE  1662871623
# 255        1.03      CA  1662871634
# 16         3.66      RU  1662871526
# ..          ...     ...         ...
# 260        5.82      CN  1662871430
# 389        1.67      CN  1662871433
# 208        3.98      CN  1662871613
# 523        3.61      IR  1662871743
# 267        7.33      CN  1662871640
#
# [596 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          kapaa  22.0752 -159.3190     26.99        77          40
# 1         barrow  71.2906 -156.7887     -5.99        86         100
# 2      busselton -33.6500  115.3333     13.33        68          84
# 3  mar del plata -38.0023  -57.5575     16.08        59           0
# 4          vaini -21.2000 -175.2000     23.09        88          20
#
#    Wind Speed Country        Date
# 0        6.17      US  1651608887
# 1        5.14      US  1651608707
# 2        4.85      AU  1651608889
# 3        6.17      AR  1651608890
# 4        2.57      TO  1651608890

# %% [markdown]
# ## Plotting the Data
# * Use proper labelling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# scatter plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Max Temp"], facecolors="blue", marker="o", edgecolor="black")

# axis title and labels
plt.title("Latitude vs. Temperature (11/09/2022)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# saving figure
plt.savefig("../WeatherPy/Latitude vs. Temperature.png")

# showing plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# scatter plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Humidity"], facecolors="blue", marker="o", edgecolor="black")

# axis title and labels
plt.title("City Latitude vs. Humidity (11/09/2022)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# saving figure
plt.savefig("../WeatherPy/City Latitude vs. Humidity.png")

# showing plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# scatter plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Cloudiness"], facecolors="blue", marker="o", edgecolor="black")

# axis title and labels
plt.title("City Latitude vs. Cloudiness (11/09/2022)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# saving figure
plt.savefig("../WeatherPy/City Latitude vs. Cloudiness.png")

# showing plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# scatter plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Wind Speed"], facecolors="blue", marker="o", edgecolor="black")

# axis title and labels
plt.title("City Latitude vs. Wind Speed (11/09/2022)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# saving figure
plt.savefig("../WeatherPy/City Latitude vs. Wind Speed.png")

# showing plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_data_df.loc[weather_data_df["Lat"] >= 0]
southern_df = weather_data_df.loc[weather_data_df["Lat"] < 0]

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = northern_df['Lat']
y_values = northern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,275),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.6374550058726091

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = southern_df['Lat']
y_values = southern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,280),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.46503545783901135

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = northern_df['Lat']
y_values = northern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=13,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.002575066574442668

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = southern_df['Lat']
y_values = southern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,42),fontsize=13,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.025012381817018526

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = northern_df['Lat']
y_values = northern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,24),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 3.1634921801511006e-05

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = southern_df['Lat']
y_values = southern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,65),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.014178221188639166

# %% [markdown]
# ### Wind Speed (m/s) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = northern_df['Lat']
y_values = northern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,14),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.00392560024321335

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = southern_df['Lat']
y_values = southern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.022743154167527358

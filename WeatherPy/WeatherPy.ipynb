# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Enter your API key here
api_key = weather_api_key
 
# base_url variable to store url
base_url = "http://api.openweathermap.org/data/2.5/weather?"
 
# complete url address
for city in cities:
    complete_url = base_url + "appid=" + api_key + "&q=" + city
    
# return response object using get method and json method
    response = requests.get(complete_url).json()
    
    print(json.dumps(response, indent=4))
# Out:
# {
#     "coord": {
#         "lon": 19.2345,
#         "lat": -34.4187
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 287,
#         "feels_like": 286.19,
#         "temp_min": 287,
#         "temp_max": 287,
#         "pressure": 1024,
#         "humidity": 67,
#         "sea_level": 1024,
#         "grnd_level": 1021
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.36,
#         "deg": 227,
#         "gust": 5.96
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890133,
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1662871713,
#         "sunset": 1662913881
#     },
#     "timezone": 7200,
#     "id": 3366880,
#     "name": "Hermanus",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -44.8683,
#         "lat": -1.8283
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 298.22,
#         "feels_like": 299.03,
#         "temp_min": 298.22,
#         "temp_max": 298.22,
#         "pressure": 1013,
#         "humidity": 86,
#         "sea_level": 1013,
#         "grnd_level": 1012
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.65,
#         "deg": 67,
#         "gust": 5.96
#     },
#     "clouds": {
#         "all": 10
#     },
#     "dt": 1662890134,
#     "sys": {
#         "country": "BR",
#         "sunrise": 1662886412,
#         "sunset": 1662929943
#     },
#     "timezone": -10800,
#     "id": 3401148,
#     "name": "Cururupu",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -4.1005,
#         "lat": 36.7726
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 301.89,
#         "feels_like": 302.05,
#         "temp_min": 298.99,
#         "temp_max": 305.36,
#         "pressure": 1016,
#         "humidity": 46
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.15,
#         "deg": 145,
#         "gust": 3.19
#     },
#     "clouds": {
#         "all": 80
#     },
#     "dt": 1662890134,
#     "sys": {
#         "type": 2,
#         "id": 2037939,
#         "country": "ES",
#         "sunrise": 1662875723,
#         "sunset": 1662921069
#     },
#     "timezone": 7200,
#     "id": 2509769,
#     "name": "V\u00e9lez-M\u00e1laga",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 42.4509,
#         "lat": 18.3851
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 301.44,
#         "feels_like": 300.09,
#         "temp_min": 301.44,
#         "temp_max": 302.21,
#         "pressure": 1009,
#         "humidity": 20,
#         "sea_level": 1009,
#         "grnd_level": 791
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.39,
#         "deg": 42,
#         "gust": 6.7
#     },
#     "clouds": {
#         "all": 51
#     },
#     "dt": 1662890135,
#     "sys": {
#         "type": 1,
#         "id": 7396,
#         "country": "SA",
#         "sunrise": 1662865046,
#         "sunset": 1662909407
#     },
#     "timezone": 10800,
#     "id": 110690,
#     "name": "Faya",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -50.0119,
#         "lat": -24.7911
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 285.6,
#         "feels_like": 285.43,
#         "temp_min": 285.6,
#         "temp_max": 285.6,
#         "pressure": 1019,
#         "humidity": 97,
#         "sea_level": 1019,
#         "grnd_level": 906
#     },
#     "visibility": 111,
#     "wind": {
#         "speed": 2.63,
#         "deg": 90,
#         "gust": 5.81
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890135,
#     "sys": {
#         "country": "BR",
#         "sunrise": 1662888094,
#         "sunset": 1662930729
#     },
#     "timezone": -10800,
#     "id": 3466704,
#     "name": "Castro",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 73.0833,
#         "lat": -0.6
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 301.06,
#         "feels_like": 303.64,
#         "temp_min": 301.06,
#         "temp_max": 301.06,
#         "pressure": 1009,
#         "humidity": 70,
#         "sea_level": 1009,
#         "grnd_level": 1008
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.34,
#         "deg": 274,
#         "gust": 6.89
#     },
#     "clouds": {
#         "all": 53
#     },
#     "dt": 1662890135,
#     "sys": {
#         "country": "MV",
#         "sunrise": 1662858088,
#         "sunset": 1662901664
#     },
#     "timezone": 18000,
#     "id": 1282256,
#     "name": "Hithadhoo",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 115.3333,
#         "lat": -33.65
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 287.04,
#         "feels_like": 286.57,
#         "temp_min": 287.04,
#         "temp_max": 287.04,
#         "pressure": 1014,
#         "humidity": 80,
#         "sea_level": 1014,
#         "grnd_level": 1014
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.86,
#         "deg": 319,
#         "gust": 1.28
#     },
#     "clouds": {
#         "all": 22
#     },
#     "dt": 1662890075,
#     "sys": {
#         "country": "AU",
#         "sunrise": 1662848652,
#         "sunset": 1662890826
#     },
#     "timezone": 28800,
#     "id": 2075265,
#     "name": "Busselton",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -17.9182,
#         "lat": 28.6585
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296,
#         "feels_like": 296.48,
#         "temp_min": 296,
#         "temp_max": 296.01,
#         "pressure": 1016,
#         "humidity": 82
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.09,
#         "deg": 180
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662890136,
#     "sys": {
#         "type": 2,
#         "id": 2002582,
#         "country": "ES",
#         "sunrise": 1662879283,
#         "sunset": 1662924139
#     },
#     "timezone": 3600,
#     "id": 2514651,
#     "name": "Los Llanos de Aridane",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 17.0633,
#         "lat": 51.3108
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 289.81,
#         "feels_like": 289.86,
#         "temp_min": 288.83,
#         "temp_max": 292.19,
#         "pressure": 1013,
#         "humidity": 89,
#         "sea_level": 1013,
#         "grnd_level": 992
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.21,
#         "deg": 308,
#         "gust": 6.69
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890136,
#     "sys": {
#         "type": 2,
#         "id": 2017463,
#         "country": "PL",
#         "sunrise": 1662870013,
#         "sunset": 1662916623
#     },
#     "timezone": 7200,
#     "id": 3083103,
#     "name": "Trzebnica",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -81.2719,
#         "lat": -4.5772
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 290.13,
#         "feels_like": 290.1,
#         "temp_min": 290.13,
#         "temp_max": 290.13,
#         "pressure": 1015,
#         "humidity": 85,
#         "sea_level": 1015,
#         "grnd_level": 1012
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.06,
#         "deg": 160,
#         "gust": 8.68
#     },
#     "clouds": {
#         "all": 62
#     },
#     "dt": 1662890134,
#     "sys": {
#         "country": "PE",
#         "sunrise": 1662895198,
#         "sunset": 1662938626
#     },
#     "timezone": -18000,
#     "id": 3691582,
#     "name": "Talara",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 168.3333,
#         "lat": -46.6
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 281.42,
#         "feels_like": 279.17,
#         "temp_min": 281.42,
#         "temp_max": 281.42,
#         "pressure": 1005,
#         "humidity": 84,
#         "sea_level": 1005,
#         "grnd_level": 1002
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.72,
#         "deg": 25,
#         "gust": 6.62
#     },
#     "clouds": {
#         "all": 48
#     },
#     "dt": 1662890137,
#     "sys": {
#         "country": "NZ",
#         "sunrise": 1662836342,
#         "sunset": 1662877702
#     },
#     "timezone": 43200,
#     "id": 2206939,
#     "name": "Bluff",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -44.4147,
#         "lat": -2.4089
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 300.26,
#         "feels_like": 303.34,
#         "temp_min": 300.26,
#         "temp_max": 300.26,
#         "pressure": 1013,
#         "humidity": 82,
#         "sea_level": 1013,
#         "grnd_level": 1010
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.89,
#         "deg": 60,
#         "gust": 6.94
#     },
#     "clouds": {
#         "all": 1
#     },
#     "dt": 1662890137,
#     "sys": {
#         "type": 1,
#         "id": 8440,
#         "country": "BR",
#         "sunrise": 1662886315,
#         "sunset": 1662929823
#     },
#     "timezone": -10800,
#     "id": 3408073,
#     "name": "Alc\u00e2ntara",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -152.4072,
#         "lat": 57.79
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 283.71,
#         "feels_like": 283.33,
#         "temp_min": 283.71,
#         "temp_max": 283.71,
#         "pressure": 1013,
#         "humidity": 96,
#         "sea_level": 1013,
#         "grnd_level": 1005
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.22,
#         "deg": 177,
#         "gust": 5.66
#     },
#     "rain": {
#         "1h": 0.2
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890138,
#     "sys": {
#         "country": "US",
#         "sunrise": 1662910311,
#         "sunset": 1662957650
#     },
#     "timezone": -28800,
#     "id": 5866583,
#     "name": "Saint Paul Harbor",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 151.25,
#         "lat": -23.85
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 292.11,
#         "feels_like": 291.71,
#         "temp_min": 290.25,
#         "temp_max": 292.11,
#         "pressure": 1017,
#         "humidity": 63
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.03,
#         "deg": 50
#     },
#     "clouds": {
#         "all": 3
#     },
#     "dt": 1662890138,
#     "sys": {
#         "type": 1,
#         "id": 9526,
#         "country": "AU",
#         "sunrise": 1662839806,
#         "sunset": 1662882436
#     },
#     "timezone": 36000,
#     "id": 2165478,
#     "name": "Gladstone",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -17.0667,
#         "lat": 32.65
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 297.46,
#         "feels_like": 298.37,
#         "temp_min": 295.44,
#         "temp_max": 298.55,
#         "pressure": 1015,
#         "humidity": 93,
#         "sea_level": 1015,
#         "grnd_level": 1015
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.36,
#         "deg": 252,
#         "gust": 4.87
#     },
#     "rain": {
#         "1h": 0.24
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890138,
#     "sys": {
#         "type": 2,
#         "id": 2009137,
#         "country": "PT",
#         "sunrise": 1662878966,
#         "sunset": 1662924048
#     },
#     "timezone": 3600,
#     "id": 2263905,
#     "name": "Ribeira Brava",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -73.414,
#         "lat": 41.3712
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 290.47,
#         "feels_like": 290.45,
#         "temp_min": 288.25,
#         "temp_max": 293.08,
#         "pressure": 1019,
#         "humidity": 84
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.91,
#         "deg": 302,
#         "gust": 1.05
#     },
#     "clouds": {
#         "all": 94
#     },
#     "dt": 1662890139,
#     "sys": {
#         "type": 2,
#         "id": 2004826,
#         "country": "US",
#         "sunrise": 1662892205,
#         "sunset": 1662937848
#     },
#     "timezone": -14400,
#     "id": 5282297,
#     "name": "Bethel",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 20.0667,
#         "lat": 32.1167
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 301.78,
#         "feels_like": 303.3,
#         "temp_min": 301.78,
#         "temp_max": 301.78,
#         "pressure": 1015,
#         "humidity": 58,
#         "sea_level": 1015,
#         "grnd_level": 1015
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.1,
#         "deg": 303,
#         "gust": 4.45
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662890139,
#     "sys": {
#         "country": "LY",
#         "sunrise": 1662870066,
#         "sunset": 1662915128
#     },
#     "timezone": 7200,
#     "id": 88319,
#     "name": "Benghazi",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -70.9167,
#         "lat": -53.15
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 276.21,
#         "feels_like": 270.9,
#         "temp_min": 275.99,
#         "temp_max": 276.21,
#         "pressure": 1004,
#         "humidity": 81
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.72,
#         "deg": 310
#     },
#     "rain": {
#         "1h": 0.1
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662890139,
#     "sys": {
#         "type": 1,
#         "id": 8487,
#         "country": "CL",
#         "sunrise": 1662893941,
#         "sunset": 1662934914
#     },
#     "timezone": -10800,
#     "id": 3874787,
#     "name": "Punta Arenas",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": -68.3,
#         "lat": -54.8
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 278.96,
#         "feels_like": 276.95,
#         "temp_min": 278.96,
#         "temp_max": 278.96,
#         "pressure": 1000,
#         "humidity": 56
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.57,
#         "deg": 0
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1662890138,
#     "sys": {
#         "type": 1,
#         "id": 8303,
#         "country": "AR",
#         "sunrise": 1662893391,
#         "sunset": 1662934208
#     },
#     "timezone": -10800,
#     "id": 3833367,
#     "name": "Ushuaia",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -121.6555,
#         "lat": 36.6777
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 293.01,
#         "feels_like": 293.17,
#         "temp_min": 291.03,
#         "temp_max": 295.77,
#         "pressure": 1014,
#         "humidity": 81,
#         "sea_level": 1014,
#         "grnd_level": 1013
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.65,
#         "deg": 335,
#         "gust": 0.76
#     },
#     "clouds": {
#         "all": 99
#     },
#     "dt": 1662890140,
#     "sys": {
#         "type": 2,
#         "id": 2006625,
#         "country": "US",
#         "sunrise": 1662903955,
#         "sunset": 1662949249
#     },
#     "timezone": -25200,
#     "id": 5391295,
#     "name": "Salinas",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -7.5406,
#         "lat": 43.2686
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 300.05,
#         "feels_like": 300.25,
#         "temp_min": 300.05,
#         "temp_max": 300.05,
#         "pressure": 1012,
#         "humidity": 46,
#         "sea_level": 1012,
#         "grnd_level": 966
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.41,
#         "deg": 186,
#         "gust": 4.24
#     },
#     "clouds": {
#         "all": 73
#     },
#     "dt": 1662890140,
#     "sys": {
#         "type": 2,
#         "id": 60947,
#         "country": "ES",
#         "sunrise": 1662876310,
#         "sunset": 1662922133
#     },
#     "timezone": 7200,
#     "id": 3105522,
#     "name": "Bereda",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -147.8028,
#         "lat": 64.8569
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 278.78,
#         "feels_like": 277.74,
#         "temp_min": 275.42,
#         "temp_max": 280.32,
#         "pressure": 1013,
#         "humidity": 87
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.56,
#         "deg": 50,
#         "gust": 1.47
#     },
#     "clouds": {
#         "all": 95
#     },
#     "dt": 1662890141,
#     "sys": {
#         "type": 2,
#         "id": 2004828,
#         "country": "US",
#         "sunrise": 1662908521,
#         "sunset": 1662957231
#     },
#     "timezone": -28800,
#     "id": 5859699,
#     "name": "College",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -68.5914,
#         "lat": 70.4692
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 275.28,
#         "feels_like": 275.28,
#         "temp_min": 275.28,
#         "temp_max": 275.28,
#         "pressure": 1000,
#         "humidity": 100
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0,
#         "deg": 0
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890141,
#     "sys": {
#         "type": 1,
#         "id": 776,
#         "country": "CA",
#         "sunrise": 1662888572,
#         "sunset": 1662939168
#     },
#     "timezone": -14400,
#     "id": 5924351,
#     "name": "Clyde River",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 15.6401,
#         "lat": 78.2186
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 273.56,
#         "feels_like": 270.35,
#         "temp_min": 273.56,
#         "temp_max": 273.56,
#         "pressure": 1011,
#         "humidity": 78,
#         "sea_level": 1011,
#         "grnd_level": 1006
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.77,
#         "deg": 247,
#         "gust": 3.34
#     },
#     "clouds": {
#         "all": 81
#     },
#     "dt": 1662890142,
#     "sys": {
#         "country": "SJ",
#         "sunrise": 1662865539,
#         "sunset": 1662921780
#     },
#     "timezone": 7200,
#     "id": 2729907,
#     "name": "Longyearbyen",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": 121.9702,
#         "lat": 20.4487
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 301.23,
#         "feels_like": 304.68,
#         "temp_min": 301.23,
#         "temp_max": 301.23,
#         "pressure": 1004,
#         "humidity": 75,
#         "sea_level": 1004,
#         "grnd_level": 1001
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 10.18,
#         "deg": 259,
#         "gust": 10.85
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890057,
#     "sys": {
#         "country": "PH",
#         "sunrise": 1662845911,
#         "sunset": 1662890382
#     },
#     "timezone": 28800,
#     "id": 1726449,
#     "name": "Basco",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -82.2665,
#         "lat": 40.8167
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 290.7,
#         "feels_like": 290.99,
#         "temp_min": 289.81,
#         "temp_max": 291.45,
#         "pressure": 1017,
#         "humidity": 95,
#         "sea_level": 1017,
#         "grnd_level": 977
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.37,
#         "deg": 147,
#         "gust": 3.94
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890142,
#     "sys": {
#         "type": 2,
#         "id": 2032410,
#         "country": "US",
#         "sunrise": 1662894352,
#         "sunset": 1662939950
#     },
#     "timezone": -14400,
#     "id": 5146062,
#     "name": "Ashland",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 108.2667,
#         "lat": -2.8833
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 301.28,
#         "feels_like": 304.5,
#         "temp_min": 301.28,
#         "temp_max": 301.28,
#         "pressure": 1007,
#         "humidity": 73,
#         "sea_level": 1007,
#         "grnd_level": 1007
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.48,
#         "deg": 110,
#         "gust": 4.07
#     },
#     "clouds": {
#         "all": 39
#     },
#     "dt": 1662890143,
#     "sys": {
#         "country": "ID",
#         "sunrise": 1662849691,
#         "sunset": 1662893178
#     },
#     "timezone": 25200,
#     "id": 1636426,
#     "name": "Manggar",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -135.33,
#         "lat": 57.0531
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 282.25,
#         "feels_like": 282.25,
#         "temp_min": 282.25,
#         "temp_max": 282.25,
#         "pressure": 1021,
#         "humidity": 91,
#         "sea_level": 1021,
#         "grnd_level": 1020
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.2,
#         "deg": 351,
#         "gust": 1.69
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662890143,
#     "sys": {
#         "country": "US",
#         "sunrise": 1662906262,
#         "sunset": 1662953504
#     },
#     "timezone": -28800,
#     "id": 5557293,
#     "name": "Sitka",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 147.3294,
#         "lat": -42.8794
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 281.22,
#         "feels_like": 277.25,
#         "temp_min": 277.74,
#         "temp_max": 281.51,
#         "pressure": 999,
#         "humidity": 64
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.23,
#         "deg": 280,
#         "gust": 13.38
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1662890021,
#     "sys": {
#         "type": 2,
#         "id": 2002195,
#         "country": "AU",
#         "sunrise": 1662841247,
#         "sunset": 1662882876
#     },
#     "timezone": 36000,
#     "id": 2163355,
#     "name": "Hobart",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -54.0148,
#         "lat": 48.8499
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 284.93,
#         "feels_like": 284.64,
#         "temp_min": 284.93,
#         "temp_max": 285.79,
#         "pressure": 1010,
#         "humidity": 95,
#         "sea_level": 1010,
#         "grnd_level": 1006
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.93,
#         "deg": 23,
#         "gust": 16.72
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890143,
#     "sys": {
#         "type": 1,
#         "id": 719,
#         "country": "CA",
#         "sunrise": 1662887221,
#         "sunset": 1662933524
#     },
#     "timezone": -9000,
#     "id": 5970873,
#     "name": "Hare Bay",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 26.891,
#         "lat": -33.5906
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 294.36,
#         "feels_like": 294,
#         "temp_min": 294.36,
#         "temp_max": 294.36,
#         "pressure": 1017,
#         "humidity": 56
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.58,
#         "deg": 210,
#         "gust": 7.15
#     },
#     "clouds": {
#         "all": 99
#     },
#     "dt": 1662890144,
#     "sys": {
#         "type": 2,
#         "id": 2072861,
#         "country": "ZA",
#         "sunrise": 1662869856,
#         "sunset": 1662912063
#     },
#     "timezone": 7200,
#     "id": 964432,
#     "name": "Port Alfred",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -99.8901,
#         "lat": 16.8634
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 298.12,
#         "feels_like": 298.92,
#         "temp_min": 298.12,
#         "temp_max": 298.12,
#         "pressure": 1012,
#         "humidity": 86,
#         "sea_level": 1012,
#         "grnd_level": 1009
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.53,
#         "deg": 71,
#         "gust": 4.7
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890144,
#     "sys": {
#         "country": "MX",
#         "sunrise": 1662899244,
#         "sunset": 1662943515
#     },
#     "timezone": -18000,
#     "id": 3533462,
#     "name": "Acapulco de Ju\u00e1rez",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -50.2056,
#         "lat": -30.1811
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 282.74,
#         "feels_like": 281.77,
#         "temp_min": 282.74,
#         "temp_max": 282.74,
#         "pressure": 1023,
#         "humidity": 77,
#         "sea_level": 1023,
#         "grnd_level": 1023
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.12,
#         "deg": 255,
#         "gust": 2.42
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662890144,
#     "sys": {
#         "country": "BR",
#         "sunrise": 1662888260,
#         "sunset": 1662930656
#     },
#     "timezone": -10800,
#     "id": 3466165,
#     "name": "Cidreira",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": -62.9967,
#         "lat": -40.8135
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 280.55,
#         "feels_like": 277.74,
#         "temp_min": 280.55,
#         "temp_max": 280.55,
#         "pressure": 1017,
#         "humidity": 39,
#         "sea_level": 1017,
#         "grnd_level": 1016
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.45,
#         "deg": 349,
#         "gust": 7.81
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662890145,
#     "sys": {
#         "country": "AR",
#         "sunrise": 1662891601,
#         "sunset": 1662933454
#     },
#     "timezone": -10800,
#     "id": 3832899,
#     "name": "Viedma",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 125.4092,
#         "lat": -8.9266
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 290.77,
#         "feels_like": 290.62,
#         "temp_min": 290.77,
#         "temp_max": 290.77,
#         "pressure": 1013,
#         "humidity": 78,
#         "sea_level": 1013,
#         "grnd_level": 858
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.89,
#         "deg": 159,
#         "gust": 1.61
#     },
#     "clouds": {
#         "all": 87
#     },
#     "dt": 1662890145,
#     "sys": {
#         "country": "TL",
#         "sunrise": 1662845697,
#         "sunset": 1662888946
#     },
#     "timezone": 32400,
#     "id": 1651810,
#     "name": "Airai",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -3.9836,
#         "lat": 22.6783
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 313.28,
#         "feels_like": 311.32,
#         "temp_min": 313.28,
#         "temp_max": 313.28,
#         "pressure": 1011,
#         "humidity": 15,
#         "sea_level": 1011,
#         "grnd_level": 996
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.57,
#         "deg": 302,
#         "gust": 5.8
#     },
#     "clouds": {
#         "all": 8
#     },
#     "dt": 1662890146,
#     "sys": {
#         "country": "ML",
#         "sunrise": 1662876091,
#         "sunset": 1662920644
#     },
#     "timezone": 0,
#     "id": 2450173,
#     "name": "Taoudenni",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 57.7575,
#         "lat": -20.3428
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 298.29,
#         "feels_like": 298.45,
#         "temp_min": 297.71,
#         "temp_max": 298.29,
#         "pressure": 1021,
#         "humidity": 61
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.66,
#         "deg": 110
#     },
#     "rain": {
#         "1h": 0.17
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1662890147,
#     "sys": {
#         "type": 1,
#         "id": 2061,
#         "country": "MU",
#         "sunrise": 1662862154,
#         "sunset": 1662904953
#     },
#     "timezone": 14400,
#     "id": 1106677,
#     "name": "Bambous Virieux",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -133.0374,
#         "lat": 69.4541
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 276.63,
#         "feels_like": 273.24,
#         "temp_min": 276.63,
#         "temp_max": 276.63,
#         "pressure": 1013,
#         "humidity": 88,
#         "sea_level": 1013,
#         "grnd_level": 1013
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.84,
#         "deg": 68,
#         "gust": 4.61
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890147,
#     "sys": {
#         "country": "CA",
#         "sunrise": 1662904279,
#         "sunset": 1662954387
#     },
#     "timezone": -21600,
#     "id": 6170031,
#     "name": "Tuktoyaktuk",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -38.6531,
#         "lat": -3.7361
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 298.73,
#         "feels_like": 299.17,
#         "temp_min": 298.73,
#         "temp_max": 299.12,
#         "pressure": 1015,
#         "humidity": 70
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.66,
#         "deg": 130
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1662890073,
#     "sys": {
#         "type": 2,
#         "id": 2008290,
#         "country": "BR",
#         "sunrise": 1662884957,
#         "sunset": 1662928415
#     },
#     "timezone": -10800,
#     "id": 3402429,
#     "name": "Caucaia",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -59.5167,
#         "lat": 13.2167
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 301.49,
#         "feels_like": 305.77,
#         "temp_min": 301.49,
#         "temp_max": 301.49,
#         "pressure": 1014,
#         "humidity": 78
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.17,
#         "deg": 110
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1662890148,
#     "sys": {
#         "type": 1,
#         "id": 8772,
#         "country": "BB",
#         "sunrise": 1662889632,
#         "sunset": 1662933753
#     },
#     "timezone": -14400,
#     "id": 3374083,
#     "name": "Bathsheba",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -103.6833,
#         "lat": 18.7333
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 298.14,
#         "feels_like": 299.12,
#         "temp_min": 298.14,
#         "temp_max": 298.14,
#         "pressure": 1011,
#         "humidity": 93,
#         "sea_level": 1011,
#         "grnd_level": 1010
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.49,
#         "deg": 48,
#         "gust": 1.49
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890148,
#     "sys": {
#         "country": "MX",
#         "sunrise": 1662900114,
#         "sunset": 1662944465
#     },
#     "timezone": -18000,
#     "id": 4013679,
#     "name": "Coahuayana Viejo",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -134.9692,
#         "lat": -23.1203
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 295.47,
#         "feels_like": 295.72,
#         "temp_min": 295.47,
#         "temp_max": 295.47,
#         "pressure": 1022,
#         "humidity": 75,
#         "sea_level": 1022,
#         "grnd_level": 1019
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.97,
#         "deg": 66,
#         "gust": 5.08
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662890148,
#     "sys": {
#         "country": "PF",
#         "sunrise": 1662908435,
#         "sunset": 1662951158
#     },
#     "timezone": -32400,
#     "id": 4030556,
#     "name": "Rikitea",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -2.1697,
#         "lat": 7.0805
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 297.21,
#         "feels_like": 297.73,
#         "temp_min": 297.21,
#         "temp_max": 297.21,
#         "pressure": 1017,
#         "humidity": 79,
#         "sea_level": 1017,
#         "grnd_level": 991
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.28,
#         "deg": 238,
#         "gust": 2.32
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890148,
#     "sys": {
#         "country": "GH",
#         "sunrise": 1662875994,
#         "sunset": 1662919871
#     },
#     "timezone": 0,
#     "id": 2303258,
#     "name": "Boma",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": 18.4232,
#         "lat": -33.9258
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 289.87,
#         "feels_like": 289.22,
#         "temp_min": 289.21,
#         "temp_max": 290.58,
#         "pressure": 1024,
#         "humidity": 62
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.66,
#         "deg": 220
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1662890054,
#     "sys": {
#         "type": 2,
#         "id": 2073005,
#         "country": "ZA",
#         "sunrise": 1662871895,
#         "sunset": 1662914088
#     },
#     "timezone": 7200,
#     "id": 3369157,
#     "name": "Cape Town",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 170.5667,
#         "lat": -45.75
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 282.48,
#         "feels_like": 281.1,
#         "temp_min": 282.48,
#         "temp_max": 282.48,
#         "pressure": 1007,
#         "humidity": 90,
#         "sea_level": 1007,
#         "grnd_level": 1005
#     },
#     "visibility": 9696,
#     "wind": {
#         "speed": 2.61,
#         "deg": 36,
#         "gust": 4.66
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890149,
#     "sys": {
#         "type": 2,
#         "id": 75281,
#         "country": "NZ",
#         "sunrise": 1662835775,
#         "sunset": 1662877197
#     },
#     "timezone": 43200,
#     "id": 2179825,
#     "name": "Waitati",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 167.55,
#         "lat": -13.8833
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 299.52,
#         "feels_like": 299.52,
#         "temp_min": 299.52,
#         "temp_max": 299.52,
#         "pressure": 1013,
#         "humidity": 78
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.57,
#         "deg": 190
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1662890150,
#     "sys": {
#         "type": 1,
#         "id": 7307,
#         "country": "VU",
#         "sunrise": 1662835687,
#         "sunset": 1662878733
#     },
#     "timezone": 39600,
#     "id": 2134814,
#     "name": "Sola",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 114.0833,
#         "lat": 71.9167
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 275.54,
#         "feels_like": 271.78,
#         "temp_min": 275.54,
#         "temp_max": 275.54,
#         "pressure": 1011,
#         "humidity": 81,
#         "sea_level": 1011,
#         "grnd_level": 1010
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.03,
#         "deg": 280,
#         "gust": 7.18
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890150,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662844269,
#         "sunset": 1662895809
#     },
#     "timezone": 32400,
#     "id": 2017155,
#     "name": "Saskylakh",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 79.1667,
#         "lat": 52.2667
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296.45,
#         "feels_like": 295.51,
#         "temp_min": 296.45,
#         "temp_max": 296.45,
#         "pressure": 997,
#         "humidity": 26,
#         "sea_level": 997,
#         "grnd_level": 981
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.72,
#         "deg": 127,
#         "gust": 9.3
#     },
#     "clouds": {
#         "all": 76
#     },
#     "dt": 1662890151,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662855036,
#         "sunset": 1662901798
#     },
#     "timezone": 25200,
#     "id": 1503153,
#     "name": "Klyuchi",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -165.4064,
#         "lat": 64.5011
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 280.46,
#         "feels_like": 276.56,
#         "temp_min": 280.43,
#         "temp_max": 280.46,
#         "pressure": 1004,
#         "humidity": 78,
#         "sea_level": 1004,
#         "grnd_level": 1004
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.21,
#         "deg": 71,
#         "gust": 12.75
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890151,
#     "sys": {
#         "type": 2,
#         "id": 2036054,
#         "country": "US",
#         "sunrise": 1662912797,
#         "sunset": 1662961402
#     },
#     "timezone": -28800,
#     "id": 5870133,
#     "name": "Nome",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 50.2788,
#         "lat": -14.9003
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 297.9,
#         "feels_like": 298.1,
#         "temp_min": 297.9,
#         "temp_max": 297.9,
#         "pressure": 1017,
#         "humidity": 64,
#         "sea_level": 1017,
#         "grnd_level": 1015
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.06,
#         "deg": 122,
#         "gust": 7.1
#     },
#     "clouds": {
#         "all": 8
#     },
#     "dt": 1662890151,
#     "sys": {
#         "country": "MG",
#         "sunrise": 1662863838,
#         "sunset": 1662906858
#     },
#     "timezone": 10800,
#     "id": 1071296,
#     "name": "Antalaha",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -147.7164,
#         "lat": 64.8378
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 277.59,
#         "feels_like": 276.37,
#         "temp_min": 275.42,
#         "temp_max": 280.33,
#         "pressure": 1013,
#         "humidity": 89
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.57,
#         "deg": 51,
#         "gust": 1.49
#     },
#     "clouds": {
#         "all": 95
#     },
#     "dt": 1662890151,
#     "sys": {
#         "type": 2,
#         "id": 2010677,
#         "country": "US",
#         "sunrise": 1662908502,
#         "sunset": 1662957208
#     },
#     "timezone": -28800,
#     "id": 5861897,
#     "name": "Fairbanks",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -37.6368,
#         "lat": 65.6145
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 276.64,
#         "feels_like": 274.44,
#         "temp_min": 276.64,
#         "temp_max": 276.64,
#         "pressure": 1018,
#         "humidity": 72,
#         "sea_level": 1018,
#         "grnd_level": 1013
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.31,
#         "deg": 275,
#         "gust": 2.53
#     },
#     "clouds": {
#         "all": 98
#     },
#     "dt": 1662890152,
#     "sys": {
#         "country": "GL",
#         "sunrise": 1662881928,
#         "sunset": 1662930957
#     },
#     "timezone": -7200,
#     "id": 3424607,
#     "name": "Tasiilaq",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 147.0587,
#         "lat": -42.7826
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 278.22,
#         "feels_like": 275.08,
#         "temp_min": 277.54,
#         "temp_max": 281.32,
#         "pressure": 1003,
#         "humidity": 77
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.02,
#         "deg": 286,
#         "gust": 6.71
#     },
#     "clouds": {
#         "all": 51
#     },
#     "dt": 1662890152,
#     "sys": {
#         "type": 2,
#         "id": 2031307,
#         "country": "AU",
#         "sunrise": 1662841309,
#         "sunset": 1662882945
#     },
#     "timezone": 36000,
#     "id": 2155415,
#     "name": "New Norfolk",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -81.7006,
#         "lat": 12.5847
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 301.16,
#         "feels_like": 305.75,
#         "temp_min": 301.16,
#         "temp_max": 301.16,
#         "pressure": 1012,
#         "humidity": 83
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.57,
#         "deg": 50
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1662890130,
#     "sys": {
#         "type": 1,
#         "id": 8623,
#         "country": "CO",
#         "sunrise": 1662894969,
#         "sunset": 1662939061
#     },
#     "timezone": -18000,
#     "id": 3670218,
#     "name": "San Andr\u00e9s",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 117.0645,
#         "lat": 7.9868
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 301.03,
#         "feels_like": 304.52,
#         "temp_min": 301.03,
#         "temp_max": 301.03,
#         "pressure": 1008,
#         "humidity": 77,
#         "sea_level": 1008,
#         "grnd_level": 1008
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.68,
#         "deg": 207,
#         "gust": 1.91
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662890153,
#     "sys": {
#         "country": "PH",
#         "sunrise": 1662847363,
#         "sunset": 1662891284
#     },
#     "timezone": 28800,
#     "id": 1728675,
#     "name": "Balabac",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": 168.8643,
#         "lat": -46.1927
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 278.43,
#         "feels_like": 277.34,
#         "temp_min": 278.43,
#         "temp_max": 278.43,
#         "pressure": 1006,
#         "humidity": 98,
#         "sea_level": 1006,
# ...
#         "deg": 339,
#         "gust": 5.26
#     },
#     "rain": {
#         "1h": 0.43
#     },
#     "clouds": {
#         "all": 98
#     },
#     "dt": 1662890335,
#     "sys": {
#         "country": "CD",
#         "sunrise": 1662870609,
#         "sunset": 1662914201
#     },
#     "timezone": 3600,
#     "id": 218680,
#     "name": "Boende",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 31.1141,
#         "lat": -8.7623
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 300.85,
#         "feels_like": 300.89,
#         "temp_min": 300.85,
#         "temp_max": 300.85,
#         "pressure": 1013,
#         "humidity": 45,
#         "sea_level": 1013,
#         "grnd_level": 926
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.48,
#         "deg": 330,
#         "gust": 4.86
#     },
#     "clouds": {
#         "all": 29
#     },
#     "dt": 1662890335,
#     "sys": {
#         "country": "ZM",
#         "sunrise": 1662868315,
#         "sunset": 1662911578
#     },
#     "timezone": 7200,
#     "id": 175961,
#     "name": "Mpulungu",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 116.25,
#         "lat": 50.5667
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 284.57,
#         "feels_like": 283.62,
#         "temp_min": 284.57,
#         "temp_max": 284.57,
#         "pressure": 1015,
#         "humidity": 71,
#         "sea_level": 1015,
#         "grnd_level": 914
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.89,
#         "deg": 359,
#         "gust": 5.2
#     },
#     "clouds": {
#         "all": 81
#     },
#     "dt": 1662890336,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662846225,
#         "sunset": 1662892813
#     },
#     "timezone": 32400,
#     "id": 2016735,
#     "name": "Sherlovaya Gora",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 124.8667,
#         "lat": 46.4667
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 296,
#         "feels_like": 295.59,
#         "temp_min": 296,
#         "temp_max": 296,
#         "pressure": 1011,
#         "humidity": 48,
#         "sea_level": 1011,
#         "grnd_level": 993
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.13,
#         "deg": 189,
#         "gust": 8.85
#     },
#     "clouds": {
#         "all": 98
#     },
#     "dt": 1662890336,
#     "sys": {
#         "country": "CN",
#         "sunrise": 1662844365,
#         "sunset": 1662890537
#     },
#     "timezone": 28800,
#     "id": 2036876,
#     "name": "Honggang",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 122.9911,
#         "lat": 39.7008
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 293.98,
#         "feels_like": 294.21,
#         "temp_min": 293.98,
#         "temp_max": 293.98,
#         "pressure": 1014,
#         "humidity": 80,
#         "sea_level": 1014,
#         "grnd_level": 1013
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.28,
#         "deg": 128,
#         "gust": 2.52
#     },
#     "clouds": {
#         "all": 56
#     },
#     "dt": 1662890336,
#     "sys": {
#         "country": "CN",
#         "sunrise": 1662845100,
#         "sunset": 1662890703
#     },
#     "timezone": 28800,
#     "id": 1784055,
#     "name": "Zhuanghe",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 40.6066,
#         "lat": 62.5903
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 284.98,
#         "feels_like": 284.23,
#         "temp_min": 284.98,
#         "temp_max": 284.98,
#         "pressure": 1019,
#         "humidity": 77,
#         "sea_level": 1019,
#         "grnd_level": 1000
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.8,
#         "deg": 271,
#         "gust": 4.59
#     },
#     "clouds": {
#         "all": 87
#     },
#     "dt": 1662890336,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662863475,
#         "sunset": 1662911862
#     },
#     "timezone": 10800,
#     "id": 504187,
#     "name": "Puksoozero",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": 25.5833,
#         "lat": -21.4167
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 304.73,
#         "feels_like": 302.57,
#         "temp_min": 304.73,
#         "temp_max": 304.73,
#         "pressure": 1015,
#         "humidity": 10,
#         "sea_level": 1015,
#         "grnd_level": 909
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.97,
#         "deg": 50,
#         "gust": 3.63
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662890338,
#     "sys": {
#         "country": "BW",
#         "sunrise": 1662869893,
#         "sunset": 1662912654
#     },
#     "timezone": 7200,
#     "id": 933535,
#     "name": "Letlhakane",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": -124.0198,
#         "lat": 54.0166
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 283.67,
#         "feels_like": 282.79,
#         "temp_min": 283.67,
#         "temp_max": 283.67,
#         "pressure": 1012,
#         "humidity": 77,
#         "sea_level": 1012,
#         "grnd_level": 938
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.04,
#         "deg": 279,
#         "gust": 1.1
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662890338,
#     "sys": {
#         "country": "CA",
#         "sunrise": 1662903750,
#         "sunset": 1662950588
#     },
#     "timezone": -25200,
#     "id": 6173361,
#     "name": "Vanderhoof",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 30.0167,
#         "lat": 63.3167
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 286.25,
#         "feels_like": 285.18,
#         "temp_min": 286.25,
#         "temp_max": 286.25,
#         "pressure": 1018,
#         "humidity": 60,
#         "sea_level": 1018,
#         "grnd_level": 1007
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.93,
#         "deg": 199,
#         "gust": 4.25
#     },
#     "clouds": {
#         "all": 99
#     },
#     "dt": 1662890338,
#     "sys": {
#         "country": "FI",
#         "sunrise": 1662865941,
#         "sunset": 1662914478
#     },
#     "timezone": 10800,
#     "id": 648090,
#     "name": "Lieksa",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 126.9078,
#         "lat": 41.8069
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 294.27,
#         "feels_like": 294.47,
#         "temp_min": 294.27,
#         "temp_max": 294.27,
#         "pressure": 1013,
#         "humidity": 78,
#         "sea_level": 1013,
#         "grnd_level": 974
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.75,
#         "deg": 268,
#         "gust": 1.01
#     },
#     "clouds": {
#         "all": 52
#     },
#     "dt": 1662890339,
#     "sys": {
#         "country": "CN",
#         "sunrise": 1662844078,
#         "sunset": 1662889846
#     },
#     "timezone": 28800,
#     "id": 2036069,
#     "name": "Linjiang",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 81.8167,
#         "lat": 7.4167
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 303.19,
#         "feels_like": 306.68,
#         "temp_min": 303.19,
#         "temp_max": 303.19,
#         "pressure": 1004,
#         "humidity": 63,
#         "sea_level": 1004,
#         "grnd_level": 1003
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.17,
#         "deg": 112,
#         "gust": 5.93
#     },
#     "clouds": {
#         "all": 78
#     },
#     "dt": 1662890339,
#     "sys": {
#         "country": "LK",
#         "sunrise": 1662855833,
#         "sunset": 1662899729
#     },
#     "timezone": 19800,
#     "id": 1242110,
#     "name": "Kalmunai",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 11.5,
#         "lat": 3.5167
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 297.33,
#         "feels_like": 297.58,
#         "temp_min": 297.33,
#         "temp_max": 297.33,
#         "pressure": 1016,
#         "humidity": 68,
#         "sea_level": 1016,
#         "grnd_level": 942
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.58,
#         "deg": 267,
#         "gust": 4.17
#     },
#     "rain": {
#         "1h": 0.32
#     },
#     "clouds": {
#         "all": 96
#     },
#     "dt": 1662890340,
#     "sys": {
#         "type": 1,
#         "id": 2111,
#         "country": "CM",
#         "sunrise": 1662872784,
#         "sunset": 1662916521
#     },
#     "timezone": 3600,
#     "id": 2228079,
#     "name": "Mbalmayo",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 45.1914,
#         "lat": -12.9067
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 300.01,
#         "feels_like": 301.7,
#         "temp_min": 300.01,
#         "temp_max": 300.01,
#         "pressure": 1016,
#         "humidity": 69
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.57,
#         "deg": 170
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662890340,
#     "sys": {
#         "type": 1,
#         "id": 2131,
#         "country": "YT",
#         "sunrise": 1662865019,
#         "sunset": 1662908119
#     },
#     "timezone": 10800,
#     "id": 1090397,
#     "name": "Bandrele",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 26.5333,
#         "lat": 41.5833
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 301.69,
#         "feels_like": 301.31,
#         "temp_min": 301.69,
#         "temp_max": 301.69,
#         "pressure": 1011,
#         "humidity": 40,
#         "sea_level": 1011,
#         "grnd_level": 1005
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.37,
#         "deg": 7,
#         "gust": 2.13
#     },
#     "clouds": {
#         "all": 52
#     },
#     "dt": 1662890340,
#     "sys": {
#         "country": "GR",
#         "sunrise": 1662868193,
#         "sunset": 1662913898
#     },
#     "timezone": 10800,
#     "id": 734978,
#     "name": "N\u00e9a V\u00fdssa",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 54.75,
#         "lat": 52.9167
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 285.79,
#         "feels_like": 284.39,
#         "temp_min": 285.79,
#         "temp_max": 285.79,
#         "pressure": 1021,
#         "humidity": 49,
#         "sea_level": 1021,
#         "grnd_level": 1001
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.01,
#         "deg": 332,
#         "gust": 5.33
#     },
#     "clouds": {
#         "all": 92
#     },
#     "dt": 1662890340,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662860863,
#         "sunset": 1662907688
#     },
#     "timezone": 18000,
#     "id": 495670,
#     "name": "Sharlyk",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 105.0622,
#         "lat": 29.5835
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 301.46,
#         "feels_like": 302.95,
#         "temp_min": 301.46,
#         "temp_max": 301.46,
#         "pressure": 1009,
#         "humidity": 59,
#         "sea_level": 1009,
#         "grnd_level": 970
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.65,
#         "deg": 155,
#         "gust": 2.65
#     },
#     "clouds": {
#         "all": 68
#     },
#     "dt": 1662890341,
#     "sys": {
#         "country": "CN",
#         "sunrise": 1662849732,
#         "sunset": 1662894674
#     },
#     "timezone": 28800,
#     "id": 1799491,
#     "name": "Neijiang",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 2.4901,
#         "lat": 42.181
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 297.61,
#         "feels_like": 297.21,
#         "temp_min": 296.08,
#         "temp_max": 299.4,
#         "pressure": 1017,
#         "humidity": 42,
#         "sea_level": 1017,
#         "grnd_level": 968
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.66,
#         "deg": 166,
#         "gust": 2.55
#     },
#     "clouds": {
#         "all": 3
#     },
#     "dt": 1662890341,
#     "sys": {
#         "type": 2,
#         "id": 2018885,
#         "country": "ES",
#         "sunrise": 1662873944,
#         "sunset": 1662919685
#     },
#     "timezone": 7200,
#     "id": 3115093,
#     "name": "Olot",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 90.7167,
#         "lat": 24.8833
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 302.65,
#         "feels_like": 307.44,
#         "temp_min": 302.65,
#         "temp_max": 302.65,
#         "pressure": 1003,
#         "humidity": 72,
#         "sea_level": 1003,
#         "grnd_level": 1002
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.22,
#         "deg": 154,
#         "gust": 5.49
#     },
#     "clouds": {
#         "all": 99
#     },
#     "dt": 1662890342,
#     "sys": {
#         "country": "BD",
#         "sunrise": 1662853303,
#         "sunset": 1662897988
#     },
#     "timezone": 21600,
#     "id": 1185116,
#     "name": "Netrakona",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 1.9756,
#         "lat": 7.9281
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 298.76,
#         "feels_like": 299.47,
#         "temp_min": 298.76,
#         "temp_max": 298.76,
#         "pressure": 1015,
#         "humidity": 80,
#         "sea_level": 1015,
#         "grnd_level": 994
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.96,
#         "deg": 229,
#         "gust": 2.74
#     },
#     "clouds": {
#         "all": 98
#     },
#     "dt": 1662890342,
#     "sys": {
#         "country": "BJ",
#         "sunrise": 1662874983,
#         "sunset": 1662918893
#     },
#     "timezone": 3600,
#     "id": 2391895,
#     "name": "Savalou",
#     "cod": 200
# }

# %%
print(requests.get(complete_url))
# Out:
# <Response [200]>

# %%
# setting up empty lists to hold retrieved data
city_name = []
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# processing record starting from 1
processing_record = 1

# starting statement just to match the outputs given
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Looping through the cities for data retrieval
# complete url address
for city in cities:
    complete_url = base_url + "appid=" + api_key + "&q=" + city
    
# return response object using get method and json method
    response = requests.get(complete_url).json()

# try and except method
    try:
        
        city_name.append(response["name"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        city_record = response["name"]
        print(f"Processing Record {processing_record} | {city_record}")
        
        # for next iteration
        processing_record += 1
        
    except:
        print("City not found. Skipping...") 
    
    # Print Ending Log Statement
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Hermanus
# Processing Record 2 | Cururupu
# Processing Record 3 | Vélez-Málaga
# Processing Record 4 | Faya
# Processing Record 5 | Castro
# Processing Record 6 | Hithadhoo
# Processing Record 7 | Busselton
# Processing Record 8 | Los Llanos de Aridane
# Processing Record 9 | Trzebnica
# Processing Record 10 | Talara
# Processing Record 11 | Bluff
# Processing Record 12 | Alcântara
# Processing Record 13 | Saint Paul Harbor
# Processing Record 14 | Gladstone
# Processing Record 15 | Ribeira Brava
# Processing Record 16 | Bethel
# Processing Record 17 | Benghazi
# Processing Record 18 | Punta Arenas
# City not found. Skipping...
# Processing Record 19 | Ushuaia
# Processing Record 20 | Salinas
# Processing Record 21 | Bereda
# Processing Record 22 | College
# Processing Record 23 | Clyde River
# Processing Record 24 | Longyearbyen
# City not found. Skipping...
# Processing Record 25 | Basco
# Processing Record 26 | Ashland
# Processing Record 27 | Manggar
# Processing Record 28 | Sitka
# Processing Record 29 | Hobart
# Processing Record 30 | Hare Bay
# Processing Record 31 | Port Alfred
# Processing Record 32 | Acapulco de Juárez
# Processing Record 33 | Cidreira
# City not found. Skipping...
# Processing Record 34 | Viedma
# Processing Record 35 | Airai
# Processing Record 36 | Taoudenni
# Processing Record 37 | Bambous Virieux
# Processing Record 38 | Tuktoyaktuk
# Processing Record 39 | Caucaia
# Processing Record 40 | Bathsheba
# Processing Record 41 | Coahuayana Viejo
# Processing Record 42 | Rikitea
# Processing Record 43 | Boma
# City not found. Skipping...
# Processing Record 44 | Cape Town
# Processing Record 45 | Waitati
# Processing Record 46 | Sola
# Processing Record 47 | Saskylakh
# Processing Record 48 | Klyuchi
# Processing Record 49 | Nome
# Processing Record 50 | Antalaha
# Processing Record 51 | Fairbanks
# Processing Record 52 | Tasiilaq
# Processing Record 53 | New Norfolk
# Processing Record 54 | San Andrés
# Processing Record 55 | Balabac
# City not found. Skipping...
# Processing Record 56 | Mataura
# Processing Record 57 | Jamestown
# Processing Record 58 | Hamilton
# Processing Record 59 | Byron Bay
# Processing Record 60 | Tūkrah
# City not found. Skipping...
# Processing Record 61 | Ilulissat
# Processing Record 62 | Manokwari
# Processing Record 63 | Karpathos
# Processing Record 64 | Damaturu
# Processing Record 65 | Brae
# Processing Record 66 | Kahului
# Processing Record 67 | Mar del Plata
# Processing Record 68 | Olafsvik
# Processing Record 69 | Bulgan
# City not found. Skipping...
# Processing Record 70 | Ellisras
# Processing Record 71 | Yellowknife
# Processing Record 72 | Launceston
# Processing Record 73 | Jumla
# Processing Record 74 | Chui
# Processing Record 75 | Cabo San Lucas
# Processing Record 76 | Whitehorse
# Processing Record 77 | Ponta do Sol
# Processing Record 78 | Butterworth
# Processing Record 79 | Tarko-Sale
# Processing Record 80 | Esperance
# Processing Record 81 | Vaini
# Processing Record 82 | George Town
# Processing Record 83 | Salalah
# Processing Record 84 | Magadan
# Processing Record 85 | Grindavik
# Processing Record 86 | Lebu
# Processing Record 87 | Duminichi
# Processing Record 88 | Hasaki
# Processing Record 89 | Struer Municipality
# Processing Record 90 | Dikson
# City not found. Skipping...
# Processing Record 91 | Mehamn
# Processing Record 92 | Butaritari
# Processing Record 93 | Samarai
# Processing Record 94 | Upernavik
# Processing Record 95 | Chapais
# Processing Record 96 | East London
# Processing Record 97 | Khovd
# City not found. Skipping...
# Processing Record 98 | Gold Coast
# Processing Record 99 | Mareeba
# Processing Record 100 | Mariinsk
# Processing Record 101 | Havre-St-Pierre
# City not found. Skipping...
# Processing Record 102 | Le Port
# Processing Record 103 | Saint George
# Processing Record 104 | Cherskiy
# Processing Record 105 | Paramonga
# Processing Record 106 | Vila Velha
# Processing Record 107 | Tena
# Processing Record 108 | Mier
# Processing Record 109 | Touros
# Processing Record 110 | Saint-Philippe
# Processing Record 111 | Kushmurun
# Processing Record 112 | Kapaa
# Processing Record 113 | Souillac
# Processing Record 114 | Tiksi
# Processing Record 115 | Nangwa
# Processing Record 116 | Varhaug
# Processing Record 117 | Khatanga
# Processing Record 118 | Atuona
# Processing Record 119 | Barrow
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 120 | Rapid City
# Processing Record 121 | Lithakia
# Processing Record 122 | Banda Aceh
# Processing Record 123 | Narsaq
# Processing Record 124 | Bredasdorp
# Processing Record 125 | Port Elizabeth
# Processing Record 126 | Albany
# Processing Record 127 | Lagoa
# Processing Record 128 | Ancud
# Processing Record 129 | Qaanaaq
# Processing Record 130 | Kaitangata
# Processing Record 131 | Alice Springs
# City not found. Skipping...
# Processing Record 132 | Punta Alta
# Processing Record 133 | Avarua
# Processing Record 134 | Mahibadhoo
# Processing Record 135 | Zyryanka
# City not found. Skipping...
# Processing Record 136 | Omboué
# Processing Record 137 | La Fria
# Processing Record 138 | Grand Gaube
# Processing Record 139 | Broome
# Processing Record 140 | Qaqortoq
# Processing Record 141 | Kavieng
# Processing Record 142 | Harper
# City not found. Skipping...
# Processing Record 143 | Camacha
# Processing Record 144 | Nouadhibou
# Processing Record 145 | Jalu
# Processing Record 146 | Abu Samrah
# Processing Record 147 | Hervey Bay
# Processing Record 148 | Asău
# Processing Record 149 | Kudinovo
# Processing Record 150 | Norman Wells
# Processing Record 151 | Yining
# Processing Record 152 | Tateyama
# Processing Record 153 | Dunda
# Processing Record 154 | Tiarei
# Processing Record 155 | Boralday
# City not found. Skipping...
# Processing Record 156 | Shakhtinsk
# Processing Record 157 | Khani
# Processing Record 158 | Del Rio
# Processing Record 159 | Vestmannaeyjar
# Processing Record 160 | Carnarvon
# Processing Record 161 | Bengkulu
# Processing Record 162 | Prien
# Processing Record 163 | Hilo
# Processing Record 164 | Faanui
# Processing Record 165 | Thompson
# Processing Record 166 | Pozo Colorado
# Processing Record 167 | Lavrentiya
# Processing Record 168 | Santo Antão do Tojal
# Processing Record 169 | Santa Rosa
# Processing Record 170 | Makat
# Processing Record 171 | Nampula
# Processing Record 172 | Mount Gambier
# Processing Record 173 | Puerto Ayora
# Processing Record 174 | Shingū
# Processing Record 175 | Taltal
# Processing Record 176 | Baturaja
# City not found. Skipping...
# Processing Record 177 | Seidu
# Processing Record 178 | Santa Fe
# Processing Record 179 | Marrakesh
# Processing Record 180 | Carahue
# Processing Record 181 | Provideniya
# Processing Record 182 | Dire Dawa
# Processing Record 183 | Pevek
# Processing Record 184 | Hofn
# Processing Record 185 | Alekseyevsk
# Processing Record 186 | Ippy
# Processing Record 187 | Moose Factory
# Processing Record 188 | Suoyarvi
# Processing Record 189 | Tura
# Processing Record 190 | Churapcha
# Processing Record 191 | Marawi
# Processing Record 192 | Carutapera
# City not found. Skipping...
# Processing Record 193 | Vostok
# Processing Record 194 | Chokurdakh
# Processing Record 195 | Owando
# Processing Record 196 | Lubumbashi
# City not found. Skipping...
# Processing Record 197 | Juneau
# Processing Record 198 | Ribeira Grande
# Processing Record 199 | Aasiaat
# Processing Record 200 | Leningradskiy
# Processing Record 201 | Sambava
# Processing Record 202 | Ulaangom
# Processing Record 203 | Buala
# Processing Record 204 | Baykit
# Processing Record 205 | Tomatlán
# Processing Record 206 | Fortuna
# Processing Record 207 | Haukipudas
# Processing Record 208 | Ciudad Mante
# Processing Record 209 | San Cristobal
# Processing Record 210 | Flin Flon
# Processing Record 211 | Beipiao
# Processing Record 212 | Arraial do Cabo
# Processing Record 213 | Kudahuvadhoo
# Processing Record 214 | Atar
# Processing Record 215 | Ostrovnoy
# Processing Record 216 | Gaildorf
# Processing Record 217 | Shenjiamen
# Processing Record 218 | Tommot
# Processing Record 219 | Nikolskoye
# Processing Record 220 | Comodoro Rivadavia
# City not found. Skipping...
# Processing Record 221 | Alyangula
# Processing Record 222 | Caucayá
# Processing Record 223 | Nanyuki
# Processing Record 224 | Loa Janan
# Processing Record 225 | Oyem
# Processing Record 226 | Inírida
# Processing Record 227 | Ambilobe
# Processing Record 228 | Dickson
# Processing Record 229 | Christchurch
# Processing Record 230 | Ubari
# City not found. Skipping...
# Processing Record 231 | La Rioja
# Processing Record 232 | Muborak
# Processing Record 233 | Sapele
# Processing Record 234 | Canto do Buriti
# Processing Record 235 | Margate
# Processing Record 236 | Ranfurly
# Processing Record 237 | Torbay
# Processing Record 238 | Bubaque
# Processing Record 239 | Qui Nhon
# Processing Record 240 | Pacifica
# City not found. Skipping...
# Processing Record 241 | Nuevo Progreso
# Processing Record 242 | Kavaratti
# Processing Record 243 | Atasū
# Processing Record 244 | Carbonia
# Processing Record 245 | São José da Coroa Grande
# Processing Record 246 | Zheleznodorozhnyy
# Processing Record 247 | Aberdeen
# Processing Record 248 | Talnakh
# Processing Record 249 | Katsuura
# Processing Record 250 | Severo-Kuril'sk
# Processing Record 251 | Te Anau
# Processing Record 252 | Kathmandu
# Processing Record 253 | Pinar del Río
# Processing Record 254 | Mossamedes
# Processing Record 255 | Vanimo
# Processing Record 256 | Pingzhuang
# Processing Record 257 | Thinadhoo
# Processing Record 258 | Hay River
# Processing Record 259 | Mitsamiouli
# Processing Record 260 | Rio Grande
# Processing Record 261 | Coyhaique
# Processing Record 262 | Utinga
# Processing Record 263 | Porbandar
# City not found. Skipping...
# Processing Record 264 | Navan
# Processing Record 265 | Palmerston North
# Processing Record 266 | Gavirate
# Processing Record 267 | Deer Lake
# Processing Record 268 | Kargil
# Processing Record 269 | Yar-Sale
# Processing Record 270 | Otavi
# Processing Record 271 | Tweed
# Processing Record 272 | Laas
# Processing Record 273 | Qasigiannguit
# Processing Record 274 | Djibouti
# Processing Record 275 | Dengzhou
# Processing Record 276 | Liepāja
# Processing Record 277 | Freeport
# Processing Record 278 | Mount Darwin
# Processing Record 279 | Pisco
# Processing Record 280 | Okhotsk
# Processing Record 281 | Sioux Lookout
# Processing Record 282 | Klaksvík
# Processing Record 283 | Wagar
# Processing Record 284 | Iqaluit
# Processing Record 285 | Anito
# Processing Record 286 | Ābādān
# Processing Record 287 | Portland
# Processing Record 288 | Eureka
# Processing Record 289 | Husavik
# Processing Record 290 | São Paulo de Olivença
# Processing Record 291 | Kuusamo
# Processing Record 292 | Hirara
# Processing Record 293 | Kristinestad
# Processing Record 294 | Lyngseidet
# Processing Record 295 | San-Pédro
# Processing Record 296 | Luganville
# Processing Record 297 | Rock Hill
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 298 | Weiz
# City not found. Skipping...
# Processing Record 299 | Jérémie
# Processing Record 300 | San Miguel de Tucumán
# Processing Record 301 | Aykhal
# Processing Record 302 | Hinganghāt
# City not found. Skipping...
# Processing Record 303 | Tarata
# Processing Record 304 | Pingliang
# Processing Record 305 | Takoradze
# Processing Record 306 | Nānākuli
# Processing Record 307 | Plouzané
# Processing Record 308 | Half Moon Bay
# Processing Record 309 | Rapid Valley
# Processing Record 310 | Sarangani
# Processing Record 311 | Cayenne
# Processing Record 312 | Tamala
# Processing Record 313 | Sørland
# Processing Record 314 | Leshukonskoye
# Processing Record 315 | Flinders
# Processing Record 316 | Shelburne
# Processing Record 317 | São Miguel
# Processing Record 318 | Ati
# Processing Record 319 | Bansang
# City not found. Skipping...
# Processing Record 320 | Vilhena
# Processing Record 321 | Batemans Bay
# Processing Record 322 | Jining
# Processing Record 323 | Kumul
# Processing Record 324 | Pochutla
# Processing Record 325 | Erenhot
# Processing Record 326 | Jiangyou
# Processing Record 327 | La Ronge
# Processing Record 328 | Barão de Melgaço
# Processing Record 329 | Amahai
# Processing Record 330 | Muros
# Processing Record 331 | Wolfsburg
# Processing Record 332 | Kamenka
# Processing Record 333 | Lüderitz
# Processing Record 334 | Tabas
# Processing Record 335 | Cap Malheureux
# Processing Record 336 | ‘Ewa Beach
# Processing Record 337 | Bambanglipuro
# Processing Record 338 | Sur
# Processing Record 339 | Geelong
# Processing Record 340 | Pacific Grove
# Processing Record 341 | Rome
# Processing Record 342 | Gurupi
# Processing Record 343 | Karratha
# Processing Record 344 | Auki
# Processing Record 345 | Porto Velho
# Processing Record 346 | Naviraí
# Processing Record 347 | Mbanza-Ngungu
# City not found. Skipping...
# Processing Record 348 | Ust'-Karsk
# Processing Record 349 | Xiangxiang
# Processing Record 350 | Ossora
# Processing Record 351 | Malakal
# Processing Record 352 | Omsukchan
# Processing Record 353 | Inhambane
# Processing Record 354 | Maragogi
# Processing Record 355 | Zhangaözen
# Processing Record 356 | Santa Maria
# Processing Record 357 | Codrington
# Processing Record 358 | Labytnangi
# Processing Record 359 | Saint-Ambroise
# Processing Record 360 | Yanta
# Processing Record 361 | Erzin
# Processing Record 362 | Mahébourg
# Processing Record 363 | Haifa
# Processing Record 364 | High Level
# Processing Record 365 | Canutama
# Processing Record 366 | Pathein
# Processing Record 367 | Douglas
# Processing Record 368 | Forsytheganj
# Processing Record 369 | Gbadolite
# Processing Record 370 | Matanzas
# Processing Record 371 | Nantucket
# Processing Record 372 | Verkhnyaya Maksakovka
# Processing Record 373 | Suriāpet
# City not found. Skipping...
# Processing Record 374 | Saldanha
# City not found. Skipping...
# Processing Record 375 | Houndé
# Processing Record 376 | Karema
# City not found. Skipping...
# Processing Record 377 | Sullia
# Processing Record 378 | Al Bardīyah
# Processing Record 379 | Bilma
# Processing Record 380 | Santa Ana
# Processing Record 381 | Rimbey
# Processing Record 382 | Port Augusta
# Processing Record 383 | Nizhnevartovsk
# Processing Record 384 | Samarkand
# Processing Record 385 | La Palma
# Processing Record 386 | Belaya Gora
# Processing Record 387 | Riyadh
# Processing Record 388 | Lompoc
# Processing Record 389 | Oussouye
# Processing Record 390 | Balaipungut
# Processing Record 391 | Letnyaya Stavka
# Processing Record 392 | Oddur
# Processing Record 393 | Cabedelo
# Processing Record 394 | Kasongo-Lunda
# Processing Record 395 | Roblin
# Processing Record 396 | Indianola
# Processing Record 397 | Myaundzha
# City not found. Skipping...
# Processing Record 398 | Toamasina
# Processing Record 399 | Antofagasta
# Processing Record 400 | Kenai
# Processing Record 401 | Kitim
# Processing Record 402 | Stromness
# Processing Record 403 | Puerto Quijarro
# Processing Record 404 | Kiryat Gat
# Processing Record 405 | Hāgere Hiywet
# Processing Record 406 | Eyrarbakki
# Processing Record 407 | Constitución
# City not found. Skipping...
# Processing Record 408 | Holme
# Processing Record 409 | Chul'man
# Processing Record 410 | Anadyr
# Processing Record 411 | Dunedin
# Processing Record 412 | Mvomero
# City not found. Skipping...
# Processing Record 413 | Rundu
# Processing Record 414 | Alto Araguaia
# Processing Record 415 | Sobolevo
# Processing Record 416 | Necochea
# Processing Record 417 | Bonthe
# Processing Record 418 | Yiyang
# Processing Record 419 | Hong Kong
# Processing Record 420 | Marsh Harbour
# Processing Record 421 | Paamiut
# Processing Record 422 | Inuvik
# Processing Record 423 | Makkah al Mukarramah
# Processing Record 424 | Cologne
# Processing Record 425 | Ledyard Center
# Processing Record 426 | Erdenet
# Processing Record 427 | Port Shepstone
# Processing Record 428 | Port Lincoln
# City not found. Skipping...
# Processing Record 429 | Port Hedland
# Processing Record 430 | Kolokani
# Processing Record 431 | Tautira
# Processing Record 432 | Meulaboh
# Processing Record 433 | Neuquén
# Processing Record 434 | Kuybysheve
# Processing Record 435 | Yangi Marg`ilon
# Processing Record 436 | Abu Dhabi
# Processing Record 437 | Mazatlán
# Processing Record 438 | Ust-Maya
# Processing Record 439 | Henties Bay
# Processing Record 440 | Geraldton
# Processing Record 441 | Hammerfest
# Processing Record 442 | Yegorlykskaya
# Processing Record 443 | Caravelas
# Processing Record 444 | Lokosovo
# Processing Record 445 | Goundam
# Processing Record 446 | Usinsk
# Processing Record 447 | Tuatapere
# City not found. Skipping...
# Processing Record 448 | Umm Kaddadah
# City not found. Skipping...
# Processing Record 449 | Pemangkat
# Processing Record 450 | Port-Cartier
# Processing Record 451 | Coos Bay
# Processing Record 452 | Esim
# Processing Record 453 | Bloemhof
# Processing Record 454 | Poum
# Processing Record 455 | Biak
# Processing Record 456 | Exeter
# Processing Record 457 | Along
# Processing Record 458 | Hobyo
# Processing Record 459 | Naberera
# Processing Record 460 | Caldwell
# Processing Record 461 | Māngrol
# Processing Record 462 | Haines Junction
# Processing Record 463 | Kruisfontein
# Processing Record 464 | Birin
# Processing Record 465 | Gwadar
# Processing Record 466 | Orlik
# Processing Record 467 | Ferrol
# Processing Record 468 | Namatanai
# Processing Record 469 | Khanpur
# Processing Record 470 | Vao
# Processing Record 471 | Nanortalik
# Processing Record 472 | Kennett
# Processing Record 473 | Norsup
# Processing Record 474 | Acajutla
# Processing Record 475 | Luanda
# Processing Record 476 | Dunmore Town
# Processing Record 477 | Kiama
# Processing Record 478 | Port Blair
# Processing Record 479 | Camargo
# Processing Record 480 | San Quintín
# Processing Record 481 | Hīt
# Processing Record 482 | Kaohsiung City
# Processing Record 483 | Kununurra
# Processing Record 484 | Puerto Escondido
# City not found. Skipping...
# Processing Record 485 | Kommunar
# Processing Record 486 | Dwārka
# Processing Record 487 | Río Gallegos
# Processing Record 488 | Itarema
# Processing Record 489 | Rosarito
# City not found. Skipping...
# Processing Record 490 | Namangan
# Processing Record 491 | Ashington
# Processing Record 492 | Zhuhai
# Processing Record 493 | Gadung
# Processing Record 494 | Todos Santos
# Processing Record 495 | Onufriyivka
# Processing Record 496 | Mayo
# Processing Record 497 | Forestville
# Processing Record 498 | Bodmin
# Processing Record 499 | Lyuban'
# Processing Record 500 | Pontianak
# Processing Record 501 | Morón
# Processing Record 502 | Port Hardy
# Processing Record 503 | Beringovskiy
# Processing Record 504 | Sovetskiy
# Processing Record 505 | Rocha
# Processing Record 506 | Araouane
# Processing Record 507 | Båtsfjord
# Processing Record 508 | Dickinson
# Processing Record 509 | Aitape
# Processing Record 510 | Arkhangel’skoye
# Processing Record 511 | Soc Trang
# Processing Record 512 | Coquimbo
# Processing Record 513 | Brunsbüttel
# Processing Record 514 | Luba
# Processing Record 515 | Pangody
# Processing Record 516 | Zhezkazgan
# Processing Record 517 | Ipixuna
# Processing Record 518 | Kautokeino
# Processing Record 519 | Koungheul
# Processing Record 520 | Kotelnikowo
# Processing Record 521 | Greeley
# Processing Record 522 | Galveston
# Processing Record 523 | Ketchikan
# Processing Record 524 | Hambantota
# Processing Record 525 | Wanlaweyn
# Processing Record 526 | Martinsville
# Processing Record 527 | Marsá Maţrūḩ
# Processing Record 528 | Nizhniy Kuranakh
# Processing Record 529 | Kano
# Processing Record 530 | Araceli
# Processing Record 531 | Winona
# Processing Record 532 | Bitung
# Processing Record 533 | Killybegs
# Processing Record 534 | Daru
# Processing Record 535 | Ganzhou
# Processing Record 536 | Zambezi
# Processing Record 537 | Tire
# Processing Record 538 | Alofi
# Processing Record 539 | Acaraú
# Processing Record 540 | Pringsewu
# Processing Record 541 | Boa Vista
# Processing Record 542 | Aklavik
# Processing Record 543 | Mujiayingzi
# Processing Record 544 | Guangyuan
# City not found. Skipping...
# Processing Record 545 | Saint Anthony
# Processing Record 546 | Camacupa
# Processing Record 547 | Djebeniana
# Processing Record 548 | Ahipara
# Processing Record 549 | São Desidério
# Processing Record 550 | Denizli Province
# Processing Record 551 | Galle
# Processing Record 552 | Oktyabr'skiy
# Processing Record 553 | Panama City
# Processing Record 554 | Gao
# Processing Record 555 | Urmia
# Processing Record 556 | Port-Gentil
# City not found. Skipping...
# Processing Record 557 | Perth
# Processing Record 558 | Kralendijk
# Processing Record 559 | Nyuksenitsa
# Processing Record 560 | Kushiro
# Processing Record 561 | Podari
# Processing Record 562 | Diamantino
# Processing Record 563 | Puerto Madero
# Processing Record 564 | Yārāda
# Processing Record 565 | Thunder Bay
# Processing Record 566 | Philadelphia
# Processing Record 567 | Boende
# Processing Record 568 | Mpulungu
# Processing Record 569 | Sherlovaya Gora
# Processing Record 570 | Honggang
# Processing Record 571 | Zhuanghe
# Processing Record 572 | Puksoozero
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 573 | Letlhakane
# City not found. Skipping...
# Processing Record 574 | Vanderhoof
# Processing Record 575 | Lieksa
# Processing Record 576 | Linjiang
# Processing Record 577 | Kalmunai
# Processing Record 578 | Mbalmayo
# Processing Record 579 | Bandrele
# Processing Record 580 | Néa Výssa
# Processing Record 581 | Sharlyk
# Processing Record 582 | Neijiang
# Processing Record 583 | Olot
# Processing Record 584 | Netrakona
# Processing Record 585 | Savalou
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Display the DataFrame
weather_data_dict = {
    "City": city_name,
    "Lat": latitude,
    "Lng": longitude,
    "Max Temp": max_temperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
    
}

weather_data_df = pd.DataFrame(weather_data_dict)
weather_data_df.head()
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Hermanus -34.4187  19.2345    287.00        67         100        5.36
# 1      Cururupu  -1.8283 -44.8683    298.22        86          10        1.65
# 2  Vélez-Málaga  36.7726  -4.1005    305.36        46          80        3.15
# 3          Faya  18.3851  42.4509    302.21        20          51        3.39
# 4        Castro -24.7911 -50.0119    285.60        97         100        2.63
#
#   Country        Date
# 0      ZA  1662890133
# 1      BR  1662890134
# 2      ES  1662890134
# 3      SA  1662890135
# 4      BR  1662890135

# %%
#Export the city data into a .csv.
weather_data_df.to_csv("../WeatherPy/weather_data.csv")

# %%
# using sort method to check if there are any humidity outliers
city_humidity=weather_data_df.sort_values("Humidity",ascending=False)
city_humidity
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 440     Hammerfest  70.6634  23.6821    280.40       100          75
# 280  Sioux Lookout  50.1001 -91.9170    278.19       100           0
# 266      Deer Lake  49.1667 -57.4316    279.07       100         100
# 22     Clyde River  70.4692 -68.5914    275.28       100         100
# 530         Winona  43.9666 -91.7668    285.04       100         100
# ..             ...      ...      ...       ...       ...         ...
# 452       Bloemhof -27.6469  25.6070    303.73         9          21
# 412          Rundu -17.9333  19.7667    305.90         9           0
# 269          Otavi -19.6500  17.3333    303.06         9           0
# 386         Riyadh  24.6877  46.7219    314.23         8           4
# 285         Ābādān  30.3392  48.3043    319.12         8           0
#
#      Wind Speed Country        Date
# 440        2.57      NO  1662890296
# 280        0.00      CA  1662890239
# 266        1.03      CA  1662890235
# 22         0.00      CA  1662890141
# 530        2.06      US  1662890324
# ..          ...     ...         ...
# 452        8.18      ZA  1662890300
# 412        3.00      NA  1662890286
# 269        3.34      NA  1662890236
# 386        5.31      SA  1662890003
# 285        9.77      IR  1662890240
#
# [585 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labelling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# scatter plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Max Temp"], facecolors="blue", marker="o", edgecolor="black")

# axis title and labels
plt.title("Latitude vs. Temperature (11/09/2022)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# saving figure
plt.savefig("../WeatherPy/Latitude vs. Temperature.png")

# showing plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# scatter plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Humidity"], facecolors="blue", marker="o", edgecolor="black")

# axis title and labels
plt.title("City Latitude vs. Humidity (11/09/2022)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# saving figure
plt.savefig("../WeatherPy/City Latitude vs. Humidity.png")

# showing plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# scatter plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Cloudiness"], facecolors="blue", marker="o", edgecolor="black")

# axis title and labels
plt.title("City Latitude vs. Cloudiness (11/09/2022)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# saving figure
plt.savefig("../WeatherPy/City Latitude vs. Cloudiness.png")

# showing plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# scatter plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Wind Speed"], facecolors="blue", marker="o", edgecolor="black")

# axis title and labels
plt.title("City Latitude vs. Wind Speed (11/09/2022)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# saving figure
plt.savefig("../WeatherPy/City Latitude vs. Wind Speed.png")

# showing plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_data_df.loc[weather_data_df["Lat"] >= 0]
southern_df = weather_data_df.loc[weather_data_df["Lat"] < 0]

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = northern_df['Lat']
y_values = northern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,275),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.6439347180828897

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = southern_df['Lat']
y_values = southern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,280),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.6178975514473648

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = northern_df['Lat']
y_values = northern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=13,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.008949676934199216

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = southern_df['Lat']
y_values = southern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,42),fontsize=13,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.007841572366376483

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = northern_df['Lat']
y_values = northern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,24),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.01153723767485205

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = southern_df['Lat']
y_values = southern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,65),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.003342978454392337

# %% [markdown]
# ### Wind Speed (m/s) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = northern_df['Lat']
y_values = northern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,14),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.001330364539011799

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = southern_df['Lat']
y_values = southern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.0010956661712881537

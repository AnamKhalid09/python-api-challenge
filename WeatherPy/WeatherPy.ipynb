# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Enter your API key here
api_key = weather_api_key
 
# base_url variable to store url
# base_url = "http://api.openweathermap.org/data/2.5/weather?"
base_url = "http://api.openweathermap.org/data/2.5/weather?units=metric&"
 
# complete url address
for city in cities:
    complete_url = base_url + "appid=" + api_key + "&q=" + city
    
# return response object using get method and json method
    response = requests.get(complete_url).json()
    
    print(json.dumps(response, indent=4))
# Out:
# {
#     "coord": {
#         "lon": 168.3333,
#         "lat": -46.6
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 7.39,
#         "feels_like": 4.69,
#         "temp_min": 7.39,
#         "temp_max": 7.39,
#         "pressure": 1002,
#         "humidity": 81,
#         "sea_level": 1002,
#         "grnd_level": 999
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.2,
#         "deg": 9,
#         "gust": 6.23
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901707,
#     "sys": {
#         "country": "NZ",
#         "sunrise": 1662922623,
#         "sunset": 1662964178
#     },
#     "timezone": 43200,
#     "id": 2206939,
#     "name": "Bluff",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 102.2655,
#         "lat": -3.8004
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 25.64,
#         "feels_like": 26.3,
#         "temp_min": 25.64,
#         "temp_max": 25.64,
#         "pressure": 1011,
#         "humidity": 78,
#         "sea_level": 1011,
#         "grnd_level": 1008
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.06,
#         "deg": 6,
#         "gust": 1.33
#     },
#     "clouds": {
#         "all": 96
#     },
#     "dt": 1662901708,
#     "sys": {
#         "country": "ID",
#         "sunrise": 1662851149,
#         "sunset": 1662894600
#     },
#     "timezone": 25200,
#     "id": 1649150,
#     "name": "Bengkulu",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 20.0403,
#         "lat": -34.5322
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 15.41,
#         "feels_like": 14.42,
#         "temp_min": 15.41,
#         "temp_max": 15.41,
#         "pressure": 1023,
#         "humidity": 54,
#         "sea_level": 1023,
#         "grnd_level": 1014
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.3,
#         "deg": 237,
#         "gust": 8.9
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901708,
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1662871522,
#         "sunset": 1662913685
#     },
#     "timezone": 7200,
#     "id": 1015776,
#     "name": "Bredasdorp",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -175.2,
#         "lat": -21.2
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 23.83,
#         "feels_like": 24.28,
#         "temp_min": 23.83,
#         "temp_max": 23.83,
#         "pressure": 1018,
#         "humidity": 77,
#         "sea_level": 1018,
#         "grnd_level": 1015
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.76,
#         "deg": 93,
#         "gust": 6.08
#     },
#     "clouds": {
#         "all": 9
#     },
#     "dt": 1662901709,
#     "sys": {
#         "country": "TO",
#         "sunrise": 1663004387,
#         "sunset": 1663047268
#     },
#     "timezone": 46800,
#     "id": 4032243,
#     "name": "Vaini",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 20.1347,
#         "lat": 54.675
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 16.03,
#         "feels_like": 15.02,
#         "temp_min": 15.54,
#         "temp_max": 16.03,
#         "pressure": 1011,
#         "humidity": 51,
#         "sea_level": 1011,
#         "grnd_level": 1011
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.61,
#         "deg": 360,
#         "gust": 9.44
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901709,
#     "sys": {
#         "type": 1,
#         "id": 8934,
#         "country": "RU",
#         "sunrise": 1662869068,
#         "sunset": 1662916094
#     },
#     "timezone": 7200,
#     "id": 485660,
#     "name": "Tsimmerbude",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -139.0333,
#         "lat": -9.8
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 24.77,
#         "feels_like": 25.1,
#         "temp_min": 24.77,
#         "temp_max": 24.77,
#         "pressure": 1014,
#         "humidity": 69,
#         "sea_level": 1014,
#         "grnd_level": 1006
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.72,
#         "deg": 78,
#         "gust": 9.53
#     },
#     "clouds": {
#         "all": 14
#     },
#     "dt": 1662901709,
#     "sys": {
#         "country": "PF",
#         "sunrise": 1662909153,
#         "sunset": 1662952390
#     },
#     "timezone": -34200,
#     "id": 4020109,
#     "name": "Atuona",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -73.65,
#         "lat": -37.6167
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 9.15,
#         "feels_like": 8.45,
#         "temp_min": 9.15,
#         "temp_max": 9.15,
#         "pressure": 1025,
#         "humidity": 86,
#         "sea_level": 1025,
#         "grnd_level": 1021
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.73,
#         "deg": 135,
#         "gust": 2.63
#     },
#     "clouds": {
#         "all": 4
#     },
#     "dt": 1662901709,
#     "sys": {
#         "country": "CL",
#         "sunrise": 1662894066,
#         "sunset": 1662936101
#     },
#     "timezone": -10800,
#     "id": 3883457,
#     "name": "Lebu",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -57.5575,
#         "lat": -38.0023
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 12.62,
#         "feels_like": 11.79,
#         "temp_min": 10.01,
#         "temp_max": 13.3,
#         "pressure": 1024,
#         "humidity": 71
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.12,
#         "deg": 320
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901710,
#     "sys": {
#         "type": 2,
#         "id": 2073060,
#         "country": "AR",
#         "sunrise": 1662890218,
#         "sunset": 1662932227
#     },
#     "timezone": -10800,
#     "id": 3430863,
#     "name": "Mar del Plata",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 150.8552,
#         "lat": -34.5833
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 12.82,
#         "feels_like": 11.67,
#         "temp_min": 11.7,
#         "temp_max": 12.88,
#         "pressure": 1011,
#         "humidity": 58
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.92,
#         "deg": 268,
#         "gust": 7.6
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901710,
#     "sys": {
#         "type": 2,
#         "id": 2033627,
#         "country": "AU",
#         "sunrise": 1662840159,
#         "sunset": 1662882273
#     },
#     "timezone": 36000,
#     "id": 6255012,
#     "name": "Flinders",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -114.3525,
#         "lat": 62.456
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 6.98,
#         "feels_like": 2.87,
#         "temp_min": 6.98,
#         "temp_max": 6.98,
#         "pressure": 1005,
#         "humidity": 75
#     },
#     "visibility": 268,
#     "wind": {
#         "speed": 7.6,
#         "deg": 290,
#         "gust": 11.18
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901711,
#     "sys": {
#         "type": 2,
#         "id": 47671,
#         "country": "CA",
#         "sunrise": 1662900748,
#         "sunset": 1662948951
#     },
#     "timezone": -21600,
#     "id": 6185377,
#     "name": "Yellowknife",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 128.8694,
#         "lat": 71.6872
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 2.95,
#         "feels_like": -1.21,
#         "temp_min": 2.95,
#         "temp_max": 2.95,
#         "pressure": 1008,
#         "humidity": 97,
#         "sea_level": 1008,
#         "grnd_level": 1004
#     },
#     "visibility": 40,
#     "wind": {
#         "speed": 4.97,
#         "deg": 282,
#         "gust": 7.71
#     },
#     "rain": {
#         "1h": 0.3
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901711,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662840766,
#         "sunset": 1662892216
#     },
#     "timezone": 32400,
#     "id": 2015306,
#     "name": "Tiksi",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 23.6866,
#         "lat": 3.8146
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 27.77,
#         "feels_like": 29.65,
#         "temp_min": 27.77,
#         "temp_max": 27.77,
#         "pressure": 1009,
#         "humidity": 65,
#         "sea_level": 1009,
#         "grnd_level": 955
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.86,
#         "deg": 254,
#         "gust": 3.6
#     },
#     "rain": {
#         "1h": 0.22
#     },
#     "clouds": {
#         "all": 58
#     },
#     "dt": 1662901712,
#     "sys": {
#         "country": "CD",
#         "sunrise": 1662869854,
#         "sunset": 1662913603
#     },
#     "timezone": 7200,
#     "id": 218253,
#     "name": "Bondo",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 140.7667,
#         "lat": -37.8333
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 7.78,
#         "feels_like": 6.79,
#         "temp_min": 7.78,
#         "temp_max": 7.78,
#         "pressure": 1019,
#         "humidity": 88,
#         "sea_level": 1019,
#         "grnd_level": 1010
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.81,
#         "deg": 244,
#         "gust": 2.67
#     },
#     "clouds": {
#         "all": 99
#     },
#     "dt": 1662901712,
#     "sys": {
#         "country": "AU",
#         "sunrise": 1662842667,
#         "sunset": 1662884606
#     },
#     "timezone": 34200,
#     "id": 2156643,
#     "name": "Mount Gambier",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -120.4579,
#         "lat": 34.6391
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 21.96,
#         "feels_like": 22.43,
#         "temp_min": 20.9,
#         "temp_max": 22.54,
#         "pressure": 1015,
#         "humidity": 85
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.54,
#         "deg": 100
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901713,
#     "sys": {
#         "type": 1,
#         "id": 4747,
#         "country": "US",
#         "sunrise": 1662903731,
#         "sunset": 1662948898
#     },
#     "timezone": -25200,
#     "id": 5367788,
#     "name": "Lompoc",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 27.9116,
#         "lat": -33.0153
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 19.57,
#         "feels_like": 19.2,
#         "temp_min": 19.57,
#         "temp_max": 19.57,
#         "pressure": 1016,
#         "humidity": 62,
#         "sea_level": 1016,
#         "grnd_level": 1010
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 11.35,
#         "deg": 212,
#         "gust": 13.6
#     },
#     "clouds": {
#         "all": 16
#     },
#     "dt": 1662901714,
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1662869597,
#         "sunset": 1662911833
#     },
#     "timezone": 7200,
#     "id": 1006984,
#     "name": "East London",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -147.7164,
#         "lat": 64.8378
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 2.34,
#         "feels_like": 0.2,
#         "temp_min": -0.81,
#         "temp_max": 5.72,
#         "pressure": 1013,
#         "humidity": 93
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.06,
#         "deg": 70
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901715,
#     "sys": {
#         "type": 1,
#         "id": 7684,
#         "country": "US",
#         "sunrise": 1662908502,
#         "sunset": 1662957208
#     },
#     "timezone": -28800,
#     "id": 5861897,
#     "name": "Fairbanks",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": -5.0242,
#         "lat": 5.1367
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 26.26,
#         "feels_like": 26.26,
#         "temp_min": 26.26,
#         "temp_max": 26.26,
#         "pressure": 1014,
#         "humidity": 73,
#         "sea_level": 1014,
#         "grnd_level": 1014
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.62,
#         "deg": 211,
#         "gust": 4.48
#     },
#     "clouds": {
#         "all": 81
#     },
#     "dt": 1662901715,
#     "sys": {
#         "country": "CI",
#         "sunrise": 1662876718,
#         "sunset": 1662920517
#     },
#     "timezone": 0,
#     "id": 2288105,
#     "name": "Grand-Lahou",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -68.3,
#         "lat": -54.8
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 7.81,
#         "feels_like": 4.79,
#         "temp_min": 7.81,
#         "temp_max": 7.81,
#         "pressure": 998,
#         "humidity": 46
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.14,
#         "deg": 300
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1662901715,
#     "sys": {
#         "type": 1,
#         "id": 8303,
#         "country": "AR",
#         "sunrise": 1662893391,
#         "sunset": 1662934208
#     },
#     "timezone": -10800,
#     "id": 3833367,
#     "name": "Ushuaia",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -42.0278,
#         "lat": -22.9661
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 20.92,
#         "feels_like": 20.97,
#         "temp_min": 20.92,
#         "temp_max": 20.92,
#         "pressure": 1021,
#         "humidity": 73
#     },
#     "visibility": 9000,
#     "wind": {
#         "speed": 3.6,
#         "deg": 240
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901716,
#     "sys": {
#         "type": 1,
#         "id": 8326,
#         "country": "BR",
#         "sunrise": 1662886141,
#         "sunset": 1662928851
#     },
#     "timezone": -10800,
#     "id": 3471451,
#     "name": "Arraial do Cabo",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": -70.4833,
#         "lat": -25.4
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 14.2,
#         "feels_like": 13.4,
#         "temp_min": 14.2,
#         "temp_max": 14.2,
#         "pressure": 1023,
#         "humidity": 66,
#         "sea_level": 1023,
#         "grnd_level": 1022
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.71,
#         "deg": 232,
#         "gust": 1.54
#     },
#     "clouds": {
#         "all": 5
#     },
#     "dt": 1662901717,
#     "sys": {
#         "country": "CL",
#         "sunrise": 1662893017,
#         "sunset": 1662935630
#     },
#     "timezone": -10800,
#     "id": 3870243,
#     "name": "Taltal",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 115.3333,
#         "lat": -33.65
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 12.6,
#         "feels_like": 12.08,
#         "temp_min": 12.6,
#         "temp_max": 12.6,
#         "pressure": 1014,
#         "humidity": 83,
#         "sea_level": 1014,
#         "grnd_level": 1014
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.15,
#         "deg": 112,
#         "gust": 1.12
#     },
#     "clouds": {
#         "all": 4
#     },
#     "dt": 1662901244,
#     "sys": {
#         "country": "AU",
#         "sunrise": 1662848652,
#         "sunset": 1662890826
#     },
#     "timezone": 28800,
#     "id": 2075265,
#     "name": "Busselton",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 114.0833,
#         "lat": 71.9167
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 0.46,
#         "feels_like": -3.15,
#         "temp_min": 0.46,
#         "temp_max": 0.46,
#         "pressure": 1012,
#         "humidity": 87,
#         "sea_level": 1012,
#         "grnd_level": 1011
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.24,
#         "deg": 255,
#         "gust": 4.96
#     },
#     "clouds": {
#         "all": 95
#     },
#     "dt": 1662901718,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662844269,
#         "sunset": 1662895809
#     },
#     "timezone": 32400,
#     "id": 2017155,
#     "name": "Saskylakh",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 27.8492,
#         "lat": 71.0357
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 6.97,
#         "feels_like": 6.97,
#         "temp_min": 6.95,
#         "temp_max": 6.97,
#         "pressure": 1012,
#         "humidity": 87
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.51,
#         "deg": 0
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901719,
#     "sys": {
#         "type": 1,
#         "id": 1633,
#         "country": "NO",
#         "sunrise": 1662865237,
#         "sunset": 1662916222
#     },
#     "timezone": 7200,
#     "id": 778707,
#     "name": "Mehamn",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -126.8329,
#         "lat": 65.282
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 8.02,
#         "feels_like": 6.43,
#         "temp_min": 8.02,
#         "temp_max": 8.02,
#         "pressure": 1014,
#         "humidity": 93
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.57,
#         "deg": 290
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1662901719,
#     "sys": {
#         "type": 1,
#         "id": 951,
#         "country": "CA",
#         "sunrise": 1662903424,
#         "sunset": 1662952264
#     },
#     "timezone": -21600,
#     "id": 6089245,
#     "name": "Norman Wells",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -134.9692,
#         "lat": -23.1203
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 22.17,
#         "feels_like": 22.4,
#         "temp_min": 22.17,
#         "temp_max": 22.17,
#         "pressure": 1021,
#         "humidity": 75,
#         "sea_level": 1021,
#         "grnd_level": 1018
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.26,
#         "deg": 56,
#         "gust": 3.52
#     },
#     "clouds": {
#         "all": 3
#     },
#     "dt": 1662901720,
#     "sys": {
#         "country": "PF",
#         "sunrise": 1662908435,
#         "sunset": 1662951158
#     },
#     "timezone": -32400,
#     "id": 4030556,
#     "name": "Rikitea",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -158.0858,
#         "lat": 21.3469
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 22.15,
#         "feels_like": 22.59,
#         "temp_min": 21.18,
#         "temp_max": 24.18,
#         "pressure": 1015,
#         "humidity": 83
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.06,
#         "deg": 320
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901721,
#     "sys": {
#         "type": 1,
#         "id": 7868,
#         "country": "US",
#         "sunrise": 1662913113,
#         "sunset": 1662957572
#     },
#     "timezone": -36000,
#     "id": 5850554,
#     "name": "Makakilo City",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -113.5841,
#         "lat": 37.1041
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 19.33,
#         "feels_like": 19.33,
#         "temp_min": 19.33,
#         "temp_max": 19.33,
#         "pressure": 1020,
#         "humidity": 77
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0,
#         "deg": 0
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901721,
#     "sys": {
#         "type": 1,
#         "id": 5832,
#         "country": "US",
#         "sunrise": 1662902002,
#         "sunset": 1662947328
#     },
#     "timezone": -21600,
#     "id": 5546220,
#     "name": "Saint George",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 43.3831,
#         "lat": 38.4924
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 24.64,
#         "feels_like": 23.73,
#         "temp_min": 24.64,
#         "temp_max": 24.64,
#         "pressure": 1019,
#         "humidity": 22
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.57,
#         "deg": 280
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901726,
#     "sys": {
#         "type": 1,
#         "id": 6998,
#         "country": "TR",
#         "sunrise": 1662864261,
#         "sunset": 1662909744
#     },
#     "timezone": 10800,
#     "id": 298117,
#     "name": "Van",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 17.9442,
#         "lat": -33.0117
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 14.42,
#         "feels_like": 13.61,
#         "temp_min": 14.42,
#         "temp_max": 14.42,
#         "pressure": 1024,
#         "humidity": 65,
#         "sea_level": 1024,
#         "grnd_level": 1020
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.14,
#         "deg": 190,
#         "gust": 9.54
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901729,
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1662871987,
#         "sunset": 1662914226
#     },
#     "timezone": 7200,
#     "id": 3361934,
#     "name": "Saldanha",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 57.5167,
#         "lat": -20.5167
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 22.2,
#         "feels_like": 22.33,
#         "temp_min": 22.2,
#         "temp_max": 22.2,
#         "pressure": 1020,
#         "humidity": 71,
#         "sea_level": 1020,
#         "grnd_level": 1018
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.83,
#         "deg": 97,
#         "gust": 8.02
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901729,
#     "sys": {
#         "country": "MU",
#         "sunrise": 1662862216,
#         "sunset": 1662905007
#     },
#     "timezone": 14400,
#     "id": 933995,
#     "name": "Souillac",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 147.3294,
#         "lat": -42.8794
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 7.35,
#         "feels_like": 3.02,
#         "temp_min": 4.59,
#         "temp_max": 7.92,
#         "pressure": 1001,
#         "humidity": 64
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.75,
#         "deg": 310
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1662901729,
#     "sys": {
#         "type": 2,
#         "id": 2002195,
#         "country": "AU",
#         "sunrise": 1662841247,
#         "sunset": 1662882876
#     },
#     "timezone": 36000,
#     "id": 2163355,
#     "name": "Hobart",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 167.6833,
#         "lat": -46.1333
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 5.82,
#         "feels_like": 3.78,
#         "temp_min": 5.82,
#         "temp_max": 5.82,
#         "pressure": 1002,
#         "humidity": 85,
#         "sea_level": 1002,
#         "grnd_level": 999
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.61,
#         "deg": 10,
#         "gust": 3.72
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901730,
#     "sys": {
#         "country": "NZ",
#         "sunrise": 1662922763,
#         "sunset": 1662964349
#     },
#     "timezone": 43200,
#     "id": 2180815,
#     "name": "Tuatapere",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -151.75,
#         "lat": -16.4833
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 26.02,
#         "feels_like": 26.02,
#         "temp_min": 26.02,
#         "temp_max": 26.02,
#         "pressure": 1015,
#         "humidity": 70,
#         "sea_level": 1015,
#         "grnd_level": 1015
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.81,
#         "deg": 89,
#         "gust": 8.52
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901730,
#     "sys": {
#         "country": "PF",
#         "sunrise": 1662912329,
#         "sunset": 1662955317
#     },
#     "timezone": -36000,
#     "id": 4034551,
#     "name": "Faanui",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -79.2353,
#         "lat": 42.097
#     },
#     "weather": [
#         {
#             "id": 501,
#             "main": "Rain",
#             "description": "moderate rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 17.32,
#         "feels_like": 17.04,
#         "temp_min": 16.4,
#         "temp_max": 18.77,
#         "pressure": 1019,
#         "humidity": 74
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.06,
#         "deg": 90
#     },
#     "rain": {
#         "1h": 2.37
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901731,
#     "sys": {
#         "type": 2,
#         "id": 2008933,
#         "country": "US",
#         "sunrise": 1662893576,
#         "sunset": 1662939271
#     },
#     "timezone": -14400,
#     "id": 5122534,
#     "name": "Jamestown",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -6.3865,
#         "lat": 58.2093
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 15.58,
#         "feels_like": 15.39,
#         "temp_min": 15.58,
#         "temp_max": 15.98,
#         "pressure": 1011,
#         "humidity": 84
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.72,
#         "deg": 190
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1662901731,
#     "sys": {
#         "type": 2,
#         "id": 2043200,
#         "country": "GB",
#         "sunrise": 1662875182,
#         "sunset": 1662922707
#     },
#     "timezone": 3600,
#     "id": 2636790,
#     "name": "Stornoway",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -70.9167,
#         "lat": -53.15
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 7.06,
#         "feels_like": 2.5,
#         "temp_min": 6.73,
#         "temp_max": 7.06,
#         "pressure": 1004,
#         "humidity": 70
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 9.26,
#         "deg": 320
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1662901731,
#     "sys": {
#         "type": 1,
#         "id": 8487,
#         "country": "CL",
#         "sunrise": 1662893941,
#         "sunset": 1662934914
#     },
#     "timezone": -10800,
#     "id": 3874787,
#     "name": "Punta Arenas",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -124.1573,
#         "lat": 40.5982
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 13.42,
#         "feels_like": 13.19,
#         "temp_min": 12.73,
#         "temp_max": 14.25,
#         "pressure": 1015,
#         "humidity": 91
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.6,
#         "deg": 99,
#         "gust": 0.8
#     },
#     "clouds": {
#         "all": 98
#     },
#     "dt": 1662901732,
#     "sys": {
#         "type": 2,
#         "id": 2040243,
#         "country": "US",
#         "sunrise": 1662904421,
#         "sunset": 1662949984
#     },
#     "timezone": -25200,
#     "id": 5563839,
#     "name": "Fortuna",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -47.3561,
#         "lat": -0.6136
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 29.05,
#         "feels_like": 32.47,
#         "temp_min": 29.05,
#         "temp_max": 29.05,
#         "pressure": 1014,
#         "humidity": 68,
#         "sea_level": 1014,
#         "grnd_level": 1014
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.8,
#         "deg": 61,
#         "gust": 4.07
#     },
#     "clouds": {
#         "all": 32
#     },
#     "dt": 1662901733,
#     "sys": {
#         "country": "BR",
#         "sunrise": 1662886986,
#         "sunset": 1662930563
#     },
#     "timezone": -10800,
#     "id": 3389822,
#     "name": "Salin\u00f3polis",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 153.5667,
#         "lat": -28.8667
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 15.56,
#         "feels_like": 15.36,
#         "temp_min": 13.02,
#         "temp_max": 15.56,
#         "pressure": 1017,
#         "humidity": 84,
#         "sea_level": 1017,
#         "grnd_level": 1017
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.7,
#         "deg": 11,
#         "gust": 3.73
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901734,
#     "sys": {
#         "type": 2,
#         "id": 2019476,
#         "country": "AU",
#         "sunrise": 1662839366,
#         "sunset": 1662881765
#     },
#     "timezone": 36000,
#     "id": 2177069,
#     "name": "Ballina",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": 30.7861,
#         "lat": 59.7035
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 16.93,
#         "feels_like": 15.7,
#         "temp_min": 14.88,
#         "temp_max": 17.15,
#         "pressure": 1017,
#         "humidity": 39,
#         "sea_level": 1017,
#         "grnd_level": 1013
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.7,
#         "deg": 124,
#         "gust": 3.65
#     },
#     "clouds": {
#         "all": 1
#     },
#     "dt": 1662901736,
#     "sys": {
#         "type": 2,
#         "id": 2034996,
#         "country": "RU",
#         "sunrise": 1662866120,
#         "sunset": 1662913931
#     },
#     "timezone": 10800,
#     "id": 546105,
#     "name": "Nikolskoye",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 147.2712,
#         "lat": -2.0226
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 26.97,
#         "feels_like": 29.23,
#         "temp_min": 26.97,
#         "temp_max": 26.97,
#         "pressure": 1011,
#         "humidity": 75,
#         "sea_level": 1011,
#         "grnd_level": 1011
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.75,
#         "deg": 58,
#         "gust": 2.53
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901737,
#     "sys": {
#         "country": "PG",
#         "sunrise": 1662840316,
#         "sunset": 1662883835
#     },
#     "timezone": 36000,
#     "id": 2092164,
#     "name": "Lorengau",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 81.1185,
#         "lat": 6.1241
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 31.19,
#         "feels_like": 35.78,
#         "temp_min": 31.19,
#         "temp_max": 31.19,
#         "pressure": 1006,
#         "humidity": 62
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.17,
#         "deg": 260
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1662901737,
#     "sys": {
#         "type": 1,
#         "id": 9124,
#         "country": "LK",
#         "sunrise": 1662856027,
#         "sunset": 1662899870
#     },
#     "timezone": 19800,
#     "id": 1244926,
#     "name": "Hambantota",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 114.0089,
#         "lat": 4.4148
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 26.14,
#         "feels_like": 26.14,
#         "temp_min": 26.14,
#         "temp_max": 26.14,
#         "pressure": 1010,
#         "humidity": 79,
#         "sea_level": 1010,
#         "grnd_level": 1010
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.68,
#         "deg": 225,
#         "gust": 1.34
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901596,
#     "sys": {
#         "country": "MY",
#         "sunrise": 1662848169,
#         "sunset": 1662891944
#     },
#     "timezone": 28800,
#     "id": 1738050,
#     "name": "Marabu",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -50.9494,
#         "lat": -24.2083
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 20.14,
#         "feels_like": 20.17,
#         "temp_min": 20.14,
#         "temp_max": 20.14,
#         "pressure": 1018,
#         "humidity": 75,
#         "sea_level": 1018,
#         "grnd_level": 931
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.81,
#         "deg": 85,
#         "gust": 1.97
#     },
#     "clouds": {
#         "all": 84
#     },
#     "dt": 1662901738,
#     "sys": {
#         "country": "BR",
#         "sunrise": 1662888307,
#         "sunset": 1662930966
#     },
#     "timezone": -10800,
#     "id": 3455777,
#     "name": "Ortigueira",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 114.1577,
#         "lat": 22.2855
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 30.18,
#         "feels_like": 37.18,
#         "temp_min": 30.03,
#         "temp_max": 30.54,
#         "pressure": 1008,
#         "humidity": 77
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.58,
#         "deg": 210
#     },
#     "clouds": {
#         "all": 1
#     },
#     "dt": 1662901498,
#     "sys": {
#         "type": 2,
#         "id": 2035800,
#         "country": "HK",
#         "sunrise": 1662847741,
#         "sunset": 1662892301
#     },
#     "timezone": 28800,
#     "id": 1819729,
#     "name": "Hong Kong",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 178.4167,
#         "lat": 69.3833
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 2.16,
#         "feels_like": -1.25,
#         "temp_min": 2.16,
#         "temp_max": 2.16,
#         "pressure": 1004,
#         "humidity": 96,
#         "sea_level": 1004,
#         "grnd_level": 1003
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.45,
#         "deg": 124,
#         "gust": 4.19
#     },
#     "clouds": {
#         "all": 98
#     },
#     "dt": 1662901738,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662915974,
#         "sunset": 1662965988
#     },
#     "timezone": 43200,
#     "id": 2123814,
#     "name": "Leningradskiy",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -159.319,
#         "lat": 22.0752
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 22.93,
#         "feels_like": 23.6,
#         "temp_min": 22.29,
#         "temp_max": 23.99,
#         "pressure": 1014,
#         "humidity": 89
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.57,
#         "deg": 290
#     },
#     "rain": {
#         "1h": 0.25
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1662901739,
#     "sys": {
#         "type": 2,
#         "id": 2005473,
#         "country": "US",
#         "sunrise": 1662913393,
#         "sunset": 1662957885
#     },
#     "timezone": -36000,
#     "id": 5848280,
#     "name": "Kapaa",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 16.3333,
#         "lat": -17.4667
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 34.91,
#         "feels_like": 32.22,
#         "temp_min": 34.91,
#         "temp_max": 34.91,
#         "pressure": 1008,
#         "humidity": 7,
#         "sea_level": 1008,
#         "grnd_level": 892
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.33,
#         "deg": 151,
#         "gust": 4.15
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901739,
#     "sys": {
#         "country": "NA",
#         "sunrise": 1662872031,
#         "sunset": 1662914955
#     },
#     "timezone": 7200,
#     "id": 3357804,
#     "name": "Eenhana",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 132.4325,
#         "lat": 62.0025
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 1.51,
#         "feels_like": -1.21,
#         "temp_min": 1.51,
#         "temp_max": 1.51,
#         "pressure": 1020,
#         "humidity": 81,
#         "sea_level": 1020,
#         "grnd_level": 998
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.48,
#         "deg": 261,
#         "gust": 2.63
#     },
#     "clouds": {
#         "all": 7
#     },
#     "dt": 1662901740,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662841460,
#         "sunset": 1662889812
#     },
#     "timezone": 32400,
#     "id": 2025241,
#     "name": "Churapcha",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 47.6231,
#         "lat": 54.1135
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 12.62,
#         "feels_like": 11.11,
#         "temp_min": 12.62,
#         "temp_max": 12.62,
#         "pressure": 1023,
#         "humidity": 45,
#         "sea_level": 1023,
#         "grnd_level": 990
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.87,
#         "deg": 322,
#         "gust": 3.45
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901741,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662862499,
#         "sunset": 1662909471
#     },
#     "timezone": 14400,
#     "id": 528278,
#     "name": "Mayna",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 153.6833,
#         "lat": 67.45
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 6.13,
#         "feels_like": 3.63,
#         "temp_min": 6.13,
#         "temp_max": 6.13,
#         "pressure": 1006,
#         "humidity": 90,
#         "sea_level": 1006,
#         "grnd_level": 1003
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.35,
#         "deg": 310,
#         "gust": 5.68
#     },
#     "rain": {
#         "1h": 0.19
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901741,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662922243,
#         "sunset": 1662971588
#     },
#     "timezone": 39600,
#     "id": 2121025,
#     "name": "Srednekolymsk",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -173.3,
#         "lat": 64.3833
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 6.26,
#         "feels_like": 2.24,
#         "temp_min": 6.26,
#         "temp_max": 6.26,
#         "pressure": 1000,
#         "humidity": 88,
#         "sea_level": 1000,
#         "grnd_level": 1000
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.68,
#         "deg": 50,
#         "gust": 10.11
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901742,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1663001283,
#         "sunset": 1663049460
#     },
#     "timezone": 43200,
#     "id": 4031574,
#     "name": "Provideniya",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 71.7122,
#         "lat": 51.7433
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 9.58,
#         "feels_like": 6.63,
#         "temp_min": 9.58,
#         "temp_max": 9.58,
#         "pressure": 1004,
#         "humidity": 89,
#         "sea_level": 1004,
#         "grnd_level": 965
#     },
#     "visibility": 8245,
#     "wind": {
#         "speed": 6.24,
#         "deg": 1,
#         "gust": 8.9
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901742,
#     "sys": {
#         "country": "KZ",
#         "sunrise": 1662856858,
#         "sunset": 1662903553
#     },
#     "timezone": 21600,
#     "id": 1516527,
#     "name": "Zholymbet",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -70.3042,
#         "lat": -18.475
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 16.13,
#         "feels_like": 15.55,
#         "temp_min": 14.75,
#         "temp_max": 16.13,
#         "pressure": 1021,
#         "humidity": 67
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.54,
#         "deg": 190
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901742,
#     "sys": {
#         "type": 1,
#         "id": 8476,
#         "country": "CL",
#         "sunrise": 1662892832,
#         "sunset": 1662935729
#     },
#     "timezone": -10800,
#     "id": 3899361,
#     "name": "Arica",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 1.0114,
#         "lat": 20.1986
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 38.47,
#         "feels_like": 36.83,
#         "temp_min": 38.47,
#         "temp_max": 38.47,
#         "pressure": 1010,
#         "humidity": 18,
#         "sea_level": 1010,
#         "grnd_level": 955
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.95,
#         "deg": 303,
#         "gust": 3.4
#     },
#     "clouds": {
#         "all": 5
#     },
#     "dt": 1662901743,
#     "sys": {
#         "country": "ML",
#         "sunrise": 1662874951,
#         "sunset": 1662919388
#     },
#     "timezone": 0,
#     "id": 2449893,
#     "name": "Tessalit",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 170.3133,
#         "lat": 69.7008
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 4.82,
#         "feels_like": 4.82,
#         "temp_min": 4.82,
#         "temp_max": 4.82,
#         "pressure": 1000,
#         "humidity": 76,
#         "sea_level": 1000,
#         "grnd_level": 994
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.72,
#         "deg": 124,
#         "gust": 0.77
#     },
#     "clouds": {
#         "all": 14
#     },
#     "dt": 1662901743,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662917866,
#         "sunset": 1662967984
#     },
#     "timezone": 43200,
#     "id": 2122090,
#     "name": "Pevek",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 19.2345,
#         "lat": -34.4187
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 14.89,
#         "feels_like": 14.29,
#         "temp_min": 14.89,
#         "temp_max": 14.89,
#         "pressure": 1024,
#         "humidity": 71,
#         "sea_level": 1024,
#         "grnd_level": 1020
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.46,
#         "deg": 221,
# ...
#         "pressure": 1013,
#         "humidity": 76,
#         "sea_level": 1013,
#         "grnd_level": 983
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.33,
#         "deg": 244,
#         "gust": 1.4
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901930,
#     "sys": {
#         "type": 2,
#         "id": 2004108,
#         "country": "US",
#         "sunrise": 1662901879,
#         "sunset": 1662946972
#     },
#     "timezone": -25200,
#     "id": 5287262,
#     "name": "Buckeye",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 166.4372,
#         "lat": 68.0546
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 8.83,
#         "feels_like": 7.98,
#         "temp_min": 8.83,
#         "temp_max": 8.83,
#         "pressure": 1000,
#         "humidity": 60,
#         "sea_level": 1000,
#         "grnd_level": 966
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.83,
#         "deg": 213,
#         "gust": 1.85
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901993,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662919082,
#         "sunset": 1662968629
#     },
#     "timezone": 43200,
#     "id": 2126682,
#     "name": "Bilibino",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 122.65,
#         "lat": 11.15
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 27.57,
#         "feels_like": 32.41,
#         "temp_min": 27.57,
#         "temp_max": 27.57,
#         "pressure": 1010,
#         "humidity": 90,
#         "sea_level": 1010,
#         "grnd_level": 1004
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.92,
#         "deg": 204,
#         "gust": 1.61
#     },
#     "clouds": {
#         "all": 97
#     },
#     "dt": 1662901993,
#     "sys": {
#         "type": 2,
#         "id": 2073369,
#         "country": "PH",
#         "sunrise": 1662845956,
#         "sunset": 1662890010
#     },
#     "timezone": 28800,
#     "id": 1694500,
#     "name": "City of Passi",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -54.9167,
#         "lat": -34.6667
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 11.66,
#         "feels_like": 10.29,
#         "temp_min": 11.24,
#         "temp_max": 11.66,
#         "pressure": 1024,
#         "humidity": 54,
#         "sea_level": 1024,
#         "grnd_level": 1015
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.76,
#         "deg": 109,
#         "gust": 2.11
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901993,
#     "sys": {
#         "type": 1,
#         "id": 8712,
#         "country": "UY",
#         "sunrise": 1662889498,
#         "sunset": 1662931679
#     },
#     "timezone": -10800,
#     "id": 3441890,
#     "name": "Departamento de Maldonado",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -50.3606,
#         "lat": -20.6483
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 29.25,
#         "feels_like": 28.86,
#         "temp_min": 29.25,
#         "temp_max": 29.25,
#         "pressure": 1015,
#         "humidity": 40,
#         "sea_level": 1015,
#         "grnd_level": 960
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.31,
#         "deg": 115,
#         "gust": 3.55
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901993,
#     "sys": {
#         "country": "BR",
#         "sunrise": 1662888092,
#         "sunset": 1662930899
#     },
#     "timezone": -10800,
#     "id": 3462487,
#     "name": "General Salgado",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 70.8333,
#         "lat": 66.8333
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 8.14,
#         "feels_like": 4.93,
#         "temp_min": 8.14,
#         "temp_max": 8.14,
#         "pressure": 1009,
#         "humidity": 71,
#         "sea_level": 1009,
#         "grnd_level": 1009
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.86,
#         "deg": 251,
#         "gust": 9.96
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901994,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662855664,
#         "sunset": 1662905168
#     },
#     "timezone": 18000,
#     "id": 1486321,
#     "name": "Yar-Sale",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 139.8,
#         "lat": 36.3
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 26.99,
#         "feels_like": 28.68,
#         "temp_min": 26.99,
#         "temp_max": 26.99,
#         "pressure": 1017,
#         "humidity": 68,
#         "sea_level": 1017,
#         "grnd_level": 1012
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.14,
#         "deg": 54,
#         "gust": 4.87
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901994,
#     "sys": {
#         "type": 2,
#         "id": 20751,
#         "country": "JP",
#         "sunrise": 1662841184,
#         "sunset": 1662886553
#     },
#     "timezone": 32400,
#     "id": 1853483,
#     "name": "Oyama",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "coord": {
#         "lon": 33.5867,
#         "lat": -16.1564
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 35.5,
#         "feels_like": 33.48,
#         "temp_min": 35.5,
#         "temp_max": 35.5,
#         "pressure": 1010,
#         "humidity": 19,
#         "sea_level": 1010,
#         "grnd_level": 995
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.22,
#         "deg": 149,
#         "gust": 4.03
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901994,
#     "sys": {
#         "country": "MZ",
#         "sunrise": 1662867867,
#         "sunset": 1662910840
#     },
#     "timezone": 7200,
#     "id": 1026014,
#     "name": "Tete",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -57.5667,
#         "lat": -24.9667
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 17.08,
#         "feels_like": 15.65,
#         "temp_min": 17.08,
#         "temp_max": 17.08,
#         "pressure": 1018,
#         "humidity": 31,
#         "sea_level": 1018,
#         "grnd_level": 1010
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.67,
#         "deg": 98,
#         "gust": 2.31
#     },
#     "clouds": {
#         "all": 1
#     },
#     "dt": 1662901995,
#     "sys": {
#         "type": 1,
#         "id": 8575,
#         "country": "PY",
#         "sunrise": 1662889910,
#         "sunset": 1662932539
#     },
#     "timezone": -14400,
#     "id": 3439348,
#     "name": "Benjam\u00edn Aceval",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -70.9353,
#         "lat": -17.1956
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 18.68,
#         "feels_like": 17.52,
#         "temp_min": 18.68,
#         "temp_max": 18.68,
#         "pressure": 1019,
#         "humidity": 35,
#         "sea_level": 1019,
#         "grnd_level": 857
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.17,
#         "deg": 213,
#         "gust": 1.57
#     },
#     "clouds": {
#         "all": 7
#     },
#     "dt": 1662901995,
#     "sys": {
#         "country": "PE",
#         "sunrise": 1662892958,
#         "sunset": 1662935906
#     },
#     "timezone": -18000,
#     "id": 3934608,
#     "name": "Moquegua",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 105.1578,
#         "lat": 54.8097
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 9,
#         "feels_like": 8.35,
#         "temp_min": 9,
#         "temp_max": 9,
#         "pressure": 1014,
#         "humidity": 71,
#         "sea_level": 1014,
#         "grnd_level": 965
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.65,
#         "deg": 107,
#         "gust": 1.6
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901996,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662848627,
#         "sunset": 1662895734
#     },
#     "timezone": 28800,
#     "id": 2012532,
#     "name": "Zhigalovo",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 112.4714,
#         "lat": 63.0128
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 5.19,
#         "feels_like": 3.2,
#         "temp_min": 5.19,
#         "temp_max": 5.19,
#         "pressure": 1014,
#         "humidity": 89,
#         "sea_level": 1014,
#         "grnd_level": 969
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.41,
#         "deg": 167,
#         "gust": 10.6
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901996,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1662846149,
#         "sunset": 1662894702
#     },
#     "timezone": 32400,
#     "id": 2025456,
#     "name": "Chernyshevskiy",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -85.9175,
#         "lat": 12.9256
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 23.45,
#         "feels_like": 24.46,
#         "temp_min": 23.45,
#         "temp_max": 23.45,
#         "pressure": 1014,
#         "humidity": 100
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0,
#         "deg": 0
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1662901997,
#     "sys": {
#         "type": 1,
#         "id": 7175,
#         "country": "NI",
#         "sunrise": 1662895974,
#         "sunset": 1662940080
#     },
#     "timezone": -21600,
#     "id": 3617708,
#     "name": "Matagalpa",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 80.217,
#         "lat": 6.0367
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 26,
#         "feels_like": 26,
#         "temp_min": 26,
#         "temp_max": 26,
#         "pressure": 1008,
#         "humidity": 87,
#         "sea_level": 1008,
#         "grnd_level": 1007
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.73,
#         "deg": 283,
#         "gust": 8.46
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901802,
#     "sys": {
#         "country": "LK",
#         "sunrise": 1662856245,
#         "sunset": 1662900084
#     },
#     "timezone": 19800,
#     "id": 1246294,
#     "name": "Galle",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -97.4337,
#         "lat": 47.9417
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 6.96,
#         "feels_like": 5.17,
#         "temp_min": 4.85,
#         "temp_max": 6.96,
#         "pressure": 1022,
#         "humidity": 81
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.57,
#         "deg": 190
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1662901908,
#     "sys": {
#         "type": 1,
#         "id": 5644,
#         "country": "US",
#         "sunrise": 1662897696,
#         "sunset": 1662943885
#     },
#     "timezone": -18000,
#     "id": 5059430,
#     "name": "Grand Forks",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -87.6335,
#         "lat": 46.5333
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 12.18,
#         "feels_like": 11.93,
#         "temp_min": 11.49,
#         "temp_max": 12.69,
#         "pressure": 1020,
#         "humidity": 95,
#         "sea_level": 1020,
#         "grnd_level": 972
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.5,
#         "deg": 353,
#         "gust": 7.02
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901998,
#     "sys": {
#         "type": 2,
#         "id": 2007015,
#         "country": "US",
#         "sunrise": 1662895407,
#         "sunset": 1662941470
#     },
#     "timezone": -14400,
#     "id": 5000950,
#     "name": "Marquette",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -87.3878,
#         "lat": 36.077
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 20.85,
#         "feels_like": 21.58,
#         "temp_min": 19.95,
#         "temp_max": 21.36,
#         "pressure": 1016,
#         "humidity": 99
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.6,
#         "deg": 210
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1662901999,
#     "sys": {
#         "type": 2,
#         "id": 2019185,
#         "country": "US",
#         "sunrise": 1662895745,
#         "sunset": 1662941014
#     },
#     "timezone": -18000,
#     "id": 4618057,
#     "name": "Dickson",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -71.6506,
#         "lat": 8.6219
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 28.53,
#         "feels_like": 30.53,
#         "temp_min": 28.53,
#         "temp_max": 28.53,
#         "pressure": 1015,
#         "humidity": 62,
#         "sea_level": 1015,
#         "grnd_level": 1001
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.27,
#         "deg": 271,
#         "gust": 1.52
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1662901999,
#     "sys": {
#         "country": "VE",
#         "sunrise": 1662892637,
#         "sunset": 1662936570
#     },
#     "timezone": -14400,
#     "id": 3641099,
#     "name": "El Vigia",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 32.05,
#         "lat": -8.5667
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 25.66,
#         "feels_like": 25.17,
#         "temp_min": 25.66,
#         "temp_max": 25.66,
#         "pressure": 1010,
#         "humidity": 34,
#         "sea_level": 1010,
#         "grnd_level": 847
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.82,
#         "deg": 112,
#         "gust": 2.09
#     },
#     "clouds": {
#         "all": 90
#     },
#     "dt": 1662901999,
#     "sys": {
#         "country": "TZ",
#         "sunrise": 1662868087,
#         "sunset": 1662911357
#     },
#     "timezone": 10800,
#     "id": 156098,
#     "name": "Laela",
#     "cod": 200
# }

# %%
print(requests.get(complete_url))
# Out:
# <Response [200]>

# %%
# setting up empty lists to hold retrieved data
city_name = []
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# processing record starting from 1
processing_record = 1

# starting statement just to match the outputs given
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Looping through the cities for data retrieval
# complete url address
for city in cities:
    complete_url = base_url + "appid=" + api_key + "&q=" + city
    
# return response object using get method and json method
    response = requests.get(complete_url).json()

# try and except method
    try:
        
        city_name.append(response["name"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        city_record = response["name"]
        print(f"Processing Record {processing_record} | {city_record}")
        
        # for next iteration
        processing_record += 1
        
    except:
        print("City not found. Skipping...") 
    
    # Print Ending Log Statement
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Bluff
# Processing Record 2 | Bengkulu
# Processing Record 3 | Bredasdorp
# Processing Record 4 | Vaini
# Processing Record 5 | Tsimmerbude
# Processing Record 6 | Atuona
# Processing Record 7 | Lebu
# Processing Record 8 | Mar del Plata
# Processing Record 9 | Flinders
# Processing Record 10 | Yellowknife
# Processing Record 11 | Tiksi
# Processing Record 12 | Bondo
# Processing Record 13 | Mount Gambier
# Processing Record 14 | Lompoc
# Processing Record 15 | East London
# Processing Record 16 | Fairbanks
# City not found. Skipping...
# Processing Record 17 | Grand-Lahou
# Processing Record 18 | Ushuaia
# Processing Record 19 | Arraial do Cabo
# City not found. Skipping...
# Processing Record 20 | Taltal
# Processing Record 21 | Busselton
# Processing Record 22 | Saskylakh
# Processing Record 23 | Mehamn
# Processing Record 24 | Norman Wells
# Processing Record 25 | Rikitea
# Processing Record 26 | Makakilo City
# Processing Record 27 | Saint George
# Processing Record 28 | Van
# Processing Record 29 | Saldanha
# Processing Record 30 | Souillac
# Processing Record 31 | Hobart
# Processing Record 32 | Tuatapere
# Processing Record 33 | Faanui
# Processing Record 34 | Jamestown
# Processing Record 35 | Stornoway
# Processing Record 36 | Punta Arenas
# Processing Record 37 | Fortuna
# Processing Record 38 | Salinópolis
# Processing Record 39 | Ballina
# City not found. Skipping...
# Processing Record 40 | Nikolskoye
# Processing Record 41 | Lorengau
# Processing Record 42 | Hambantota
# Processing Record 43 | Marabu
# Processing Record 44 | Ortigueira
# Processing Record 45 | Hong Kong
# Processing Record 46 | Leningradskiy
# Processing Record 47 | Kapaa
# Processing Record 48 | Eenhana
# Processing Record 49 | Churapcha
# Processing Record 50 | Mayna
# Processing Record 51 | Srednekolymsk
# Processing Record 52 | Provideniya
# Processing Record 53 | Zholymbet
# Processing Record 54 | Arica
# Processing Record 55 | Tessalit
# Processing Record 56 | Pevek
# Processing Record 57 | Hermanus
# City not found. Skipping...
# Processing Record 58 | Esperance
# City not found. Skipping...
# Processing Record 59 | Puerto Ayora
# Processing Record 60 | Nome
# Processing Record 61 | Yaan
# Processing Record 62 | Castro
# Processing Record 63 | Avarua
# Processing Record 64 | Albany
# Processing Record 65 | Ribeira Grande
# Processing Record 66 | Qasigiannguit
# Processing Record 67 | St. George's
# Processing Record 68 | Ouadda
# Processing Record 69 | Talnakh
# Processing Record 70 | Codrington
# Processing Record 71 | Kati
# Processing Record 72 | Carnarvon
# Processing Record 73 | George Town
# Processing Record 74 | Berlevåg
# Processing Record 75 | Ponta do Sol
# Processing Record 76 | Itarema
# Processing Record 77 | San Patricio
# Processing Record 78 | Torbay
# Processing Record 79 | Svetlaya
# City not found. Skipping...
# Processing Record 80 | Urcos
# Processing Record 81 | Umm Kaddadah
# Processing Record 82 | North Myrtle Beach
# Processing Record 83 | Klaksvík
# City not found. Skipping...
# Processing Record 84 | La Ronge
# Processing Record 85 | Mataura
# Processing Record 86 | New Norfolk
# Processing Record 87 | Ketchikan
# Processing Record 88 | Salalah
# Processing Record 89 | Port Keats
# Processing Record 90 | La Libertad
# Processing Record 91 | Bhan
# Processing Record 92 | Hithadhoo
# Processing Record 93 | Anadyr
# Processing Record 94 | Roald
# Processing Record 95 | Fendou
# Processing Record 96 | Mahébourg
# Processing Record 97 | Kaitangata
# Processing Record 98 | Muros
# Processing Record 99 | Antofagasta
# Processing Record 100 | Blagoyevo
# Processing Record 101 | Myre
# City not found. Skipping...
# Processing Record 102 | Thompson
# Processing Record 103 | Rodrigues Alves
# Processing Record 104 | Saint-Augustin
# Processing Record 105 | Chokurdakh
# Processing Record 106 | Tilaran
# Processing Record 107 | Barrow
# Processing Record 108 | Konëvo
# Processing Record 109 | Ailigandí
# Processing Record 110 | Futog
# Processing Record 111 | Vorţa
# Processing Record 112 | Presidencia Roque Sáenz Peña
# Processing Record 113 | Severo-Kuril'sk
# Processing Record 114 | Seymchan
# Processing Record 115 | Bereda
# Processing Record 116 | Geraldton
# Processing Record 117 | Andenes
# Processing Record 118 | Broome
# Processing Record 119 | Quatre Cocos
# Processing Record 120 | Trzcianka
# City not found. Skipping...
# Processing Record 121 | Nortelândia
# Processing Record 122 | Saint-Philippe
# Processing Record 123 | Talcahuano
# Processing Record 124 | Qaanaaq
# Processing Record 125 | Coquimbo
# Processing Record 126 | Tura
# Processing Record 127 | Alofi
# Processing Record 128 | Pentecoste
# Processing Record 129 | Kluang
# Processing Record 130 | Cape Town
# Processing Record 131 | Omboué
# Processing Record 132 | Jhajha
# Processing Record 133 | Airai
# Processing Record 134 | Bethel
# Processing Record 135 | Deputatsky
# Processing Record 136 | Upernavik
# Processing Record 137 | Honningsvåg
# City not found. Skipping...
# Processing Record 138 | Altay
# Processing Record 139 | Zaraza
# Processing Record 140 | Katsuura
# Processing Record 141 | Turukhansk
# Processing Record 142 | Celano
# Processing Record 143 | Port Alfred
# Processing Record 144 | Namatanai
# Processing Record 145 | Suleja
# Processing Record 146 | Bozdar Wada
# Processing Record 147 | Isangel
# Processing Record 148 | Troitskoye
# Processing Record 149 | Ancud
# Processing Record 150 | Puerto Madryn
# Processing Record 151 | Acajutla
# Processing Record 152 | Damietta
# Processing Record 153 | Saint-Joseph
# Processing Record 154 | Samandağ
# Processing Record 155 | Pangkalanbuun
# Processing Record 156 | Port Elizabeth
# Processing Record 157 | Turan
# Processing Record 158 | Hamilton
# Processing Record 159 | Turan
# Processing Record 160 | Bambous Virieux
# Processing Record 161 | Pervomays'k
# City not found. Skipping...
# Processing Record 162 | Los Andes
# Processing Record 163 | Rawson
# City not found. Skipping...
# Processing Record 164 | Lata
# Processing Record 165 | Samarai
# Processing Record 166 | Hilo
# City not found. Skipping...
# Processing Record 167 | Jalu
# Processing Record 168 | Cherskiy
# Processing Record 169 | Kahului
# Processing Record 170 | Tuktoyaktuk
# Processing Record 171 | Pundaguitan
# Processing Record 172 | Torbat-e Jām
# Processing Record 173 | Butaritari
# Processing Record 174 | Noshiro
# Processing Record 175 | Tasiilaq
# City not found. Skipping...
# Processing Record 176 | Goderich
# Processing Record 177 | Tougue
# Processing Record 178 | Zorritos
# Processing Record 179 | Snåase
# Processing Record 180 | Athens
# City not found. Skipping...
# Processing Record 181 | Hobyo
# Processing Record 182 | Caernarfon
# Processing Record 183 | Saint Paul Harbor
# Processing Record 184 | Baracoa
# Processing Record 185 | Alenquer
# Processing Record 186 | Sioux Lookout
# Processing Record 187 | Kiryat Gat
# Processing Record 188 | Encruzilhada do Sul
# Processing Record 189 | Farīdpur
# Processing Record 190 | Pierre
# Processing Record 191 | Socorro
# Processing Record 192 | Chino Valley
# Processing Record 193 | Owando
# Processing Record 194 | Adrar
# Processing Record 195 | Inuvik
# Processing Record 196 | Plymouth
# Processing Record 197 | Lashio
# Processing Record 198 | Sinnamary
# Processing Record 199 | Tegul'det
# Processing Record 200 | Nishihara
# Processing Record 201 | Fuling
# Processing Record 202 | Sisimiut
# Processing Record 203 | Te Anau
# Processing Record 204 | Viedma
# Processing Record 205 | San Quintín
# Processing Record 206 | Cícero Dantas
# Processing Record 207 | Port Hardy
# Processing Record 208 | Vao
# Processing Record 209 | Erenhot
# Processing Record 210 | Bam
# Processing Record 211 | Lofthus
# City not found. Skipping...
# Processing Record 212 | Alice Springs
# Processing Record 213 | Inhambane
# Processing Record 214 | São Filipe
# Processing Record 215 | Khatanga
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 216 | Sitka
# Processing Record 217 | Pangnirtung
# Processing Record 218 | Nagai
# Processing Record 219 | Ambovombe
# Processing Record 220 | Clarence Town
# City not found. Skipping...
# Processing Record 221 | Owen Sound
# Processing Record 222 | Los Zacatones
# Processing Record 223 | Pirovskoye
# Processing Record 224 | Longyearbyen
# Processing Record 225 | Mahibadhoo
# Processing Record 226 | Gorontalo
# Processing Record 227 | Port Hedland
# Processing Record 228 | Raudeberg
# Processing Record 229 | Punta Alta
# Processing Record 230 | Pochutla
# Processing Record 231 | Constitución
# Processing Record 232 | Nanortalik
# Processing Record 233 | Saint Anthony
# Processing Record 234 | Kastamonu Province
# Processing Record 235 | Touros
# Processing Record 236 | Marawi
# Processing Record 237 | Korla
# Processing Record 238 | Banyo
# Processing Record 239 | Våler
# Processing Record 240 | Port-Gentil
# Processing Record 241 | Conde
# Processing Record 242 | Hasaki
# Processing Record 243 | Bathsheba
# Processing Record 244 | Araouane
# Processing Record 245 | Agua Prieta
# Processing Record 246 | Lagoa
# Processing Record 247 | Dunedin
# Processing Record 248 | Doha
# Processing Record 249 | Cabo San Lucas
# Processing Record 250 | Caucayá
# Processing Record 251 | Altamira
# Processing Record 252 | Flagstaff
# Processing Record 253 | Ishigaki
# Processing Record 254 | Grindavik
# Processing Record 255 | Nouadhibou
# Processing Record 256 | Mpika
# Processing Record 257 | Chimoio
# Processing Record 258 | Poronaysk
# City not found. Skipping...
# Processing Record 259 | Ahipara
# Processing Record 260 | Necochea
# Processing Record 261 | Westport
# Processing Record 262 | Arlit
# Processing Record 263 | Pisco
# City not found. Skipping...
# Processing Record 264 | Urusha
# Processing Record 265 | Ulaanbaatar
# Processing Record 266 | Barcelos
# Processing Record 267 | Bennettsville
# City not found. Skipping...
# Processing Record 268 | Youhao
# Processing Record 269 | Narsingdi
# City not found. Skipping...
# Processing Record 270 | Petropavlovskoye
# Processing Record 271 | Estelle
# Processing Record 272 | Kudahuvadhoo
# Processing Record 273 | San Cristobal
# Processing Record 274 | Sysert'
# Processing Record 275 | Melfort
# Processing Record 276 | Naze
# Processing Record 277 | Tautira
# Processing Record 278 | Kavieng
# Processing Record 279 | Ferme-Neuve
# Processing Record 280 | Xining
# Processing Record 281 | Rio Brilhante
# Processing Record 282 | Kattivākkam
# Processing Record 283 | Huarmey
# Processing Record 284 | Bithūr
# Processing Record 285 | Bonthe
# City not found. Skipping...
# Processing Record 286 | Husavik
# Processing Record 287 | Lavrentiya
# Processing Record 288 | Omsukchan
# Processing Record 289 | Soubre
# Processing Record 290 | Bhola District
# Processing Record 291 | Marsá Maţrūḩ
# Processing Record 292 | Gigmoto
# Processing Record 293 | Dhilwan
# Processing Record 294 | Coolum Beach
# Processing Record 295 | Greenville
# City not found. Skipping...
# Processing Record 296 | Ayan
# Processing Record 297 | Bucerías
# Processing Record 298 | Kaoma
# Processing Record 299 | Narsaq
# Processing Record 300 | Nālūt
# Processing Record 301 | Isparta Province
# Processing Record 302 | Los Llanos de Aridane
# Processing Record 303 | Dikson
# Processing Record 304 | Vestmannaeyjar
# Processing Record 305 | Shimoda
# Processing Record 306 | Biak
# Processing Record 307 | Atar
# Processing Record 308 | Mairang
# Processing Record 309 | Clyde River
# City not found. Skipping...
# Processing Record 310 | Belmonte
# City not found. Skipping...
# Processing Record 311 | Klyuchi
# Processing Record 312 | Zhangye
# Processing Record 313 | Ostrogozhsk
# Processing Record 314 | Gua Musang
# Processing Record 315 | Kamenka
# Processing Record 316 | Broken Hill
# Processing Record 317 | Asău
# Processing Record 318 | Nampa
# Processing Record 319 | Beringovskiy
# Processing Record 320 | Kulhudhuffushi
# Processing Record 321 | Dubrovka
# Processing Record 322 | Bandarbeyla
# Processing Record 323 | Denpasar
# Processing Record 324 | Rosetta
# Processing Record 325 | Kawalu
# City not found. Skipping...
# Processing Record 326 | Terrace Bay
# Processing Record 327 | Ponferrada
# Processing Record 328 | Halvad
# Processing Record 329 | Landerneau
# Processing Record 330 | Yulara
# Processing Record 331 | Laguna
# Processing Record 332 | Kavaratti
# Processing Record 333 | Port Blair
# Processing Record 334 | Sohag
# Processing Record 335 | Murray Bridge
# Processing Record 336 | Batemans Bay
# Processing Record 337 | Praia da Vitória
# Processing Record 338 | Ostrovnoy
# Processing Record 339 | Shangrao
# Processing Record 340 | Pallasovka
# Processing Record 341 | Kropotkin
# Processing Record 342 | Buraidah
# Processing Record 343 | Athabasca
# Processing Record 344 | Ambilobe
# Processing Record 345 | Chapais
# Processing Record 346 | Alyangula
# Processing Record 347 | Mayo
# Processing Record 348 | Storforshei
# Processing Record 349 | Saint-François
# Processing Record 350 | Kumul
# Processing Record 351 | Vardø
# Processing Record 352 | Rapid Valley
# City not found. Skipping...
# Processing Record 353 | Bowen
# Processing Record 354 | Litovko
# Processing Record 355 | Christchurch
# Processing Record 356 | Lázaro Cárdenas
# Processing Record 357 | Juegang
# Processing Record 358 | Havre-St-Pierre
# Processing Record 359 | Maoming
# Processing Record 360 | Haverhill
# Processing Record 361 | Mangai
# Processing Record 362 | Taitung City
# Processing Record 363 | Weligama
# Processing Record 364 | Beisfjord
# Processing Record 365 | Charlestown
# City not found. Skipping...
# Processing Record 366 | Nantucket
# Processing Record 367 | Poum
# Processing Record 368 | Baijiantan
# Processing Record 369 | Marzuq
# Processing Record 370 | Dicabisagan
# Processing Record 371 | Saint-Pierre
# Processing Record 372 | Fukuechō
# Processing Record 373 | La Bañeza
# City not found. Skipping...
# Processing Record 374 | Sibu
# Processing Record 375 | Kalianget
# Processing Record 376 | Glendive
# Processing Record 377 | Namtsy
# City not found. Skipping...
# Processing Record 378 | Petropavlovsk-Kamchatskiy
# Processing Record 379 | Bensonville
# Processing Record 380 | Katherine
# Processing Record 381 | Coyhaique
# Processing Record 382 | Waddān
# City not found. Skipping...
# Processing Record 383 | Kibala
# Processing Record 384 | Haines Junction
# Processing Record 385 | Bahir Dar
# Processing Record 386 | Beidao
# Processing Record 387 | Polyarny
# Processing Record 388 | Beruwala
# Processing Record 389 | Chui
# City not found. Skipping...
# Processing Record 390 | Welver
# Processing Record 391 | Dalbandin
# Processing Record 392 | Verkhniy Lomov
# Processing Record 393 | Guerrero Negro
# Processing Record 394 | Chara
# Processing Record 395 | Rawlins
# Processing Record 396 | Moree
# Processing Record 397 | Oussouye
# Processing Record 398 | São João da Barra
# Processing Record 399 | Vila Franca do Campo
# Processing Record 400 | Yeppoon
# Processing Record 401 | Myrtle Beach
# Processing Record 402 | Chester
# Processing Record 403 | Santa Cruz de la Sierra
# Processing Record 404 | Gizo Government Station
# Processing Record 405 | Ust-Tsilma
# Processing Record 406 | Ilula
# Processing Record 407 | Mount Isa
# Processing Record 408 | Indiaroba
# Processing Record 409 | Aksu
# Processing Record 410 | Kota Belud
# Processing Record 411 | Quthing
# Processing Record 412 | Zapadnaya Dvina
# Processing Record 413 | Hualmay
# Processing Record 414 | Vila Velha
# City not found. Skipping...
# Processing Record 415 | Tot'ma
# Processing Record 416 | Beloha
# Processing Record 417 | Belém
# City not found. Skipping...
# Processing Record 418 | Hirara
# Processing Record 419 | Ciénaga
# Processing Record 420 | Ust-Maya
# Processing Record 421 | Darhan
# Processing Record 422 | Monteagudo
# Processing Record 423 | Krasnyy Chikoy
# Processing Record 424 | Sangar
# City not found. Skipping...
# Processing Record 425 | Taoudenni
# Processing Record 426 | Forsytheganj
# Processing Record 427 | Basoko
# Processing Record 428 | Ca Mau
# Processing Record 429 | Cidreira
# Processing Record 430 | Kuruman
# Processing Record 431 | Provincia di Imperia
# Processing Record 432 | Margate
# Processing Record 433 | Payo
# Processing Record 434 | Henties Bay
# Processing Record 435 | Vrangel'
# Processing Record 436 | Zyryanovsk
# Processing Record 437 | Tagusao
# Processing Record 438 | Shellbrook
# Processing Record 439 | Waipawa
# Processing Record 440 | Nyzhni Sirohozy
# Processing Record 441 | Sambava
# Processing Record 442 | Linkou
# Processing Record 443 | Båtsfjord
# Processing Record 444 | Coahuayana Viejo
# Processing Record 445 | Bariloche
# Processing Record 446 | Kuytun
# Processing Record 447 | Nizhniy Kuranakh
# Processing Record 448 | Ngunguru
# Processing Record 449 | Izazi
# Processing Record 450 | Okha
# Processing Record 451 | Belaya Gora
# Processing Record 452 | Vestmanna
# Processing Record 453 | Cordele
# Processing Record 454 | Auki
# Processing Record 455 | Östersund
# Processing Record 456 | Aykhal
# Processing Record 457 | Iqaluit
# Processing Record 458 | Menzel Kamel
# Processing Record 459 | Nampula
# Processing Record 460 | Camopi
# Processing Record 461 | Cedar City
# City not found. Skipping...
# Processing Record 462 | Dauphin
# Processing Record 463 | Launceston
# Processing Record 464 | Bubaque
# Processing Record 465 | Fort Nelson
# Processing Record 466 | Örnsköldsvik
# Processing Record 467 | Gillette
# Processing Record 468 | Grand-Bourg
# Processing Record 469 | Verkh-Usugli
# Processing Record 470 | Payakumbuh
# Processing Record 471 | Shenjiamen
# Processing Record 472 | Baghdad
# Processing Record 473 | Dwārka
# Processing Record 474 | Ringwood
# Processing Record 475 | Baturaja
# City not found. Skipping...
# Processing Record 476 | Atbasar
# Processing Record 477 | Purificación
# Processing Record 478 | Tiring
# Processing Record 479 | Slave Lake
# Processing Record 480 | Mossamedes
# City not found. Skipping...
# Processing Record 481 | Half Moon Bay
# Processing Record 482 | Chauk
# City not found. Skipping...
# Processing Record 483 | Oakdale
# Processing Record 484 | Tashtagol
# Processing Record 485 | Lüderitz
# Processing Record 486 | Bahía de Caráquez
# Processing Record 487 | Bulgan
# Processing Record 488 | Atambua
# City not found. Skipping...
# Processing Record 489 | Padang
# Processing Record 490 | Palmas Bellas
# Processing Record 491 | Zelenogorskiy
# City not found. Skipping...
# Processing Record 492 | Kiama
# Processing Record 493 | Bireun
# Processing Record 494 | Chhuīkhadān
# Processing Record 495 | Port Lincoln
# City not found. Skipping...
# Processing Record 496 | Petropavlovka
# Processing Record 497 | Tromsø
# Processing Record 498 | Istok
# Processing Record 499 | Brigg
# Processing Record 500 | Marsabit
# Processing Record 501 | Kenai
# Processing Record 502 | San Jerónimo
# Processing Record 503 | Beaumont
# City not found. Skipping...
# Processing Record 504 | Almaznyy
# Processing Record 505 | Mitú
# Processing Record 506 | Straelen
# City not found. Skipping...
# Processing Record 507 | Koutiala
# Processing Record 508 | Ariano Irpino
# Processing Record 509 | Augustów
# Processing Record 510 | Cayenne
# Processing Record 511 | Viet Tri
# Processing Record 512 | Colares
# Processing Record 513 | Nagua
# Processing Record 514 | Sesheke
# Processing Record 515 | Malartic
# Processing Record 516 | Hashtrūd
# Processing Record 517 | Homer
# Processing Record 518 | Khomutovo
# Processing Record 519 | Sakakah
# Processing Record 520 | Dudinka
# Processing Record 521 | Olafsvik
# Processing Record 522 | Adwa
# Processing Record 523 | Catherinas Lust
# Processing Record 524 | Gashua
# Processing Record 525 | Hofn
# Processing Record 526 | Wakkanai
# Processing Record 527 | Tazovsky
# Processing Record 528 | Lively
# Processing Record 529 | Finschhafen
# Processing Record 530 | Kalāleh
# Processing Record 531 | Okhotsk
# Processing Record 532 | Jaisalmer
# Processing Record 533 | Severnyy
# Processing Record 534 | Buckeye
# Processing Record 535 | Bilibino
# Processing Record 536 | City of Passi
# Processing Record 537 | Departamento de Maldonado
# Processing Record 538 | General Salgado
# Processing Record 539 | Yar-Sale
# Processing Record 540 | Oyama
# City not found. Skipping...
# Processing Record 541 | Tete
# Processing Record 542 | Benjamín Aceval
# Processing Record 543 | Moquegua
# Processing Record 544 | Zhigalovo
# Processing Record 545 | Chernyshevskiy
# Processing Record 546 | Matagalpa
# Processing Record 547 | Galle
# Processing Record 548 | Grand Forks
# Processing Record 549 | Marquette
# Processing Record 550 | Dickson
# Processing Record 551 | El Vigia
# Processing Record 552 | Laela
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Display the DataFrame
weather_data_dict = {
    "City": city_name,
    "Lat": latitude,
    "Lng": longitude,
    "Max Temp": max_temperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
    
}

weather_data_df = pd.DataFrame(weather_data_dict)
weather_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Bluff -46.6000  168.3333      7.39        81         100        4.20
# 1     Bengkulu  -3.8004  102.2655     25.64        78          96        1.06
# 2   Bredasdorp -34.5322   20.0403     15.41        54         100        7.30
# 3        Vaini -21.2000 -175.2000     23.83        77           9        5.76
# 4  Tsimmerbude  54.6750   20.1347     16.03        51         100        7.61
#
#   Country        Date
# 0      NZ  1662901707
# 1      ID  1662901911
# 2      ZA  1662902001
# 3      TO  1662902001
# 4      RU  1662901709

# %%
#Export the city data into a .csv.
weather_data_df.to_csv("../WeatherPy/weather_data.csv",index=False,header=True)

# %%
# using sort method to check if there are any humidity outliers
city_humidity=weather_data_df.sort_values("Humidity",ascending=False)
city_humidity
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 308      Clyde River  70.4692  -68.5914      3.13       100          75
# 296         Bucerías  20.7500 -105.3333     26.10       100         100
# 357  Havre-St-Pierre  50.2334  -63.5986     14.20       100         100
# 545        Matagalpa  12.9256  -85.9175     23.45       100          75
# 549          Dickson  36.0770  -87.3878     21.36        99         100
# ..               ...      ...       ...       ...       ...         ...
# 341         Buraidah  26.3260   43.9750     42.25         7           4
# 209              Bam  29.1060   58.3570     36.20         7           1
# 518          Sakakah  29.9697   40.2064     42.39         7           0
# 47           Eenhana -17.4667   16.3333     34.91         7           0
# 297            Kaoma -14.7833   24.8000     34.04         6           0
#
#      Wind Speed Country        Date
# 308        1.54      CA  1662902089
# 296        0.00      MX  1662902086
# 357        2.06      CA  1662901914
# 545        0.00      NI  1662901997
# 549        3.60      US  1662901999
# ..          ...     ...         ...
# 341        3.53      SA  1662902099
# 209        4.49      IR  1662901839
# 518        3.61      SA  1662901786
# 47         3.33      NA  1662901739
# 297        2.88      ZM  1662902087
#
# [552 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labelling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# scatter plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Max Temp"], facecolors="blue", marker="o", edgecolor="black")

# axis title and labels
plt.title("Latitude vs. Temperature (11/09/2022)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# saving figure
plt.savefig("../WeatherPy/Latitude vs. Temperature.png")

# showing plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# scatter plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Humidity"], facecolors="blue", marker="o", edgecolor="black")

# axis title and labels
plt.title("City Latitude vs. Humidity (11/09/2022)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# saving figure
plt.savefig("../WeatherPy/City Latitude vs. Humidity.png")

# showing plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# scatter plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Cloudiness"], facecolors="blue", marker="o", edgecolor="black")

# axis title and labels
plt.title("City Latitude vs. Cloudiness (11/09/2022)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# saving figure
plt.savefig("../WeatherPy/City Latitude vs. Cloudiness.png")

# showing plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# scatter plot
plt.scatter(weather_data_df["Lat"], weather_data_df["Wind Speed"], facecolors="blue", marker="o", edgecolor="black")

# axis title and labels
plt.title("City Latitude vs. Wind Speed (11/09/2022)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# saving figure
plt.savefig("../WeatherPy/City Latitude vs. Wind Speed.png")

# showing plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_data_df.loc[weather_data_df["Lat"] >= 0]
southern_df = weather_data_df.loc[weather_data_df["Lat"] < 0]

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = northern_df['Lat']
y_values = northern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,275),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.607409266001895

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = southern_df['Lat']
y_values = southern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,280),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.611468438754845

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = northern_df['Lat']
y_values = northern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=13,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.008067841602050513

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = southern_df['Lat']
y_values = southern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,42),fontsize=13,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 4.201262667596743e-05

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = northern_df['Lat']
y_values = northern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,24),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.017909261254572

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = southern_df['Lat']
y_values = southern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,65),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.0011439004740466932

# %% [markdown]
# ### Wind Speed (m/s) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = northern_df['Lat']
y_values = northern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,14),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 1.3737051272675642e-05

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot the different factors in a scatter plot
x_values = southern_df['Lat']
y_values = southern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
# saving figure
plt.savefig("../WeatherPy/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
plt.show()
# Out:
# The r-squared is: 0.034427249321249416
